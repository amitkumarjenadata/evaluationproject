# %%
import pandas as pd
df_bikes=pd.read_csv("bikes.csv",parse_dates=["date"])
df_bikes
#importing pandas library
#loading the data and parsing dates
# Out:
#           date  temperature   humidity  windspeed        count
# 0   2011-01-03     2.716070  45.715346  21.414957   120.000000
# 1   2011-01-04     2.896673  54.267219  15.136882   108.000000
# 2   2011-01-05     4.235654  45.697702  17.034578    82.000000
# 3   2011-01-06     3.112643  50.237349  10.091568    88.000000
# 4   2011-01-07     2.723918  49.144928  15.738204   148.000000
# 5   2011-01-08     1.967445  48.851252  17.035029   112.333333
# 6   2011-01-09     1.210973  48.557576  18.331855    76.666667
# 7   2011-01-10     0.454501  48.263900  19.628680    41.000000
# 8   2011-01-11     1.361393  59.623460  12.414597    43.000000
# 9   2011-01-12     1.541997  54.775880  25.432188    25.000000
# 10  2011-01-13     1.158189  47.565957  25.173470    38.000000
# 11  2011-01-14     0.953048  51.329770  12.729596    54.000000
# 12  2011-01-15     1.645921  55.850225  13.090300    42.750000
# 13  2011-01-16     2.338794  60.370679  13.451004    31.500000
# 14  2011-01-17     3.031667  64.891133  13.811708    20.250000
# 15  2011-01-18     3.724539  69.411587  14.172412     9.000000
# 16  2011-01-19     7.475045  62.715350  18.562278    78.000000
# 17  2011-01-20     5.959733  51.358079  17.676844    83.000000
# 18  2011-01-21     1.779077  46.821447  28.899955    75.000000
# 19  2011-01-22     0.452718  47.466458  24.265518    78.666667
# 20  2011-01-23    -0.873641  48.111470  19.631082    82.333333
# 21  2011-01-24    -2.200000  48.756481  14.996645    86.000000
# 22  2011-01-25     4.062848  55.748088  12.961280   186.000000
# 23  2011-01-26     3.765915  69.458098  24.663452    34.000000
# 24  2011-01-27     2.648318  59.686889  11.822905    15.000000
# 25  2011-01-28     3.069429  65.579933  12.497912    38.000000
# 26  2011-01-29     2.694496  62.056845  14.017077    39.333333
# 27  2011-01-30     2.319563  58.533757  15.536242    40.666667
# 28  2011-01-31     1.944630  55.010668  17.055406    42.000000
# 29  2011-02-01     2.507948  67.619156   7.498521    47.000000
# ..         ...          ...        ...        ...          ...
# 161 2011-06-13    24.503544  48.915277  25.483761   863.000000
# 162 2011-06-14    22.972039  49.613220  22.911058   727.000000
# 163 2011-06-15    24.089636  47.635751  15.680140   769.000000
# 164 2011-06-16    24.172387  59.733400  18.430601   545.000000
# 165 2011-06-17    25.207232  62.385586  13.905206   863.000000
# 166 2011-06-18    24.972669  62.579465  14.201135   808.333333
# 167 2011-06-19    24.738107  62.773344  14.497065   753.666667
# 168 2011-06-20    24.503544  62.967224  14.792994   699.000000
# 169 2011-06-21    26.780113  64.316600  15.902195   774.000000
# 170 2011-06-22    29.387839  60.803599  15.990431   661.000000
# 171 2011-06-23    29.139484  60.570933  20.736953   746.000000
# 172 2011-06-24    28.932555  53.312321  19.540087   969.000000
# 173 2011-06-25    28.242675  54.894326  16.819110   930.666667
# 174 2011-06-26    27.552795  56.476331  14.098133   892.333333
# 175 2011-06-27    26.862915  58.058336  11.377156   854.000000
# 176 2011-06-28    29.925974  56.709016  13.994655   732.000000
# 177 2011-06-29    29.139484  49.101432  22.378784   848.000000
# 178 2011-06-30    27.566603  45.541921  16.921304  1027.000000
# 179 2011-07-01    28.849753  43.424807  11.021927  1246.000000
# 180 2011-07-02    29.149853  46.135159  11.443672  1192.250000
# 181 2011-07-03    29.449952  48.845511  11.865418  1138.500000
# 182 2011-07-04    29.750052  51.555862  12.287164  1084.750000
# 183 2011-07-05    30.050152  54.266214  12.708910  1031.000000
# 184 2011-07-06    28.725576  62.804352  14.394110   784.000000
# 185 2011-07-07    30.215705  57.662853  15.058703   754.000000
# 186 2011-07-08    28.187490  63.618656  19.761499   692.000000
# 187 2011-07-09    29.070524  61.346450  21.121738   702.333333
# 188 2011-07-10    29.953558  59.074244  22.481976   712.666667
# 189 2011-07-11    30.836592  56.802038  23.842215   723.000000
# 190 2011-07-12    32.409522  52.521355  17.987135   662.000000
#
# [191 rows x 5 columns]

# %%
#checking the datatypes
df_bikes.dtypes
# Out:
# date           datetime64[ns]
# temperature           float64
# humidity              float64
# windspeed             float64
# count                 float64
# dtype: object

# %%
#heatmap shows no missing data present in the dataset
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df_bikes.isnull())
plt.show()

# %%
#creating a DataFrame and loanding the month year day and count data on the DataFrame
df_bikes_dates=pd.DataFrame()
df_bikes_dates["month"]=df_bikes["date"].dt.month_name()
df_bikes_dates["year"]=df_bikes["date"].dt.year
df_bikes_dates["day"]=df_bikes["date"].dt.day_name()
df_bikes_dates["count"]=df_bikes["count"]
df_bikes_dates
# Out:
#         month  year        day        count
# 0     January  2011     Monday   120.000000
# 1     January  2011    Tuesday   108.000000
# 2     January  2011  Wednesday    82.000000
# 3     January  2011   Thursday    88.000000
# 4     January  2011     Friday   148.000000
# 5     January  2011   Saturday   112.333333
# 6     January  2011     Sunday    76.666667
# 7     January  2011     Monday    41.000000
# 8     January  2011    Tuesday    43.000000
# 9     January  2011  Wednesday    25.000000
# 10    January  2011   Thursday    38.000000
# 11    January  2011     Friday    54.000000
# 12    January  2011   Saturday    42.750000
# 13    January  2011     Sunday    31.500000
# 14    January  2011     Monday    20.250000
# 15    January  2011    Tuesday     9.000000
# 16    January  2011  Wednesday    78.000000
# 17    January  2011   Thursday    83.000000
# 18    January  2011     Friday    75.000000
# 19    January  2011   Saturday    78.666667
# 20    January  2011     Sunday    82.333333
# 21    January  2011     Monday    86.000000
# 22    January  2011    Tuesday   186.000000
# 23    January  2011  Wednesday    34.000000
# 24    January  2011   Thursday    15.000000
# 25    January  2011     Friday    38.000000
# 26    January  2011   Saturday    39.333333
# 27    January  2011     Sunday    40.666667
# 28    January  2011     Monday    42.000000
# 29   February  2011    Tuesday    47.000000
# ..        ...   ...        ...          ...
# 161      June  2011     Monday   863.000000
# 162      June  2011    Tuesday   727.000000
# 163      June  2011  Wednesday   769.000000
# 164      June  2011   Thursday   545.000000
# 165      June  2011     Friday   863.000000
# 166      June  2011   Saturday   808.333333
# 167      June  2011     Sunday   753.666667
# 168      June  2011     Monday   699.000000
# 169      June  2011    Tuesday   774.000000
# 170      June  2011  Wednesday   661.000000
# 171      June  2011   Thursday   746.000000
# 172      June  2011     Friday   969.000000
# 173      June  2011   Saturday   930.666667
# 174      June  2011     Sunday   892.333333
# 175      June  2011     Monday   854.000000
# 176      June  2011    Tuesday   732.000000
# 177      June  2011  Wednesday   848.000000
# 178      June  2011   Thursday  1027.000000
# 179      July  2011     Friday  1246.000000
# 180      July  2011   Saturday  1192.250000
# 181      July  2011     Sunday  1138.500000
# 182      July  2011     Monday  1084.750000
# 183      July  2011    Tuesday  1031.000000
# 184      July  2011  Wednesday   784.000000
# 185      July  2011   Thursday   754.000000
# 186      July  2011     Friday   692.000000
# 187      July  2011   Saturday   702.333333
# 188      July  2011     Sunday   712.666667
# 189      July  2011     Monday   723.000000
# 190      July  2011    Tuesday   662.000000
#
# [191 rows x 4 columns]

# %%
#checking no. of distinct year
df_bikes_dates["year"].drop_duplicates()
# Out:
# 0    2011
# Name: year, dtype: int64

# %%
#making one more column for type_of_day
import numpy as np
df_bikes_dates["type_of_day"]=np.where((df_bikes_dates["day"]=="Sunday")|(df_bikes_dates["day"]=="Saturday"),"weekend","weekday")

# %%
df_bikes_dates
# Out:
#         month  year        day        count type_of_day
# 0     January  2011     Monday   120.000000     weekday
# 1     January  2011    Tuesday   108.000000     weekday
# 2     January  2011  Wednesday    82.000000     weekday
# 3     January  2011   Thursday    88.000000     weekday
# 4     January  2011     Friday   148.000000     weekday
# 5     January  2011   Saturday   112.333333     weekend
# 6     January  2011     Sunday    76.666667     weekend
# 7     January  2011     Monday    41.000000     weekday
# 8     January  2011    Tuesday    43.000000     weekday
# 9     January  2011  Wednesday    25.000000     weekday
# 10    January  2011   Thursday    38.000000     weekday
# 11    January  2011     Friday    54.000000     weekday
# 12    January  2011   Saturday    42.750000     weekend
# 13    January  2011     Sunday    31.500000     weekend
# 14    January  2011     Monday    20.250000     weekday
# 15    January  2011    Tuesday     9.000000     weekday
# 16    January  2011  Wednesday    78.000000     weekday
# 17    January  2011   Thursday    83.000000     weekday
# 18    January  2011     Friday    75.000000     weekday
# 19    January  2011   Saturday    78.666667     weekend
# 20    January  2011     Sunday    82.333333     weekend
# 21    January  2011     Monday    86.000000     weekday
# 22    January  2011    Tuesday   186.000000     weekday
# 23    January  2011  Wednesday    34.000000     weekday
# 24    January  2011   Thursday    15.000000     weekday
# 25    January  2011     Friday    38.000000     weekday
# 26    January  2011   Saturday    39.333333     weekend
# 27    January  2011     Sunday    40.666667     weekend
# 28    January  2011     Monday    42.000000     weekday
# 29   February  2011    Tuesday    47.000000     weekday
# ..        ...   ...        ...          ...         ...
# 161      June  2011     Monday   863.000000     weekday
# 162      June  2011    Tuesday   727.000000     weekday
# 163      June  2011  Wednesday   769.000000     weekday
# 164      June  2011   Thursday   545.000000     weekday
# 165      June  2011     Friday   863.000000     weekday
# 166      June  2011   Saturday   808.333333     weekend
# 167      June  2011     Sunday   753.666667     weekend
# 168      June  2011     Monday   699.000000     weekday
# 169      June  2011    Tuesday   774.000000     weekday
# 170      June  2011  Wednesday   661.000000     weekday
# 171      June  2011   Thursday   746.000000     weekday
# 172      June  2011     Friday   969.000000     weekday
# 173      June  2011   Saturday   930.666667     weekend
# 174      June  2011     Sunday   892.333333     weekend
# 175      June  2011     Monday   854.000000     weekday
# 176      June  2011    Tuesday   732.000000     weekday
# 177      June  2011  Wednesday   848.000000     weekday
# 178      June  2011   Thursday  1027.000000     weekday
# 179      July  2011     Friday  1246.000000     weekday
# 180      July  2011   Saturday  1192.250000     weekend
# 181      July  2011     Sunday  1138.500000     weekend
# 182      July  2011     Monday  1084.750000     weekday
# 183      July  2011    Tuesday  1031.000000     weekday
# 184      July  2011  Wednesday   784.000000     weekday
# 185      July  2011   Thursday   754.000000     weekday
# 186      July  2011     Friday   692.000000     weekday
# 187      July  2011   Saturday   702.333333     weekend
# 188      July  2011     Sunday   712.666667     weekend
# 189      July  2011     Monday   723.000000     weekday
# 190      July  2011    Tuesday   662.000000     weekday
#
# [191 rows x 5 columns]

# %%
sns.barplot(x="type_of_day",y="count",data=df_bikes_dates)
plt.show()
#shows the plot of count as the per the day .i.e weekday or weekend

# %%
#barplot to showw the count of ecah day of the week
sns.barplot(x="day",y="count",data=df_bikes_dates)
plt.show()

# %%
#barplot to show the count of each month
sns.barplot(x="month",y="count",data=df_bikes_dates)
plt.show()

# %%
#lineplot of count vs temperature shows that with increase in temperature there is a incerase in count
sns.lineplot(x="temperature",y="count",data=df_bikes)
plt.show()
#lineplot of count vs humidity shows that with increase in humidity there is a incerase in count

sns.lineplot(x="humidity",y="count",data=df_bikes)
plt.show()
#lineplot of count vs windspeed shows that with increase in windspeed there is a incerase in count

sns.lineplot(x="windspeed",y="count",data=df_bikes)
plt.show()

# %%
sns.pairplot(data=df_bikes)
#pairplot of individual column present in the dataset

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df_bikes,figsize=(15,10))
plt.show()
#scatter matrix of each of the column paired with other columns

# %%
df_bikes.hist(figsize=(15,10))
#histogram of all the numeric column
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026EE5CFCC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EE82BA0B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026EE7F996A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EE7FC1D30>]],
#       dtype=object)

# %%
x=df_bikes.drop(columns=["count","date"])
y=pd.DataFrame(df_bikes["count"])
#dividing the data into input and output

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_x=sc.fit_transform(x)
df_x=pd.DataFrame(df_x,columns=x.columns)
#scaling the input data

# %%
df_x.skew()
#checking the skewness of each column shows that no skewed column is present
# Out:
# temperature    0.053735
# humidity      -0.417698
# windspeed      0.341381
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_predict=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#creating a function to find the maximum r2score corresponding to the random_state

# %%
regr=linear_model.LinearRegression()
r_state=maxr2_score(regr,df_x,y)
#calling the function using LinearRegression
# Out:
# r2score corresponing to 42 is: 0.7842161037383236
# r2score corresponing to 43 is: 0.8561235096423362
# r2score corresponing to 44 is: 0.8220943910877586
# r2score corresponing to 45 is: 0.8091937006132763
# r2score corresponing to 46 is: 0.8311527364686458
# r2score corresponing to 47 is: 0.8499680049830113
# r2score corresponing to 48 is: 0.8844080169977218
# r2score corresponing to 49 is: 0.7772607696333791
# r2score corresponing to 50 is: 0.8479423119654566
# r2score corresponing to 51 is: 0.857105239649655
# r2score corresponing to 52 is: 0.8602915347971104
# r2score corresponing to 53 is: 0.7417387797288817
# r2score corresponing to 54 is: 0.8547014023877113
# r2score corresponing to 55 is: 0.8106582263404709
# r2score corresponing to 56 is: 0.8113479191108768
# r2score corresponing to 57 is: 0.7164471933996188
# r2score corresponing to 58 is: 0.7769039720896356
# r2score corresponing to 59 is: 0.7787656969009746
# r2score corresponing to 60 is: 0.8671666788022219
# r2score corresponing to 61 is: 0.8328841258898624
# r2score corresponing to 62 is: 0.8134655708357222
# r2score corresponing to 63 is: 0.8153068194832009
# r2score corresponing to 64 is: 0.6925378560142713
# r2score corresponing to 65 is: 0.7632766700645858
# r2score corresponing to 66 is: 0.7058054245036461
# r2score corresponing to 67 is: 0.8124438381112228
# r2score corresponing to 68 is: 0.8282652162310699
# r2score corresponing to 69 is: 0.8254643472014647
# r2score corresponing to 70 is: 0.7694857428314354
# r2score corresponing to 71 is: 0.7861928831112452
# r2score corresponing to 72 is: 0.8147360466496624
# r2score corresponing to 73 is: 0.7919662624606052
# r2score corresponing to 74 is: 0.7379007786703837
# r2score corresponing to 75 is: 0.8616927980987529
# r2score corresponing to 76 is: 0.860645134219232
# r2score corresponing to 77 is: 0.8295365840729169
# r2score corresponing to 78 is: 0.7864920433864991
# r2score corresponing to 79 is: 0.8176203283500179
# r2score corresponing to 80 is: 0.6891417637335748
# r2score corresponing to 81 is: 0.786954478340013
# r2score corresponing to 82 is: 0.8492602199389078
# r2score corresponing to 83 is: 0.7282718694714742
# r2score corresponing to 84 is: 0.8100761198378292
# r2score corresponing to 85 is: 0.8765269461126793
# r2score corresponing to 86 is: 0.9033489566161145
# r2score corresponing to 87 is: 0.7347690921820333
# r2score corresponing to 88 is: 0.9068265759551855
# r2score corresponing to 89 is: 0.8189058135705253
# r2score corresponing to 90 is: 0.855753110605714
# r2score corresponing to 91 is: 0.8599593894698235
# r2score corresponing to 92 is: 0.8047643129572049
# r2score corresponing to 93 is: 0.816660357692786
# r2score corresponing to 94 is: 0.7760893784244967
# r2score corresponing to 95 is: 0.7589842518638342
# r2score corresponing to 96 is: 0.7425027907254969
# r2score corresponing to 97 is: 0.8242843205602389
# r2score corresponing to 98 is: 0.7036836968351847
# r2score corresponing to 99 is: 0.8342454254520337
# r2score corresponing to 100 is: 0.7691270433064292
#
#
# max r2_score corresponding to  88 is 0.9068265759551855

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(df_x,y)
gknr.best_params_
#using GridSearchCV to find the best parameters
# Out:
# {'n_neighbors': 2}

# %%
def maxr2_score(knr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        knr=KNeighborsRegressor(n_neighbors=2)
        knr.fit(x_train,y_train)
        y_predict=knr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#creating a function to find the maximum r2score corresponding to the random_state

# %%
knr=KNeighborsRegressor(n_neighbors=2)
r_state=maxr2_score(knr,df_x,y)
#calling the function using KNeighborsRegressor
# Out:
# r2score corresponing to 42 is: 0.8409859178924696
# r2score corresponing to 43 is: 0.8998248261473388
# r2score corresponing to 44 is: 0.7491979411819829
# r2score corresponing to 45 is: 0.8470563178347148
# r2score corresponing to 46 is: 0.8232124547275413
# r2score corresponing to 47 is: 0.8487527275519398
# r2score corresponing to 48 is: 0.76344536838745
# r2score corresponing to 49 is: 0.7807341366693714
# r2score corresponing to 50 is: 0.8645800324265365
# r2score corresponing to 51 is: 0.753094052899996
# r2score corresponing to 52 is: 0.8865636388964723
# r2score corresponing to 53 is: 0.8167339777329485
# r2score corresponing to 54 is: 0.8871554764356016
# r2score corresponing to 55 is: 0.859071938100268
# r2score corresponing to 56 is: 0.632267740295011
# r2score corresponing to 57 is: 0.852618312105845
# r2score corresponing to 58 is: 0.8279688547565459
# r2score corresponing to 59 is: 0.8502970341669531
# r2score corresponing to 60 is: 0.8910031574660435
# r2score corresponing to 61 is: 0.8514391083289269
# r2score corresponing to 62 is: 0.8331585350069266
# r2score corresponing to 63 is: 0.8315276136246175
# r2score corresponing to 64 is: 0.6442684286490075
# r2score corresponing to 65 is: 0.8277632849688836
# r2score corresponing to 66 is: 0.7439396378829165
# r2score corresponing to 67 is: 0.8621698246097284
# r2score corresponing to 68 is: 0.8033740232867118
# r2score corresponing to 69 is: 0.8999515198776243
# r2score corresponing to 70 is: 0.8689780682081637
# r2score corresponing to 71 is: 0.862382354585304
# r2score corresponing to 72 is: 0.8900902664608268
# r2score corresponing to 73 is: 0.8494936382191304
# r2score corresponing to 74 is: 0.8606359832790637
# r2score corresponing to 75 is: 0.7860944702808035
# r2score corresponing to 76 is: 0.7701846283139893
# r2score corresponing to 77 is: 0.8277877756304166
# r2score corresponing to 78 is: 0.7796382654283569
# r2score corresponing to 79 is: 0.8565248749462492
# r2score corresponing to 80 is: 0.751279625239053
# r2score corresponing to 81 is: 0.8413333310827816
# r2score corresponing to 82 is: 0.8747312496381958
# r2score corresponing to 83 is: 0.6578613923179716
# r2score corresponing to 84 is: 0.9142009078637788
# r2score corresponing to 85 is: 0.7662207024287275
# r2score corresponing to 86 is: 0.9228544015958049
# r2score corresponing to 87 is: 0.8241014196466419
# r2score corresponing to 88 is: 0.8469422390978263
# r2score corresponing to 89 is: 0.8507812663502539
# r2score corresponing to 90 is: 0.864144539114385
# r2score corresponing to 91 is: 0.8691710502105424
# r2score corresponing to 92 is: 0.903100001307537
# r2score corresponing to 93 is: 0.8145283992162786
# r2score corresponing to 94 is: 0.8294652258547928
# r2score corresponing to 95 is: 0.8709400772129655
# r2score corresponing to 96 is: 0.8569282291970007
# r2score corresponing to 97 is: 0.8085341123272621
# r2score corresponing to 98 is: 0.6437848970122255
# r2score corresponing to 99 is: 0.8875436792248442
# r2score corresponing to 100 is: 0.7834228728249426
#
#
# max r2_score corresponding to  86 is 0.9228544015958049

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
grid_param={"random_state":range(0,20)}
Gdt=GridSearchCV(dtr,param_grid=grid_param,scoring='r2',cv=10)
Gdt.fit(df_x,y)
Gdt.best_params_
#using GridSearchCV to find the best parameters
# Out:
# {'random_state': 5}

# %%
knr=DecisionTreeRegressor(random_state=5)
r_state=maxr2_score(dtr,df_x,y)
#calling the function using DecisionTreeRegressor
# Out:
# r2score corresponing to 42 is: 0.8409859178924696
# r2score corresponing to 43 is: 0.8998248261473388
# r2score corresponing to 44 is: 0.7491979411819829
# r2score corresponing to 45 is: 0.8470563178347148
# r2score corresponing to 46 is: 0.8232124547275413
# r2score corresponing to 47 is: 0.8487527275519398
# r2score corresponing to 48 is: 0.76344536838745
# r2score corresponing to 49 is: 0.7807341366693714
# r2score corresponing to 50 is: 0.8645800324265365
# r2score corresponing to 51 is: 0.753094052899996
# r2score corresponing to 52 is: 0.8865636388964723
# r2score corresponing to 53 is: 0.8167339777329485
# r2score corresponing to 54 is: 0.8871554764356016
# r2score corresponing to 55 is: 0.859071938100268
# r2score corresponing to 56 is: 0.632267740295011
# r2score corresponing to 57 is: 0.852618312105845
# r2score corresponing to 58 is: 0.8279688547565459
# r2score corresponing to 59 is: 0.8502970341669531
# r2score corresponing to 60 is: 0.8910031574660435
# r2score corresponing to 61 is: 0.8514391083289269
# r2score corresponing to 62 is: 0.8331585350069266
# r2score corresponing to 63 is: 0.8315276136246175
# r2score corresponing to 64 is: 0.6442684286490075
# r2score corresponing to 65 is: 0.8277632849688836
# r2score corresponing to 66 is: 0.7439396378829165
# r2score corresponing to 67 is: 0.8621698246097284
# r2score corresponing to 68 is: 0.8033740232867118
# r2score corresponing to 69 is: 0.8999515198776243
# r2score corresponing to 70 is: 0.8689780682081637
# r2score corresponing to 71 is: 0.862382354585304
# r2score corresponing to 72 is: 0.8900902664608268
# r2score corresponing to 73 is: 0.8494936382191304
# r2score corresponing to 74 is: 0.8606359832790637
# r2score corresponing to 75 is: 0.7860944702808035
# r2score corresponing to 76 is: 0.7701846283139893
# r2score corresponing to 77 is: 0.8277877756304166
# r2score corresponing to 78 is: 0.7796382654283569
# r2score corresponing to 79 is: 0.8565248749462492
# r2score corresponing to 80 is: 0.751279625239053
# r2score corresponing to 81 is: 0.8413333310827816
# r2score corresponing to 82 is: 0.8747312496381958
# r2score corresponing to 83 is: 0.6578613923179716
# r2score corresponing to 84 is: 0.9142009078637788
# r2score corresponing to 85 is: 0.7662207024287275
# r2score corresponing to 86 is: 0.9228544015958049
# r2score corresponing to 87 is: 0.8241014196466419
# r2score corresponing to 88 is: 0.8469422390978263
# r2score corresponing to 89 is: 0.8507812663502539
# r2score corresponing to 90 is: 0.864144539114385
# r2score corresponing to 91 is: 0.8691710502105424
# r2score corresponing to 92 is: 0.903100001307537
# r2score corresponing to 93 is: 0.8145283992162786
# r2score corresponing to 94 is: 0.8294652258547928
# r2score corresponing to 95 is: 0.8709400772129655
# r2score corresponing to 96 is: 0.8569282291970007
# r2score corresponing to 97 is: 0.8085341123272621
# r2score corresponing to 98 is: 0.6437848970122255
# r2score corresponing to 99 is: 0.8875436792248442
# r2score corresponing to 100 is: 0.7834228728249426
#
#
# max r2_score corresponding to  86 is 0.9228544015958049

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
regr_score_mean=cross_val_score(regr,df_x,y,cv=5,scoring="r2").mean()
regr_score_std=cross_val_score(regr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of linearRegression :",regr_score_mean)
print("stadard deviation for r2 score of linearRegression :",regr_score_std)
knr_score_mean=cross_val_score(knr,df_x,y,cv=5,scoring="r2").mean()
knr_score_std=cross_val_score(knr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of knr:",knr_score_mean)
print("standard deviation of r2score for knr:",knr_score_std)
dtr_score_mean=cross_val_score(dtr,df_x,y,cv=5,scoring="r2").mean()
dtr_score_std=cross_val_score(dtr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of DecisionTrennRegression :",dtr_score_mean)
print("stadard deviation for r2 score of DecisionTreeeRegression :",dtr_score_std)
#crosss validation for bias-variance tradeoff using cross_val_score
# Out:
# mean r2 score of linearRegression : -1.3420349056530623
# stadard deviation for r2 score of linearRegression : 2.5439734486786834
# mean r2 score of knr: -2.8923826943938495
# standard deviation of r2score for knr: 4.818330785755209
# mean r2 score of DecisionTrennRegression : -2.681490820211852
# stadard deviation for r2 score of DecisionTreeeRegression : 5.112411096689186

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(df_x,y)
clf.best_params_
#using GridSearchCV to find the best parameters
# Out:
# {'alpha': 0.001}

# %%
def maxr2_score(lsreg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        lsreg=Lasso(alpha=0.001)
        lsreg.fit(x_train,y_train)
        y_predict=lsreg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#creating a function to find the maximum r2score corresponding to the random_state

# %%
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,df_x,y)
#calling the function using lassoRegression
# Out:
# r2score corresponing to 42 is: 0.7842174498334199
# r2score corresponing to 43 is: 0.8561240837210332
# r2score corresponing to 44 is: 0.8220956008133878
# r2score corresponing to 45 is: 0.8091925331250628
# r2score corresponing to 46 is: 0.8311525571468354
# r2score corresponing to 47 is: 0.8499691632747856
# r2score corresponing to 48 is: 0.8844078212639079
# r2score corresponing to 49 is: 0.7772585673021447
# r2score corresponing to 50 is: 0.8479416430503856
# r2score corresponing to 51 is: 0.8571057730136356
# r2score corresponing to 52 is: 0.8602886544379462
# r2score corresponing to 53 is: 0.7417388325666814
# r2score corresponing to 54 is: 0.8547013519043103
# r2score corresponing to 55 is: 0.8106573449931624
# r2score corresponing to 56 is: 0.8113480136879678
# r2score corresponing to 57 is: 0.71644933738454
# r2score corresponing to 58 is: 0.7769035843921311
# r2score corresponing to 59 is: 0.7787653644596316
# r2score corresponing to 60 is: 0.8671655833815176
# r2score corresponing to 61 is: 0.8328840194092313
# r2score corresponing to 62 is: 0.8134671149873342
# r2score corresponing to 63 is: 0.8153052518137773
# r2score corresponing to 64 is: 0.6925393850724727
# r2score corresponing to 65 is: 0.7632769260797357
# r2score corresponing to 66 is: 0.7058073283589632
# r2score corresponing to 67 is: 0.8124440333363375
# r2score corresponing to 68 is: 0.8282647348122059
# r2score corresponing to 69 is: 0.8254625172417211
# r2score corresponing to 70 is: 0.7694875758717468
# r2score corresponing to 71 is: 0.7861932382056025
# r2score corresponing to 72 is: 0.8147352673518018
# r2score corresponing to 73 is: 0.791966015826339
# r2score corresponing to 74 is: 0.7379043825257318
# r2score corresponing to 75 is: 0.8616933306290779
# r2score corresponing to 76 is: 0.8606454106627869
# r2score corresponing to 77 is: 0.829536898228055
# r2score corresponing to 78 is: 0.7864917264121098
# r2score corresponing to 79 is: 0.8176193276721087
# r2score corresponing to 80 is: 0.6891433312682461
# r2score corresponing to 81 is: 0.7869554098541696
# r2score corresponing to 82 is: 0.8492614620571851
# r2score corresponing to 83 is: 0.728269658759324
# r2score corresponing to 84 is: 0.8100765635810333
# r2score corresponing to 85 is: 0.8765261163646089
# r2score corresponing to 86 is: 0.9033487123177208
# r2score corresponing to 87 is: 0.7347713946207869
# r2score corresponing to 88 is: 0.9068259465561186
# r2score corresponing to 89 is: 0.8189063468861132
# r2score corresponing to 90 is: 0.855753065532611
# r2score corresponing to 91 is: 0.8599579552255382
# r2score corresponing to 92 is: 0.8047650994201695
# r2score corresponing to 93 is: 0.8166593075749964
# r2score corresponing to 94 is: 0.7760888406826709
# r2score corresponing to 95 is: 0.7589848897902896
# r2score corresponing to 96 is: 0.7425032636772049
# r2score corresponing to 97 is: 0.8242837754070034
# r2score corresponing to 98 is: 0.7036838448128226
# r2score corresponing to 99 is: 0.834246116232167
# r2score corresponing to 100 is: 0.7691272371689731
#
#
# max r2_score corresponding to  88 is 0.9068259465561186

# %%
Lsreg_score_mean=cross_val_score(lsreg,df_x,y,cv=5,scoring="r2").mean()
Lsreg_score_std=cross_val_score(lsreg,df_x,y,cv=5,scoring="r2").std()
print("mean r2score for Lasso:",Lsreg_score_mean)
print("standard deviation in r2score for lasso:",Lsreg_score_std)
#cross validation to check bias-variance tradeoff using cross_val_score
# Out:
# mean r2score for Lasso: -1.342065551459472
# standard deviation in r2score for lasso: 2.544042393170182

# %%
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(df_x,y)
clf.best_params_
#using GridSearchCV finding the best parameter
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
def maxr2_score(gbr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        gbr=GradientBoostingRegressor(learning_rate=0.1, n_estimators=100)
        gbr.fit(x_train,y_train)
        y_predict=gbr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#creating a function to find the maximum r2score corresponding to the random_state

# %%
gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=100)
r_state=maxr2_score(gbr,df_x,y)
#calling the function using GradientBoostRegressor
# Out:
# r2score corresponing to 42 is: 0.8404529754780197
# r2score corresponing to 43 is: 0.8988679078995918
# r2score corresponing to 44 is: 0.8645152847264007
# r2score corresponing to 45 is: 0.8394066851317163
# r2score corresponing to 46 is: 0.8988185843138641
# r2score corresponing to 47 is: 0.8660815408282505
# r2score corresponing to 48 is: 0.8224048015674051
# r2score corresponing to 49 is: 0.8629004006850313
# r2score corresponing to 50 is: 0.9014992901204091
# r2score corresponing to 51 is: 0.8619770665792978
# r2score corresponing to 52 is: 0.9260177431608176
# r2score corresponing to 53 is: 0.8199126126026521
# r2score corresponing to 54 is: 0.8586396719675506
# r2score corresponing to 55 is: 0.8689096155588591
# r2score corresponing to 56 is: 0.8400491757601142
# r2score corresponing to 57 is: 0.823470142886802
# r2score corresponing to 58 is: 0.8697412698633442
# r2score corresponing to 59 is: 0.8757793531911816
# r2score corresponing to 60 is: 0.8642747044074818
# r2score corresponing to 61 is: 0.8827380945319965
# r2score corresponing to 62 is: 0.8781143309143113
# r2score corresponing to 63 is: 0.8555021375089348
# r2score corresponing to 64 is: 0.8599191845110571
# r2score corresponing to 65 is: 0.8612880790523976
# r2score corresponing to 66 is: 0.8294864710413905
# r2score corresponing to 67 is: 0.8915822279063317
# r2score corresponing to 68 is: 0.8684286905722837
# r2score corresponing to 69 is: 0.903420503130925
# r2score corresponing to 70 is: 0.8647862631841062
# r2score corresponing to 71 is: 0.8921073696528031
# r2score corresponing to 72 is: 0.8387443017290694
# r2score corresponing to 73 is: 0.8763670217162959
# r2score corresponing to 74 is: 0.8271507312390597
# r2score corresponing to 75 is: 0.8325132254726961
# r2score corresponing to 76 is: 0.8834331423576658
# r2score corresponing to 77 is: 0.899485024240573
# r2score corresponing to 78 is: 0.8750146841256934
# r2score corresponing to 79 is: 0.8761259933596509
# r2score corresponing to 80 is: 0.8308281444514933
# r2score corresponing to 81 is: 0.8676804049132596
# r2score corresponing to 82 is: 0.870298122999823
# r2score corresponing to 83 is: 0.8471715357372696
# r2score corresponing to 84 is: 0.8960522039662686
# r2score corresponing to 85 is: 0.8452842191614
# r2score corresponing to 86 is: 0.8986378661689522
# r2score corresponing to 87 is: 0.8267128093744174
# r2score corresponing to 88 is: 0.916367011771654
# r2score corresponing to 89 is: 0.8537408463417668
# r2score corresponing to 90 is: 0.9191496164199628
# r2score corresponing to 91 is: 0.9082677630497947
# r2score corresponing to 92 is: 0.8693177538933003
# r2score corresponing to 93 is: 0.8652656478518788
# r2score corresponing to 94 is: 0.8689131093526773
# r2score corresponing to 95 is: 0.8731197135459405
# r2score corresponing to 96 is: 0.8233765755928669
# r2score corresponing to 97 is: 0.8575990725364452
# r2score corresponing to 98 is: 0.8231750638039061
# r2score corresponing to 99 is: 0.8911672128307411
# r2score corresponing to 100 is: 0.8460243274218503
#
#
# max r2_score corresponding to  52 is 0.9260177431608176

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[regr,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(df_x,y)
clf.best_params_
#using GridSearchCV to find the best parameter for hyperparameter tuning
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#  'learning_rate': 0.1,
#  'n_estimators': 10}

# %%
def maxr2_score(ada_reg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
                       max_leaf_nodes=None, min_impurity_decrease=0.0,
                       min_impurity_split=None, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       presort=False, random_state=None, splitter='best'),
 learning_rate= 0.1,
 n_estimators= 10)
        ada_reg.fit(x_train,y_train)
        y_predict=ada_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#creating a function to find the maximum r2score corresponding to the random_state

# %%
ada_reg=AdaBoostRegressor(learning_rate=0.01,n_estimators=10,base_estimator=DecisionTreeRegressor())
r_state=maxr2_score(ada_reg,df_x,y)
#calling the function using AdaBoostRegressor
# Out:
# r2score corresponing to 42 is: 0.8046625234834476
# r2score corresponing to 43 is: 0.9241040764984227
# r2score corresponing to 44 is: 0.856518858119037
# r2score corresponing to 45 is: 0.8056008044134134
# r2score corresponing to 46 is: 0.9025046875695014
# r2score corresponing to 47 is: 0.8396122834373334
# r2score corresponing to 48 is: 0.8156149263944921
# r2score corresponing to 49 is: 0.8817417253390154
# r2score corresponing to 50 is: 0.8946344573182778
# r2score corresponing to 51 is: 0.9022153202898969
# r2score corresponing to 52 is: 0.8923495074136552
# r2score corresponing to 53 is: 0.7159971968140182
# r2score corresponing to 54 is: 0.8446400519177913
# r2score corresponing to 55 is: 0.7856422440067823
# r2score corresponing to 56 is: 0.8472317473746337
# r2score corresponing to 57 is: 0.8336556021719636
# r2score corresponing to 58 is: 0.861899841922523
# r2score corresponing to 59 is: 0.8746353406962571
# r2score corresponing to 60 is: 0.8481370015112785
# r2score corresponing to 61 is: 0.8253941964278435
# r2score corresponing to 62 is: 0.8517965923459936
# r2score corresponing to 63 is: 0.7544528354509604
# r2score corresponing to 64 is: 0.8694846997327056
# r2score corresponing to 65 is: 0.8474441697960102
# r2score corresponing to 66 is: 0.7907451974602464
# r2score corresponing to 67 is: 0.8948783322137988
# r2score corresponing to 68 is: 0.8222306122004882
# r2score corresponing to 69 is: 0.8622463856142332
# r2score corresponing to 70 is: 0.8718194371406497
# r2score corresponing to 71 is: 0.9103319406622274
# r2score corresponing to 72 is: 0.8764600796009987
# r2score corresponing to 73 is: 0.8852946635615379
# r2score corresponing to 74 is: 0.7992917251784212
# r2score corresponing to 75 is: 0.8119585835754555
# r2score corresponing to 76 is: 0.8938995335928209
# r2score corresponing to 77 is: 0.8698890430096767
# r2score corresponing to 78 is: 0.8650181930568343
# r2score corresponing to 79 is: 0.8777436743956646
# r2score corresponing to 80 is: 0.802037316869574
# r2score corresponing to 81 is: 0.8407468591548448
# r2score corresponing to 82 is: 0.8135759748173568
# r2score corresponing to 83 is: 0.8668787742927782
# r2score corresponing to 84 is: 0.871242349327952
# r2score corresponing to 85 is: 0.7789361882361006
# r2score corresponing to 86 is: 0.8869983592477646
# r2score corresponing to 87 is: 0.8339306924501675
# r2score corresponing to 88 is: 0.931298982610684
# r2score corresponing to 89 is: 0.8594025033032193
# r2score corresponing to 90 is: 0.9350950452345501
# r2score corresponing to 91 is: 0.897747803047602
# r2score corresponing to 92 is: 0.8715706068061693
# r2score corresponing to 93 is: 0.8376955058506478
# r2score corresponing to 94 is: 0.7781905637581024
# r2score corresponing to 95 is: 0.8609981442521272
# r2score corresponing to 96 is: 0.7780550089841625
# r2score corresponing to 97 is: 0.8560985055226238
# r2score corresponing to 98 is: 0.810802169610269
# r2score corresponing to 99 is: 0.905033949366014
# r2score corresponing to 100 is: 0.8420989394845003
#
#
# max r2_score corresponding to  90 is 0.9350950452345501

# %%
print("mean r2score for AdaBoostRegressor:",cross_val_score(ada_reg,df_x,y,cv=5,scoring="r2").mean())
print("standard deviationof  r2score for AdaBoostRegressor:",cross_val_score(ada_reg,df_x,y,cv=5,scoring="r2").std())
#cross validation for bias-tradeoff using cross-val-score
# Out:
# mean r2score for AdaBoostRegressor: -0.8926740519905165
# standard deviationof  r2score for AdaBoostRegressor: 1.4697412515568942

# %%
x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=90,test_size=0.20)
ada_reg.fit(x_train,y_train)
y_predict=ada_reg.predict(x_test)

# %% [markdown]
# # # since AdaBoostRegressor gives the best r2score of 0.9350 corresponding to random_state 90 so with the change in random state and fitting the traing data using AdaBoostRegressor and usnig Predict function on the testing data

# %%
print("r2score is",r2_score(y_test,y_predict))
print("root mean squarred error is",np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# r2score is 0.8544620468510624
# root mean squarred error is 115.15093062308192

# %% [markdown]
# # # using joblib to dump the file using AdaBoostRegressor as my selected algorithm as it also takes care of overfitting or underfitting problem

# %%
from sklearn.externals import joblib
joblib.dump(gbr,"gbr_bikes.pkl")
