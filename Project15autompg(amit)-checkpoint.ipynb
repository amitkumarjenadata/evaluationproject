# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
auto=pd.read_csv('autompg.csv',delim_whitespace=True,names=['mpg','cylinders','displacement','horsepower','weight',
                                              'acceleration','model year','origin','car name'])
auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0        8.0         307.0       130.0  3504.0          12.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5
# 2    18.0        8.0         318.0       150.0  3436.0          11.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5
# 5    15.0        8.0         429.0       198.0  4341.0          10.0
# 6    14.0        8.0         454.0       220.0  4354.0           9.0
# 7    14.0        8.0         440.0       215.0  4312.0           8.5
# 8    14.0        8.0         455.0       225.0  4425.0          10.0
# 9    15.0        8.0         390.0       190.0  3850.0           8.5
# 10    NaN        4.0         133.0       115.0  3090.0          17.5
# 11    NaN        8.0         350.0       165.0  4142.0          11.5
# 12    NaN        8.0         351.0       153.0  4034.0          11.0
# 13    NaN        8.0         383.0       175.0  4166.0          10.5
# 14    NaN        8.0         360.0       175.0  3850.0          11.0
# 15   15.0        8.0         383.0       170.0  3563.0          10.0
# 16   14.0        8.0         340.0       160.0  3609.0           8.0
# 17    NaN        8.0         302.0       140.0  3353.0           8.0
# 18   15.0        8.0         400.0       150.0  3761.0           9.5
# 19   14.0        8.0         455.0       225.0  3086.0          10.0
# 20   24.0        4.0         113.0        95.0  2372.0          15.0
# 21   22.0        6.0         198.0        95.0  2833.0          15.5
# 22   18.0        6.0         199.0        97.0  2774.0          15.5
# 23   21.0        6.0         200.0        85.0  2587.0          16.0
# 24   27.0        4.0          97.0        88.0  2130.0          14.5
# 25   26.0        4.0          97.0        46.0  1835.0          20.5
# 26   25.0        4.0         110.0        87.0  2672.0          17.5
# 27   24.0        4.0         107.0        90.0  2430.0          14.5
# 28   25.0        4.0         104.0        95.0  2375.0          17.5
# 29   26.0        4.0         121.0       113.0  2234.0          12.5
# ..    ...        ...           ...         ...     ...           ...
# 376  27.0        4.0         112.0        88.0  2640.0          18.6
# 377  34.0        4.0         112.0        88.0  2395.0          18.0
# 378  31.0        4.0         112.0        85.0  2575.0          16.2
# 379  29.0        4.0         135.0        84.0  2525.0          16.0
# 380  27.0        4.0         151.0        90.0  2735.0          18.0
# 381  24.0        4.0         140.0        92.0  2865.0          16.4
# 382  23.0        4.0         151.0         NaN  3035.0          20.5
# 383  36.0        4.0         105.0        74.0  1980.0          15.3
# 384  37.0        4.0          91.0        68.0  2025.0          18.2
# 385  31.0        4.0          91.0        68.0  1970.0          17.6
# 386  38.0        4.0         105.0        63.0  2125.0          14.7
# 387  36.0        4.0          98.0        70.0  2125.0          17.3
# 388  36.0        4.0         120.0        88.0  2160.0          14.5
# 389  36.0        4.0         107.0        75.0  2205.0          14.5
# 390  34.0        4.0         108.0        70.0  2245.0          16.9
# 391  38.0        4.0          91.0        67.0  1965.0          15.0
# 392  32.0        4.0          91.0        67.0  1965.0          15.7
# 393  38.0        4.0          91.0        67.0  1995.0          16.2
# 394  25.0        6.0         181.0       110.0  2945.0          16.4
# 395  38.0        6.0         262.0        85.0  3015.0          17.0
# 396  26.0        4.0         156.0        92.0  2585.0          14.5
# 397  22.0        6.0         232.0       112.0  2835.0          14.7
# 398  32.0        4.0         144.0        96.0  2665.0          13.9
# 399  36.0        4.0         135.0        84.0  2370.0          13.0
# 400  27.0        4.0         151.0        90.0  2950.0          17.3
# 401  27.0        4.0         140.0        86.0  2790.0          15.6
# 402  44.0        4.0          97.0        52.0  2130.0          24.6
# 403  32.0        4.0         135.0        84.0  2295.0          11.6
# 404  28.0        4.0         120.0        79.0  2625.0          18.6
# 405  31.0        4.0         119.0        82.0  2720.0          19.4
#
#      model year  origin                           car name
# 0          70.0     1.0          chevrolet chevelle malibu
# 1          70.0     1.0                  buick skylark 320
# 2          70.0     1.0                 plymouth satellite
# 3          70.0     1.0                      amc rebel sst
# 4          70.0     1.0                        ford torino
# 5          70.0     1.0                   ford galaxie 500
# 6          70.0     1.0                   chevrolet impala
# 7          70.0     1.0                  plymouth fury iii
# 8          70.0     1.0                   pontiac catalina
# 9          70.0     1.0                 amc ambassador dpl
# 10         70.0     2.0               citroen ds-21 pallas
# 11         70.0     1.0   chevrolet chevelle concours (sw)
# 12         70.0     1.0                   ford torino (sw)
# 13         70.0     1.0            plymouth satellite (sw)
# 14         70.0     1.0                 amc rebel sst (sw)
# 15         70.0     1.0                dodge challenger se
# 16         70.0     1.0                 plymouth 'cuda 340
# 17         70.0     1.0              ford mustang boss 302
# 18         70.0     1.0              chevrolet monte carlo
# 19         70.0     1.0            buick estate wagon (sw)
# 20         70.0     3.0              toyota corona mark ii
# 21         70.0     1.0                    plymouth duster
# 22         70.0     1.0                         amc hornet
# 23         70.0     1.0                      ford maverick
# 24         70.0     3.0                       datsun pl510
# 25         70.0     2.0       volkswagen 1131 deluxe sedan
# 26         70.0     2.0                        peugeot 504
# 27         70.0     2.0                        audi 100 ls
# 28         70.0     2.0                           saab 99e
# 29         70.0     2.0                           bmw 2002
# ..          ...     ...                                ...
# 376        82.0     1.0           chevrolet cavalier wagon
# 377        82.0     1.0          chevrolet cavalier 2-door
# 378        82.0     1.0         pontiac j2000 se hatchback
# 379        82.0     1.0                     dodge aries se
# 380        82.0     1.0                    pontiac phoenix
# 381        82.0     1.0               ford fairmont futura
# 382        82.0     1.0                     amc concord dl
# 383        82.0     2.0                volkswagen rabbit l
# 384        82.0     3.0                 mazda glc custom l
# 385        82.0     3.0                   mazda glc custom
# 386        82.0     1.0             plymouth horizon miser
# 387        82.0     1.0                     mercury lynx l
# 388        82.0     3.0                   nissan stanza xe
# 389        82.0     3.0                       honda accord
# 390        82.0     3.0                     toyota corolla
# 391        82.0     3.0                        honda civic
# 392        82.0     3.0                 honda civic (auto)
# 393        82.0     3.0                      datsun 310 gx
# 394        82.0     1.0              buick century limited
# 395        82.0     1.0  oldsmobile cutlass ciera (diesel)
# 396        82.0     1.0         chrysler lebaron medallion
# 397        82.0     1.0                     ford granada l
# 398        82.0     3.0                   toyota celica gt
# 399        82.0     1.0                  dodge charger 2.2
# 400        82.0     1.0                   chevrolet camaro
# 401        82.0     1.0                    ford mustang gl
# 402        82.0     2.0                          vw pickup
# 403        82.0     1.0                      dodge rampage
# 404        82.0     1.0                        ford ranger
# 405        82.0     1.0                         chevy s-10
#
# [406 rows x 9 columns]

# %%
auto.shape
# Out:
# (406, 9)

# %%
#check the datatypes
auto.dtypes
# Out:
# mpg             float64
# cylinders       float64
# displacement    float64
# horsepower      float64
# weight          float64
# acceleration    float64
# model year      float64
# origin          float64
# car name         object
# dtype: object

# %%
#checking information
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       406 non-null float64
# displacement    406 non-null float64
# horsepower      400 non-null float64
# weight          406 non-null float64
# acceleration    406 non-null float64
# model year      406 non-null float64
# origin          406 non-null float64
# car name        406 non-null object
# dtypes: float64(8), object(1)
# memory usage: 28.6+ KB

# %%
#check all the columns
auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
#Using label encoder to convert into numerical data

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
auto['car name']=le.fit_transform(auto['car name'].astype(str))

# %%
#show the first five data
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0        8.0         307.0       130.0  3504.0          12.0
# 1  15.0        8.0         350.0       165.0  3693.0          11.5
# 2  18.0        8.0         318.0       150.0  3436.0          11.0
# 3  16.0        8.0         304.0       150.0  3433.0          12.0
# 4  17.0        8.0         302.0       140.0  3449.0          10.5
#
#    model year  origin  car name
# 0        70.0     1.0        50
# 1        70.0     1.0        37
# 2        70.0     1.0       235
# 3        70.0     1.0        14
# 4        70.0     1.0       164

# %%
#find statistical information
auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  406.000000    406.000000  400.000000   406.000000
# mean    23.514573    5.475369    194.779557  105.082500  2979.413793
# std      7.815984    1.712160    104.922458   38.768779   847.004328
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    105.000000   75.750000  2226.500000
# 50%     23.000000    4.000000    151.000000   95.000000  2822.500000
# 75%     29.000000    8.000000    302.000000  130.000000  3618.250000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin    car name
# count    406.000000  406.000000  406.000000  406.000000
# mean      15.519704   75.921182    1.568966  151.679803
# std        2.803359    3.748737    0.797479   91.537112
# min        8.000000   70.000000    1.000000    0.000000
# 25%       13.700000   73.000000    1.000000   66.250000
# 50%       15.500000   76.000000    1.000000  152.000000
# 75%       17.175000   79.000000    2.000000  230.750000
# max       24.800000   82.000000    3.000000  311.000000

# %%
#checking whether there is a null value or not?
auto.isnull().sum()
# Out:
# mpg             8
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
#drop some nan value
auto.dropna(inplace=True)

# %%
#checking null values with visualization
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(auto.isnull())

# %%
#visualization with distribution plot for specic columns
import warnings 
warnings.filterwarnings('ignore')
sns.distplot(auto["mpg"])

# %%
sns.distplot(auto["cylinders"])

# %%
#distribution plot for displacement:
sns.distplot(auto["displacement"])

# %%
#distribution plot for horsepower:
sns.distplot(auto["horsepower"])

# %%
#distribution plot for weight:
sns.distplot(auto["weight"])

# %%
#distribution plot for acceleration:
sns.distplot(auto["acceleration"])

# %%
#visualization by using pairplot
sns.pairplot(auto)

# %%
#visualization by using scatterplot
auto.plot.scatter(x='displacement',y='mpg')

# %%
#scatter plot of horsepower vs mpg
auto.plot.scatter(x='horsepower',y='mpg')

# %%
#visualization with boxplot where we can find wheather any outliers present or not
auto.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False,figsize=(10,10))
plt.tight_layout()

# %%
#find the correlation matrix
auto.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
# car name      0.268281  -0.278486     -0.292287   -0.235594 -0.252545
#
#               acceleration  model year    origin  car name
# mpg               0.423329    0.580541  0.565209  0.268281
# cylinders        -0.504683   -0.345647 -0.568932 -0.278486
# displacement     -0.543800   -0.369855 -0.614535 -0.292287
# horsepower       -0.689196   -0.416361 -0.455171 -0.235594
# weight           -0.416839   -0.309120 -0.585005 -0.252545
# acceleration      1.000000    0.290316  0.212746  0.135557
# model year        0.290316    1.000000  0.181528  0.076170
# origin            0.212746    0.181528  1.000000  0.360380
# car name          0.135557    0.076170  0.360380  1.000000

# %%
#find the correlation matrix with visualization
sns.heatmap(auto.corr(),annot=True)

# %%
#checking for skewness
auto.skew()
# Out:
# mpg             0.457092
# cylinders       0.508109
# displacement    0.701669
# horsepower      1.087326
# weight          0.519586
# acceleration    0.291587
# model year      0.019688
# origin          0.915185
# car name        0.034112
# dtype: float64

# %%
#removing skewness
import numpy as np
for col in auto.columns:
    if auto.skew().loc[col]>0.55:
        auto[col]=np.log1p(auto[col])

# %%
#again checking for skewness
auto.skew()
# Out:
# mpg             0.457092
# cylinders       0.508109
# displacement    0.214231
# horsepower      0.377557
# weight          0.519586
# acceleration    0.291587
# model year      0.019688
# origin          0.790401
# car name        0.034112
# dtype: float64

# %%
#removing outliers
from scipy.stats import zscore
z_score=abs(zscore(auto))
print(auto.shape)
auto_data=auto.loc[(z_score<3).all(axis=1)]
print(auto_data.shape)
# Out:
# (392, 9)
# (390, 9)

# %%
#let separate input and output variables to be used for the problem
x=pd.DataFrame(auto_data.drop(columns=['mpg']))
x=pd.DataFrame(auto_data.iloc[:,1:9])
y=pd.DataFrame(auto_data['mpg'])

# %%
#check the first five output data
y.head()
# Out:
#     mpg
# 0  18.0
# 1  15.0
# 2  18.0
# 3  16.0
# 4  17.0

# %%
#Using standardscaler tecnique for scaling the data

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# In this dataset we have to use Regression Algorithm

# %%
#Using Linear Regression:

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_predict=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
regr=linear_model.LinearRegression()
r_state=maxr2_score(regr,x,y)
# Out:
# r2score corresponing to 42 is: 0.8153733652444787
# r2score corresponing to 43 is: 0.8568595749585686
# r2score corresponing to 44 is: 0.8517856968558027
# r2score corresponing to 45 is: 0.8656092389965158
# r2score corresponing to 46 is: 0.8474336616317916
# r2score corresponing to 47 is: 0.8170153596072635
# r2score corresponing to 48 is: 0.7971852225548925
# r2score corresponing to 49 is: 0.7956411306187362
# r2score corresponing to 50 is: 0.8557358586950867
# r2score corresponing to 51 is: 0.7859912171113719
# r2score corresponing to 52 is: 0.854191022102559
# r2score corresponing to 53 is: 0.8383625370222823
# r2score corresponing to 54 is: 0.8268892538112589
# r2score corresponing to 55 is: 0.8194063039942366
# r2score corresponing to 56 is: 0.8196261393513082
# r2score corresponing to 57 is: 0.7838815874630296
# r2score corresponing to 58 is: 0.8188804703991213
# r2score corresponing to 59 is: 0.8614023150024428
# r2score corresponing to 60 is: 0.8375873551450296
# r2score corresponing to 61 is: 0.8635064299424848
# r2score corresponing to 62 is: 0.8521318684811987
# r2score corresponing to 63 is: 0.8047295671322383
# r2score corresponing to 64 is: 0.8103359949901299
# r2score corresponing to 65 is: 0.8415554914458228
# r2score corresponing to 66 is: 0.8432755774270614
# r2score corresponing to 67 is: 0.786434290169432
# r2score corresponing to 68 is: 0.7942174518992584
# r2score corresponing to 69 is: 0.8142101656995119
# r2score corresponing to 70 is: 0.768042677453589
# r2score corresponing to 71 is: 0.8179581142838899
# r2score corresponing to 72 is: 0.869918493245259
# r2score corresponing to 73 is: 0.8661054577059174
# r2score corresponing to 74 is: 0.8304987341680237
# r2score corresponing to 75 is: 0.7838246617565602
# r2score corresponing to 76 is: 0.7794793219177629
# r2score corresponing to 77 is: 0.7996393478429475
# r2score corresponing to 78 is: 0.7377411582502901
# r2score corresponing to 79 is: 0.7859981210666747
# r2score corresponing to 80 is: 0.8604169296275995
# r2score corresponing to 81 is: 0.8038878005717929
# r2score corresponing to 82 is: 0.8652863659539407
# r2score corresponing to 83 is: 0.8192206822536425
# r2score corresponing to 84 is: 0.8129982799451858
# r2score corresponing to 85 is: 0.8310516340757212
# r2score corresponing to 86 is: 0.8214175298053732
# r2score corresponing to 87 is: 0.8813807155067592
# r2score corresponing to 88 is: 0.8281081849837815
# r2score corresponing to 89 is: 0.8208786717921296
# r2score corresponing to 90 is: 0.8575492042378907
# r2score corresponing to 91 is: 0.8096509196691397
# r2score corresponing to 92 is: 0.800170353833277
# r2score corresponing to 93 is: 0.867488555580116
# r2score corresponing to 94 is: 0.8176404913220792
# r2score corresponing to 95 is: 0.7962007813983053
# r2score corresponing to 96 is: 0.8474084582381884
# r2score corresponing to 97 is: 0.8640544654753824
# r2score corresponing to 98 is: 0.8331758948937256
# r2score corresponing to 99 is: 0.8443223564478493
# r2score corresponing to 100 is: 0.7783136814588683
#
#
# max r2_score corresponding to  87 is 0.8813807155067592

# %%
#Using GridSearchCV for finding best parameters
from sklearn.model_selection import GridSearchCV

# %%
#Using KNR:
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,25)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 6}

# %%
def maxr2_score(knr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        knr=KNeighborsRegressor(n_neighbors=6)
        knr.fit(x_train,y_train)
        y_predict=knr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
knr=KNeighborsRegressor(n_neighbors=6)
r_state=maxr2_score(knr,x,y)
# Out:
# r2score corresponing to 42 is: 0.869531013227782
# r2score corresponing to 43 is: 0.8462267353305044
# r2score corresponing to 44 is: 0.8654673233686071
# r2score corresponing to 45 is: 0.8777667392074446
# r2score corresponing to 46 is: 0.8864500732105414
# r2score corresponing to 47 is: 0.8317179051486387
# r2score corresponing to 48 is: 0.809861051884802
# r2score corresponing to 49 is: 0.8195866761059931
# r2score corresponing to 50 is: 0.9033696062910477
# r2score corresponing to 51 is: 0.8007345286513029
# r2score corresponing to 52 is: 0.8488403833823115
# r2score corresponing to 53 is: 0.8845113611317952
# r2score corresponing to 54 is: 0.8096680771727643
# r2score corresponing to 55 is: 0.8648012528004916
# r2score corresponing to 56 is: 0.8271729312826845
# r2score corresponing to 57 is: 0.8407885660785036
# r2score corresponing to 58 is: 0.8324253844793372
# r2score corresponing to 59 is: 0.899604755241443
# r2score corresponing to 60 is: 0.8291536278701879
# r2score corresponing to 61 is: 0.8733665542648646
# r2score corresponing to 62 is: 0.86355775585389
# r2score corresponing to 63 is: 0.8628139934121652
# r2score corresponing to 64 is: 0.8679431453753235
# r2score corresponing to 65 is: 0.8402371651740694
# r2score corresponing to 66 is: 0.8619902148182155
# r2score corresponing to 67 is: 0.8350532153194984
# r2score corresponing to 68 is: 0.8746919424626509
# r2score corresponing to 69 is: 0.8418446434208097
# r2score corresponing to 70 is: 0.8239784770396139
# r2score corresponing to 71 is: 0.8642729715116771
# r2score corresponing to 72 is: 0.8972268913449265
# r2score corresponing to 73 is: 0.900656232844944
# r2score corresponing to 74 is: 0.8850133162826508
# r2score corresponing to 75 is: 0.8286653828339768
# r2score corresponing to 76 is: 0.822065007722289
# r2score corresponing to 77 is: 0.8344388647580078
# r2score corresponing to 78 is: 0.7665431399910483
# r2score corresponing to 79 is: 0.8322807432873897
# r2score corresponing to 80 is: 0.9228122132000961
# r2score corresponing to 81 is: 0.834597301656292
# r2score corresponing to 82 is: 0.9128907339706003
# r2score corresponing to 83 is: 0.8010915271126773
# r2score corresponing to 84 is: 0.8476897445675113
# r2score corresponing to 85 is: 0.8670995485148005
# r2score corresponing to 86 is: 0.8500603242711873
# r2score corresponing to 87 is: 0.908066944083425
# r2score corresponing to 88 is: 0.8090747567976898
# r2score corresponing to 89 is: 0.8290109328020947
# r2score corresponing to 90 is: 0.8936503336012247
# r2score corresponing to 91 is: 0.7963325893408545
# r2score corresponing to 92 is: 0.830525774266498
# r2score corresponing to 93 is: 0.8743320624596749
# r2score corresponing to 94 is: 0.8680524578438884
# r2score corresponing to 95 is: 0.7691426541635971
# r2score corresponing to 96 is: 0.8716034807328332
# r2score corresponing to 97 is: 0.8522379921174916
# r2score corresponing to 98 is: 0.857257779357149
# r2score corresponing to 99 is: 0.8629677541294412
# r2score corresponing to 100 is: 0.8366684290964452
#
#
# max r2_score corresponding to  80 is 0.9228122132000961

# %%
#find best parameter for DCT:
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
grid_param={"random_state":range(0,20)}
Gdt=GridSearchCV(dtr,param_grid=grid_param,scoring='r2',cv=10)
Gdt.fit(x,y)
Gdt.best_params_
# Out:
# {'random_state': 19}

# %%
def maxr2_score(dtr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        dtr=DecisionTreeRegressor(random_state=19)
        dtr.fit(x_train,y_train)
        y_predict=dtr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
dtr=DecisionTreeRegressor(random_state=19)
r_state=maxr2_score(dtr,x,y)
# Out:
# r2score corresponing to 42 is: 0.7918264018287392
# r2score corresponing to 43 is: 0.7700615911460246
# r2score corresponing to 44 is: 0.6222708143290984
# r2score corresponing to 45 is: 0.7993505880995218
# r2score corresponing to 46 is: 0.7527074382324367
# r2score corresponing to 47 is: 0.7653518690402302
# r2score corresponing to 48 is: 0.6992973596877746
# r2score corresponing to 49 is: 0.6914452468799887
# r2score corresponing to 50 is: 0.8448757688464892
# r2score corresponing to 51 is: 0.7481427660122981
# r2score corresponing to 52 is: 0.7370832164981699
# r2score corresponing to 53 is: 0.8247432562477074
# r2score corresponing to 54 is: 0.7513666986267022
# r2score corresponing to 55 is: 0.8070841344082179
# r2score corresponing to 56 is: 0.722605056847771
# r2score corresponing to 57 is: 0.7947638184204056
# r2score corresponing to 58 is: 0.6788466022167288
# r2score corresponing to 59 is: 0.7229382378743041
# r2score corresponing to 60 is: 0.6551748719230497
# r2score corresponing to 61 is: 0.8167066046659756
# r2score corresponing to 62 is: 0.8250068751047844
# r2score corresponing to 63 is: 0.7889897999688483
# r2score corresponing to 64 is: 0.6883274521194045
# r2score corresponing to 65 is: 0.7594569809084477
# r2score corresponing to 66 is: 0.8044812995485311
# r2score corresponing to 67 is: 0.7993897163841658
# r2score corresponing to 68 is: 0.5280524619442977
# r2score corresponing to 69 is: 0.7587814202126745
# r2score corresponing to 70 is: 0.7633891528368716
# r2score corresponing to 71 is: 0.5598084604199765
# r2score corresponing to 72 is: 0.7476090098077347
# r2score corresponing to 73 is: 0.8271985426905877
# r2score corresponing to 74 is: 0.8126640043227491
# r2score corresponing to 75 is: 0.7681521932702502
# r2score corresponing to 76 is: 0.7086553662982428
# r2score corresponing to 77 is: 0.8096452605856845
# r2score corresponing to 78 is: 0.7610449961823017
# r2score corresponing to 79 is: 0.7688080792392776
# r2score corresponing to 80 is: 0.8006762166878156
# r2score corresponing to 81 is: 0.6757554287694105
# r2score corresponing to 82 is: 0.824095541839589
# r2score corresponing to 83 is: 0.7575470971216964
# r2score corresponing to 84 is: 0.758026032183292
# r2score corresponing to 85 is: 0.7533905927803691
# r2score corresponing to 86 is: 0.7918271130483923
# r2score corresponing to 87 is: 0.8377478976167163
# r2score corresponing to 88 is: 0.7320004402267244
# r2score corresponing to 89 is: 0.6868842035582614
# r2score corresponing to 90 is: 0.8031735380809979
# r2score corresponing to 91 is: 0.7975943561527222
# r2score corresponing to 92 is: 0.6460278609604291
# r2score corresponing to 93 is: 0.8298318757342865
# r2score corresponing to 94 is: 0.7245851552891842
# r2score corresponing to 95 is: 0.7672739148482672
# r2score corresponing to 96 is: 0.7563306195504043
# r2score corresponing to 97 is: 0.8060908404510942
# r2score corresponing to 98 is: 0.7889350557392862
# r2score corresponing to 99 is: 0.820594344267853
# r2score corresponing to 100 is: 0.807860832489491
#
#
# max r2_score corresponding to  50 is 0.8448757688464892

# %%
#find best parameter for SVR:
from sklearn.svm import SVR
sv=SVR()
parameters={"kernel":['linear','poly','rbf']}
clf=GridSearchCV(sv,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'kernel': 'rbf'}

# %%
def maxr2_score(sv,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        sv=SVR(kernel="rbf")
        sv.fit(x_train,y_train)
        y_predict=sv.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
sv=SVR(kernel="rbf")
r_state=maxr2_score(sv,x,y)
# Out:
# r2score corresponing to 42 is: 0.8566288236460435
# r2score corresponing to 43 is: 0.8506551866512178
# r2score corresponing to 44 is: 0.8292511492744774
# r2score corresponing to 45 is: 0.8847189377907199
# r2score corresponing to 46 is: 0.8890434124293114
# r2score corresponing to 47 is: 0.7872571207250185
# r2score corresponing to 48 is: 0.8137794156472877
# r2score corresponing to 49 is: 0.8174150976769226
# r2score corresponing to 50 is: 0.8737804811902598
# r2score corresponing to 51 is: 0.7821555822010055
# r2score corresponing to 52 is: 0.8342994166188848
# r2score corresponing to 53 is: 0.8017372692626763
# r2score corresponing to 54 is: 0.8177656678444214
# r2score corresponing to 55 is: 0.8585402181653927
# r2score corresponing to 56 is: 0.8052110185463313
# r2score corresponing to 57 is: 0.8103285428407092
# r2score corresponing to 58 is: 0.839165344573714
# r2score corresponing to 59 is: 0.894248535580786
# r2score corresponing to 60 is: 0.8299376600019315
# r2score corresponing to 61 is: 0.8265967235786059
# r2score corresponing to 62 is: 0.8417227914213462
# r2score corresponing to 63 is: 0.862984470981307
# r2score corresponing to 64 is: 0.8061194675296259
# r2score corresponing to 65 is: 0.8360709917118784
# r2score corresponing to 66 is: 0.8413643123361919
# r2score corresponing to 67 is: 0.8045244508189067
# r2score corresponing to 68 is: 0.8505188670610018
# r2score corresponing to 69 is: 0.8309370021832854
# r2score corresponing to 70 is: 0.8186462912426442
# r2score corresponing to 71 is: 0.7968464247675527
# r2score corresponing to 72 is: 0.8835595890595275
# r2score corresponing to 73 is: 0.8717961186847265
# r2score corresponing to 74 is: 0.8471338970820295
# r2score corresponing to 75 is: 0.7959154235394722
# r2score corresponing to 76 is: 0.7742428814037373
# r2score corresponing to 77 is: 0.8152800826089732
# r2score corresponing to 78 is: 0.7610176802765144
# r2score corresponing to 79 is: 0.8183937532728235
# r2score corresponing to 80 is: 0.8977786180406856
# r2score corresponing to 81 is: 0.8167870378229127
# r2score corresponing to 82 is: 0.8912802613007055
# r2score corresponing to 83 is: 0.8298951297818498
# r2score corresponing to 84 is: 0.8142669798328174
# r2score corresponing to 85 is: 0.8112079239106287
# r2score corresponing to 86 is: 0.7951741664692531
# r2score corresponing to 87 is: 0.8904941290162598
# r2score corresponing to 88 is: 0.8645020374654844
# r2score corresponing to 89 is: 0.7710219020455438
# r2score corresponing to 90 is: 0.8439598906369417
# r2score corresponing to 91 is: 0.7738541430777359
# r2score corresponing to 92 is: 0.8176724354948826
# r2score corresponing to 93 is: 0.8671509532457958
# r2score corresponing to 94 is: 0.8713677995978457
# r2score corresponing to 95 is: 0.7828992762585563
# r2score corresponing to 96 is: 0.8832297550191496
# r2score corresponing to 97 is: 0.8861751033017914
# r2score corresponing to 98 is: 0.8028694149395278
# r2score corresponing to 99 is: 0.84615117370418
# r2score corresponing to 100 is: 0.8113896006889832
#
#
# max r2_score corresponding to  80 is 0.8977786180406856

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
regr_score_mean=cross_val_score(regr,x,y,cv=5,scoring="r2").mean()
regr_score_std=cross_val_score(regr,x,y,cv=5,scoring="r2").std()
print("mean r2 score of linearRegression :",regr_score_mean)
print("stadard deviation for r2 score of linearRegression :",regr_score_std)
print('\n')
knr_score_mean=cross_val_score(knr,x,y,cv=5,scoring="r2").mean()
knr_score_std=cross_val_score(knr,x,y,cv=5,scoring="r2").std()
print("mean r2 score of knr:",knr_score_mean)
print("standard deviation of r2score for knr:",knr_score_std)
print('\n')
dtr_score_mean=cross_val_score(dtr,x,y,cv=5,scoring="r2").mean()
dtr_score_std=cross_val_score(dtr,x,y,cv=5,scoring="r2").std()
print("mean r2 score of DecisionTreeRegression :",dtr_score_mean)
print("stadard deviation for r2 score of DecisionTreeeRegression :",dtr_score_std)
print('\n')
sv_score_mean=cross_val_score(sv,x,y,cv=5,scoring="r2").mean()
sv_score_std=cross_val_score(sv,x,y,cv=5,scoring="r2").std()
print("mean r2 score of SVR :",sv_score_mean)
print("stadard deviation for r2 score of SVR :",sv_score_std)
# Out:
# mean r2 score of linearRegression : 0.6003323794186122
# stadard deviation for r2 score of linearRegression : 0.22077217308229916
#
#
# mean r2 score of knr: 0.692795801575171
# standard deviation of r2score for knr: 0.1908074109777689
#
#
# mean r2 score of DecisionTreeRegression : 0.5558995524874859
# stadard deviation for r2 score of DecisionTreeeRegression : 0.22399745564851045
#
#
# mean r2 score of SVR : 0.6187322582250631
# stadard deviation for r2 score of SVR : 0.4016072161416335

# %%
#best parameter for Ridge Operation:
from sklearn.linear_model import Ridge
r_reg=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(r_reg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
def maxr2_score(r_reg,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        r_reg=Ridge(alpha=1)
        r_reg.fit(x_train,y_train)
        y_predict=r_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
r_reg=Ridge(alpha=1)
r_state=maxr2_score(r_reg,x,y)
# Out:
# r2score corresponing to 42 is: 0.8154054663095747
# r2score corresponing to 43 is: 0.8572335649233358
# r2score corresponing to 44 is: 0.85216162692322
# r2score corresponing to 45 is: 0.8656627662662089
# r2score corresponing to 46 is: 0.8482807145164908
# r2score corresponing to 47 is: 0.8170751961791667
# r2score corresponing to 48 is: 0.7981724759809643
# r2score corresponing to 49 is: 0.7956200950622128
# r2score corresponing to 50 is: 0.8559437060615938
# r2score corresponing to 51 is: 0.7865311984425728
# r2score corresponing to 52 is: 0.8539715357830346
# r2score corresponing to 53 is: 0.8378260199552561
# r2score corresponing to 54 is: 0.827107438530424
# r2score corresponing to 55 is: 0.8203517088428971
# r2score corresponing to 56 is: 0.8195918586945905
# r2score corresponing to 57 is: 0.7846354422187867
# r2score corresponing to 58 is: 0.8190088474229685
# r2score corresponing to 59 is: 0.8623031814843896
# r2score corresponing to 60 is: 0.8375427044778627
# r2score corresponing to 61 is: 0.8629936447362281
# r2score corresponing to 62 is: 0.8520159286610907
# r2score corresponing to 63 is: 0.805541306487335
# r2score corresponing to 64 is: 0.8098729406711298
# r2score corresponing to 65 is: 0.8412511757291792
# r2score corresponing to 66 is: 0.8438936126302303
# r2score corresponing to 67 is: 0.7861504630431138
# r2score corresponing to 68 is: 0.7958779892851056
# r2score corresponing to 69 is: 0.8149050384297503
# r2score corresponing to 70 is: 0.768901490279078
# r2score corresponing to 71 is: 0.8178266404325729
# r2score corresponing to 72 is: 0.8702814488498145
# r2score corresponing to 73 is: 0.866296426347539
# r2score corresponing to 74 is: 0.830731592192962
# r2score corresponing to 75 is: 0.7833953303169101
# r2score corresponing to 76 is: 0.7789921542851055
# r2score corresponing to 77 is: 0.8000009146350726
# r2score corresponing to 78 is: 0.7385060535537691
# r2score corresponing to 79 is: 0.7863405937266403
# r2score corresponing to 80 is: 0.8612984355464729
# r2score corresponing to 81 is: 0.8035081362260577
# r2score corresponing to 82 is: 0.8657121698732352
# r2score corresponing to 83 is: 0.8193041286077687
# r2score corresponing to 84 is: 0.8132947154000403
# r2score corresponing to 85 is: 0.8307561260468046
# r2score corresponing to 86 is: 0.8211847164334974
# r2score corresponing to 87 is: 0.8829010525093137
# r2score corresponing to 88 is: 0.8288435807764656
# r2score corresponing to 89 is: 0.8204239370392251
# r2score corresponing to 90 is: 0.8574649399040086
# r2score corresponing to 91 is: 0.8095681186431424
# r2score corresponing to 92 is: 0.8015906152950334
# r2score corresponing to 93 is: 0.8675733239734131
# r2score corresponing to 94 is: 0.8190191932665565
# r2score corresponing to 95 is: 0.7959624017594387
# r2score corresponing to 96 is: 0.8478184613853776
# r2score corresponing to 97 is: 0.8641586439293067
# r2score corresponing to 98 is: 0.8336404189770964
# r2score corresponing to 99 is: 0.84422303430556
# r2score corresponing to 100 is: 0.7778927147660377
#
#
# max r2_score corresponding to  87 is 0.8829010525093137

# %%
r_reg_score_mean=cross_val_score(r_reg,x,y,cv=5,scoring="r2").mean()
r_reg_score_std=cross_val_score(r_reg,x,y,cv=5,scoring="r2").std()
print("mean r2score for RidgeRegression:",r_reg_score_mean)
print("standard deviation in r2score for RidgeRegression:",r_reg_score_std)
# Out:
# mean r2score for RidgeRegression: 0.6028186080205782
# standard deviation in r2score for RidgeRegression: 0.2195194330148966

# %%
#Parameters  for Lasso Operation
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.1}

# %%
def maxr2_score(lsreg,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        lsreg=Lasso(alpha=0.1)
        lsreg.fit(x_train,y_train)
        y_predict=lsreg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
lsreg=Lasso(alpha=0.1)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2score corresponing to 42 is: 0.8115485516027514
# r2score corresponing to 43 is: 0.8589296164781003
# r2score corresponing to 44 is: 0.8544404779673197
# r2score corresponing to 45 is: 0.8621165386756259
# r2score corresponing to 46 is: 0.852789834796563
# r2score corresponing to 47 is: 0.813888384044894
# r2score corresponing to 48 is: 0.7999676829295255
# r2score corresponing to 49 is: 0.793081784319678
# r2score corresponing to 50 is: 0.8535263941103407
# r2score corresponing to 51 is: 0.786668127178356
# r2score corresponing to 52 is: 0.8512823227344875
# r2score corresponing to 53 is: 0.827962137699273
# r2score corresponing to 54 is: 0.8218554436999056
# r2score corresponing to 55 is: 0.8265322339262489
# r2score corresponing to 56 is: 0.8150220556487046
# r2score corresponing to 57 is: 0.7868762631089848
# r2score corresponing to 58 is: 0.8168190873740746
# r2score corresponing to 59 is: 0.8658141358497375
# r2score corresponing to 60 is: 0.8310417458760619
# r2score corresponing to 61 is: 0.8540308370605912
# r2score corresponing to 62 is: 0.8466155084177833
# r2score corresponing to 63 is: 0.8032066558838116
# r2score corresponing to 64 is: 0.7986597736619847
# r2score corresponing to 65 is: 0.8297438443668802
# r2score corresponing to 66 is: 0.8451095334917691
# r2score corresponing to 67 is: 0.7756201736934267
# r2score corresponing to 68 is: 0.8019926115761165
# r2score corresponing to 69 is: 0.8186333455147135
# r2score corresponing to 70 is: 0.7719819744420838
# r2score corresponing to 71 is: 0.8156557665288986
# r2score corresponing to 72 is: 0.8660106622912587
# r2score corresponing to 73 is: 0.8644653188907175
# r2score corresponing to 74 is: 0.8290366396534309
# r2score corresponing to 75 is: 0.7751532212800942
# r2score corresponing to 76 is: 0.7702840741770742
# r2score corresponing to 77 is: 0.8019043794579181
# r2score corresponing to 78 is: 0.7377280107321591
# r2score corresponing to 79 is: 0.7844579193233749
# r2score corresponing to 80 is: 0.8648211770301366
# r2score corresponing to 81 is: 0.7966100121038513
# r2score corresponing to 82 is: 0.8615921052373129
# r2score corresponing to 83 is: 0.8158652456031313
# r2score corresponing to 84 is: 0.811649781097042
# r2score corresponing to 85 is: 0.8242344679867015
# r2score corresponing to 86 is: 0.816168343711972
# r2score corresponing to 87 is: 0.8885432610939199
# r2score corresponing to 88 is: 0.8296242947354522
# r2score corresponing to 89 is: 0.8073843657665396
# r2score corresponing to 90 is: 0.8507067035995
# r2score corresponing to 91 is: 0.8049974935632751
# r2score corresponing to 92 is: 0.8073171135602784
# r2score corresponing to 93 is: 0.8627872172813978
# r2score corresponing to 94 is: 0.8164021055360076
# r2score corresponing to 95 is: 0.7921204783970991
# r2score corresponing to 96 is: 0.8460735885697823
# r2score corresponing to 97 is: 0.8588131282038334
# r2score corresponing to 98 is: 0.8366421794254076
# r2score corresponing to 99 is: 0.8389099547844461
# r2score corresponing to 100 is: 0.7723675874353138
#
#
# max r2_score corresponding to  87 is 0.8885432610939199

# %%
Lsreg_score_mean=cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean()
Lsreg_score_std=cross_val_score(lsreg,x,y,cv=5,scoring="r2").std()
print("mean r2score for Lasso:",Lsreg_score_mean)
print("standard deviation in r2score for lasso:",Lsreg_score_std)
# Out:
# mean r2score for Lasso: 0.5981975445252715
# standard deviation in r2score for lasso: 0.23259570394770918

# %%
#Find best parameter for GradientBoosting:
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}

# %%
def maxr2_score(gbr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        gbr=GradientBoostingRegressor(learning_rate=0.01, n_estimators=1000)
        gbr.fit(x_train,y_train)
        y_predict=gbr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
gbr=GradientBoostingRegressor(learning_rate=0.01,n_estimators=1000)
r_state=maxr2_score(gbr,x,y)
# Out:
# r2score corresponing to 42 is: 0.8731740017824894
# r2score corresponing to 43 is: 0.8722526195659474
# r2score corresponing to 44 is: 0.9160744377948101
# r2score corresponing to 45 is: 0.9002411161428094
# r2score corresponing to 46 is: 0.8637567891378639
# r2score corresponing to 47 is: 0.831788084532489
# r2score corresponing to 48 is: 0.8473957296706578
# r2score corresponing to 49 is: 0.8136955088974227
# r2score corresponing to 50 is: 0.9367618358033982
# r2score corresponing to 51 is: 0.7868013509629536
# r2score corresponing to 52 is: 0.8914014253246532
# r2score corresponing to 53 is: 0.9017086723210409
# r2score corresponing to 54 is: 0.8470434009114897
# r2score corresponing to 55 is: 0.8855016273545766
# r2score corresponing to 56 is: 0.8353357652085034
# r2score corresponing to 57 is: 0.8502859342196678
# r2score corresponing to 58 is: 0.8656714700066499
# r2score corresponing to 59 is: 0.8709341404455845
# r2score corresponing to 60 is: 0.8258434218467785
# r2score corresponing to 61 is: 0.9148786183193496
# r2score corresponing to 62 is: 0.881951201094349
# r2score corresponing to 63 is: 0.8750477687452494
# r2score corresponing to 64 is: 0.8837663751893351
# r2score corresponing to 65 is: 0.8446046811189882
# r2score corresponing to 66 is: 0.8668049916572098
# r2score corresponing to 67 is: 0.8329614144049402
# r2score corresponing to 68 is: 0.824483402310105
# r2score corresponing to 69 is: 0.8971579153310945
# r2score corresponing to 70 is: 0.8532677819706503
# r2score corresponing to 71 is: 0.8086729239168089
# r2score corresponing to 72 is: 0.8893187235751447
# r2score corresponing to 73 is: 0.9251458416615079
# r2score corresponing to 74 is: 0.8595364448271031
# r2score corresponing to 75 is: 0.8830720005487496
# r2score corresponing to 76 is: 0.8492544520658479
# r2score corresponing to 77 is: 0.9111740014994556
# r2score corresponing to 78 is: 0.8414911720699205
# r2score corresponing to 79 is: 0.8264154109651454
# r2score corresponing to 80 is: 0.885051955197693
# r2score corresponing to 81 is: 0.8535496438434839
# r2score corresponing to 82 is: 0.9180865754056766
# r2score corresponing to 83 is: 0.8437857951661769
# r2score corresponing to 84 is: 0.8692148842235727
# r2score corresponing to 85 is: 0.8599947644177595
# r2score corresponing to 86 is: 0.8459775844857127
# r2score corresponing to 87 is: 0.9256407105873435
# r2score corresponing to 88 is: 0.8458270918537331
# r2score corresponing to 89 is: 0.842513086150466
# r2score corresponing to 90 is: 0.8765994335887604
# r2score corresponing to 91 is: 0.8342462652639293
# r2score corresponing to 92 is: 0.8136523236208062
# r2score corresponing to 93 is: 0.9277920902605441
# r2score corresponing to 94 is: 0.8584155000679492
# r2score corresponing to 95 is: 0.8530844801412756
# r2score corresponing to 96 is: 0.8922989729353193
# r2score corresponing to 97 is: 0.9044234979264533
# r2score corresponing to 98 is: 0.8793537291166397
# r2score corresponing to 99 is: 0.9003751109878708
# r2score corresponing to 100 is: 0.8561299824266352
#
#
# max r2_score corresponding to  50 is 0.9367618358033982

# %%
gbr_score_mean=cross_val_score(gbr,x,y,cv=5,scoring="r2").mean()
gbr_score_std=cross_val_score(gbr,x,y,cv=5,scoring="r2").std()
print("mean r2score for GradientBoostRegression:",gbr_score_mean)
print("standard deviation in r2score for GradientBoostRegression:",gbr_score_std)
# Out:
# mean r2score for GradientBoostRegression: 0.7780063891548666
# standard deviation in r2score for GradientBoostRegression: 0.16059739225336261

# %%
#Find best parameters for AdaBoostRegressor:
from sklearn.ensemble import AdaBoostRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[regr,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 500}

# %%
def maxr2_score(ada_reg,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
                       max_leaf_nodes=None, min_impurity_decrease=0.0,
                       min_impurity_split=None, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       presort=False, random_state=None, splitter='best'),
 learning_rate= 1,
 n_estimators=500)
        ada_reg.fit(x_train,y_train)
        y_predict=ada_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
                       max_leaf_nodes=None, min_impurity_decrease=0.0,
                       min_impurity_split=None, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       presort=False, random_state=None, splitter='best'),
 learning_rate= 1,
 n_estimators=500)
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2score corresponing to 42 is: 0.8491805983413345
# r2score corresponing to 43 is: 0.846465155804927
# r2score corresponing to 44 is: 0.8750100119258745
# r2score corresponing to 45 is: 0.8935621361627027
# r2score corresponing to 46 is: 0.8908037599568734
# r2score corresponing to 47 is: 0.8822070479648944
# r2score corresponing to 48 is: 0.8226709167062703
# r2score corresponing to 49 is: 0.8204285066116266
# r2score corresponing to 50 is: 0.9018452200777989
# r2score corresponing to 51 is: 0.8249639719265551
# r2score corresponing to 52 is: 0.8786315683234538
# r2score corresponing to 53 is: 0.9045867149321151
# r2score corresponing to 54 is: 0.8137390605405004
# r2score corresponing to 55 is: 0.8586996812573626
# r2score corresponing to 56 is: 0.8201380234088224
# r2score corresponing to 57 is: 0.84077770453466
# r2score corresponing to 58 is: 0.8552430109379051
# r2score corresponing to 59 is: 0.8840684018360753
# r2score corresponing to 60 is: 0.8120526133664391
# r2score corresponing to 61 is: 0.9083337731941812
# r2score corresponing to 62 is: 0.8677155752053568
# r2score corresponing to 63 is: 0.8590957697517266
# r2score corresponing to 64 is: 0.8509870902296708
# r2score corresponing to 65 is: 0.8674708136227758
# r2score corresponing to 66 is: 0.8810110900419025
# r2score corresponing to 67 is: 0.8587515897815998
# r2score corresponing to 68 is: 0.8521844653280818
# r2score corresponing to 69 is: 0.9137654737897871
# r2score corresponing to 70 is: 0.8194818781827085
# r2score corresponing to 71 is: 0.8219168598499177
# r2score corresponing to 72 is: 0.8892096132255594
# r2score corresponing to 73 is: 0.9014447621863292
# r2score corresponing to 74 is: 0.8673357238726235
# r2score corresponing to 75 is: 0.884848839789659
# r2score corresponing to 76 is: 0.842825934748608
# r2score corresponing to 77 is: 0.891546666815101
# r2score corresponing to 78 is: 0.8174692609462626
# r2score corresponing to 79 is: 0.8352597863565134
# r2score corresponing to 80 is: 0.9010057888399109
# r2score corresponing to 81 is: 0.8437127528849026
# r2score corresponing to 82 is: 0.9164723891995203
# r2score corresponing to 83 is: 0.8600530657445556
# r2score corresponing to 84 is: 0.8587085034020316
# r2score corresponing to 85 is: 0.8540044804155151
# r2score corresponing to 86 is: 0.8554487051256532
# r2score corresponing to 87 is: 0.9091984146040402
# r2score corresponing to 88 is: 0.848285526054357
# r2score corresponing to 89 is: 0.8615827909128868
# r2score corresponing to 90 is: 0.8538354161548237
# r2score corresponing to 91 is: 0.8142842005185741
# r2score corresponing to 92 is: 0.8001422124221982
# r2score corresponing to 93 is: 0.9084938951746456
# r2score corresponing to 94 is: 0.8778694791424363
# r2score corresponing to 95 is: 0.8155510315287122
# r2score corresponing to 96 is: 0.8822652117295954
# r2score corresponing to 97 is: 0.9122117704994529
# r2score corresponing to 98 is: 0.8825616365082296
# r2score corresponing to 99 is: 0.8670888067842769
# r2score corresponing to 100 is: 0.8736454217799443
#
#
# max r2_score corresponding to  82 is 0.9164723891995203

# %%
print("mean r2score for AdaBoostRegressor:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("standard deviation of  r2score for AdaBoostRegressor:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# mean r2score for AdaBoostRegressor: 0.7529580649173393
# standard deviation of  r2score for AdaBoostRegressor: 0.1934963195767029

# %% [markdown]
# For this dataset GradientBoostRegressor model performs well.So I use this model for my final output.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=50,test_size=0.20)
gbr.fit(x_train,y_train)
y_pred=gbr.predict(x_test)

# %%
print("r2score is",r2_score(y_test,y_pred))
print("root mean squared error is",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2score is 0.9368016738176509
# root mean squared error is 1.9011327219021021

# %%
#save the model
from sklearn.externals import joblib
joblib.dump(gbr,"gbr_autompg.pkl")
# Out:
# ['gbr_autompg.pkl']

# %% [markdown]
# # the highest r2score is provided by GradientBoostRegressor at 0.9368 and the cross val score is 0.77 so GradientBoostRegressor is choosen for the model as it also overcomes the overefitiing and underfitting problem
