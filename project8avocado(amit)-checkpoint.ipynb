# %%
import pandas as pd
df_avocado=pd.read_csv("avocado.csv",parse_dates=["Date"])
df_avocado.head()
avocado_data=df_avocado

# %%
#checking the datatypes
df_avocado.dtypes
# Out:
# Unnamed: 0               int64
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
df_avocado["month"]=df_avocado["Date"].dt.month_name()
df_avocado["day"]=df_avocado["Date"].dt.day_name()

# %%
df_avocado.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df_avocado.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-06-12          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region     month     day
# 0  Albany  December  Sunday
# 1  Albany  December  Sunday
# 2  Albany  December  Sunday
# 3  Albany      June  Friday
# 4  Albany  November  Sunday

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.barplot(x="year",y="AveragePrice",data=df_avocado)

# %%
df_avocado.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# std    7.579765e+05  6.474765e+05  1.182157e+05    7455.712144     0.369324
# min    3.311770e+03  3.311770e+03  0.000000e+00       0.000000  2015.000000
# 25%    3.620689e+04  2.972722e+04  5.407400e+02       0.000000  2015.000000
# 50%    7.397906e+04  6.237569e+04  5.044350e+03       0.000000  2015.000000
# 75%    1.576097e+05  1.461994e+05  2.926767e+04     401.480000  2015.000000
# max    6.736304e+06  5.893642e+06  1.121076e+06  108072.790000  2016.000000

# %%
#find the correlation matrix
df_avocado.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284  0.178683
# Total Volume    0.967689    0.960642    0.910226     0.521717 -0.004189
# 4046            0.930395    0.922278    0.884229     0.474063 -0.040439
# 4225            0.951779    0.943988    0.900496     0.504718 -0.007254
# 4770            0.926405    0.923607    0.840523     0.646053  0.029222
# Total Bags      1.000000    0.997341    0.911336     0.601856  0.090108
# Small Bags      0.997341    1.000000    0.879131     0.611300  0.106382
# Large Bags      0.911336    0.879131    1.000000     0.447779 -0.018678
# XLarge Bags     0.601856    0.611300    0.447779     1.000000  0.218342
# year            0.090108    0.106382   -0.018678     0.218342  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df_avocado.corr(),annot=True)

# %%
df_avocado.hist(figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1889CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E19AE848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E19F8E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1A2DF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1A6D0C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1AA5208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1ADF288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1B15388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1B1BF08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1B5B108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1BC26C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F2E1BF9848>]],
#       dtype=object)

# %%
sns.pairplot(data=df_avocado)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df_avocado['type']=le.fit_transform(df_avocado['type'].astype(str))
df_avocado['region']=le.fit_transform(df_avocado['region'].astype(str))
df_avocado['day']=le.fit_transform(df_avocado['day'].astype(str))
df_avocado['month']=le.fit_transform(df_avocado['month'].astype(str))
df_avocado.head()
#using labelEncoder converting the Gender column to numerical form
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-06-12          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region  month  \
# 0     8696.87     8603.62       93.25          0.0     0  2015       0      2
# 1     9505.56     9408.07       97.49          0.0     0  2015       0      2
# 2     8145.35     8042.21      103.14          0.0     0  2015       0      2
# 3     5811.16     5677.40      133.76          0.0     0  2015       0      6
# 4     6183.95     5986.26      197.69          0.0     0  2015       0      9
#
#    day
# 0    3
# 1    3
# 2    3
# 3    0
# 4    3

# %%
df_avocado=df_avocado.drop(columns=["Date"])

# %%
df_avocado.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'month', 'day'],
#       dtype='object')

# %%
df_avocado.plot(kind='box', subplots=True, layout=(4,4), sharex=False, sharey=False,figsize=(10,10))
plt.tight_layout()

# %%
sns.distplot(df_avocado["AveragePrice"])

# %%
sns.distplot(df_avocado["Total Volume"])

# %%
sns.distplot(df_avocado["Total Bags"])

# %%
#visualization with violin plot for specific columns
plt.violinplot(df_avocado["AveragePrice"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1f2e96bd588>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1f2e96a9d08>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1f2e96bde88>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1f2e96bddc8>}

# %%
#visualization with violin plot for specific columns
plt.violinplot(df_avocado['Total Volume'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1f2e972adc8>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1f2e9718688>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1f2e9733cc8>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1f2e9733c48>}

# %%
df_avocado.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# type            0.000000
# year            1.828332
# region          0.288146
# month          -0.017524
# day            -0.396612
# dtype: float64

# %%
#removing skewness
import warnings
warnings.filterwarnings("ignore")
import numpy as np
for col in df_avocado.columns:
    if df_avocado.skew().loc[col]>0.55:
        df_avocado[col]=np.log1p(df_avocado[col])

# %%
df_avocado.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# type            0.000000
# year            1.828332
# region          0.288146
# month          -0.017524
# day            -0.396612
# dtype: float64

# %%
x=df_avocado.drop(columns=['AveragePrice'])
x1=df_avocado.drop(columns=['region'])
x=pd.DataFrame(df_avocado.iloc[:,1:14])
x1=pd.DataFrame(df_avocado.iloc[:,0:13])
y=pd.DataFrame(df_avocado['AveragePrice'])
y1=pd.DataFrame(df_avocado['region'])
x1.head()
# Out:
#    AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0          1.33     11.070344  6.944801  10.905146  3.895080    9.070833
# 1          1.35     10.912867  6.515127  10.706381  4.083115    9.159737
# 2          0.93     11.680313  6.679222  11.600485  4.879007    9.005325
# 3          1.08     11.277116  7.032624  11.184108  4.298373    8.667708
# 4          1.28     10.840377  6.848515  10.688288  4.340944    8.729874
#
#    Small Bags  Large Bags  XLarge Bags  type      year  region  month
# 0    9.060055    4.545951          0.0     0  7.608871       0      2
# 1    9.149429    4.589955          0.0     0  7.608871       0      2
# 2    8.992584    4.645736          0.0     0  7.608871       0      2
# 3    8.644425    4.903495          0.0     0  7.608871       0      6
# 4    8.697389    5.291746          0.0     0  7.608871       0      9

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_x=sc.fit_transform(x)
df_x=pd.DataFrame(df_x,columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_predict=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
regr=linear_model.LinearRegression()
r_state=maxr2_score(regr,df_x,y)
# Out:
# r2score corresponing to 42 is: 0
df_x,y)
# Out:
# r2score corresponing to 42 is: 0.5103383707195892
# r2score corresponing to 43 is: 0.5326724327647754
# r2score corresponing to 44 is: 0.48154429068185345
# r2score corresponing to 45 is: 0.465588679114452
# r2score corresponing to 46 is: 0.5554194840583057
# r2score corresponing to 47 is: 0.5085307898861545
# r2score corresponing to 48 is: 0.47338249339483995
# r2score corresponing to 49 is: 0.4847601066805376
# r2score corresponing to 50 is: 0.48333704924223553
# r2score corresponing to 51 is: 0.5324026341832966
# r2score corresponing to 52 is: 0.537225039042608
# r2score corresponing to 53 is: 0.5228078883918852
# r2score corresponing to 54 is: 0.5354932241341701
# r2score corresponing to 55 is: 0.5273571065970097
# r2score corresponing to 56 is: 0.46284836178194344
# r2score corresponing to 57 is: 0.46156933842279324
# r2score corresponing to 58 is: 0.49216791162408036
# r2score corresponing to 59 is: 0.5593532654310185
# r2score corresponing to 60 is: 0.5746682320623682
# r2score corresponing to 61 is: 0.4870540671695891
# r2score corresponing to 62 is: 0.49880744343185734
# r2score corresponing to 63 is: 0.5141561027136853
# r2score corresponing to 64 is: 0.4765068730048907
# r2score corresponing to 65 is: 0.4893056447796238
# r2score corresponing to 66 is: 0.5322728393814409
# r2score corresponing to 67 is: 0.5170060344804275
# r2score corresponing to 68 is: 0.4933906350173908
# r2score corresponing to 69 is: 0.47747551939787614
# r2score corresponing to 70 is: 0.5162115111687101
# r2score corresponing to 71 is: 0.49979730923263055
# r2score corresponing to 72 is: 0.4564248016900695
# r2score corresponing to 73 is: 0.5232658753349193
# r2score corresponing to 74 is: 0.571858303422611
# r2score corresponing to 75 is: 0.5253948932682645
# r2score corresponing to 76 is: 0.47386421718788807
# r2score corresponing to 77 is: 0.4386723621431792
# r2score corresponing to 78 is: 0.5179677796144133
# r2score corresponing to 79 is: 0.5429013292539029
# r2score corresponing to 80 is: 0.49946609640412754
# r2score corresponing to 81 is: 0.5118991740651045
# r2score corresponing to 82 is: 0.5781883269422038
# r2score corresponing to 83 is: 0.3898646321279454
# r2score corresponing to 84 is: 0.5179136329607085
# r2score corresponing to 85 is: 0.5000837238817172
# r2score corresponing to 86 is: 0.4188157503040011
# r2score corresponing to 87 is: 0.5358542302248026
# r2score corresponing to 88 is: 0.46943356460903674
# r2score corresponing to 89 is: 0.5610820177408098
# r2score corresponing to 90 is: 0.5015415064431309
# r2score corresponing to 91 is: 0.5002701954619413
# r2score corresponing to 92 is: 0.5887998134995266
# r2score corresponing to 93 is: 0.5736795447128294
# r2score corresponing to 94 is: 0.5145573474045856
# r2score corresponing to 95 is: 0.496779672488021
# r2score corresponing to 96 is: 0.4410600636826745
# r2score corresponing to 97 is: 0.5034867885021633
# r2score corresponing to 98 is: 0.5086625980476249
# r2score corresponing to 99 is: 0.5418051764303956
# r2score corresponing to 100 is: 0.48391982554791135
#
#
# max r2_score corresponding to  92 is 0.5887998134995266

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
grid_param={"random_state":range(0,20)}
Gdt=GridSearchCV(dtr,param_grid=grid_param,scoring='r2',cv=10)
Gdt.fit(df_x,y)
Gdt.best_params_
# Out:
# {'random_state': 3}

# %%
def maxr2_score(dtr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        dtr=DecisionTreeRegressor(random_state=3)
        dtr.fit(x_train,y_train)
        y_predict=dtr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
dtr=DecisionTreeRegressor(random_state=3)
r_state=maxr2_score(dtr,df_x,y)
# Out:
# r2score corresponing to 42 is: 0.669409767470644
# r2score corresponing to 43 is: 0.777890213147719
# r2score corresponing to 44 is: 0.5853376272489645
# r2score corresponing to 45 is: 0.6647772362360267
# r2score corresponing to 46 is: 0.5782839952637786
# r2score corresponing to 47 is: 0.6852356495185103
# r2score corresponing to 48 is: 0.5955817786657489
# r2score corresponing to 49 is: 0.735379065286349
# r2score corresponing to 50 is: 0.6438765729561464
# r2score corresponing to 51 is: 0.6912994107695105
# r2score corresponing to 52 is: 0.6457198077410811
# r2score corresponing to 53 is: 0.6997841823530142
# r2score corresponing to 54 is: 0.5692867043438381
# r2score corresponing to 55 is: 0.6320810295096542
# r2score corresponing to 56 is: 0.46678962674492497
# r2score corresponing to 57 is: 0.672548995663978
# r2score corresponing to 58 is: 0.6222476932437278
# r2score corresponing to 59 is: 0.6647393108039732
# r2score corresponing to 60 is: 0.6887151061066021
# r2score corresponing to 61 is: 0.5401066278295918
# r2score corresponing to 62 is: 0.5407964629989486
# r2score corresponing to 63 is: 0.6635364463424822
# r2score corresponing to 64 is: 0.5558629985442051
# r2score corresponing to 65 is: 0.6128071856146493
# r2score corresponing to 66 is: 0.7112070461542119
# r2score corresponing to 67 is: 0.6652082060070432
# r2score corresponing to 68 is: 0.6928416472096737
# r2score corresponing to 69 is: 0.5530409736961931
# r2score corresponing to 70 is: 0.6468724010832806
# r2score corresponing to 71 is: 0.615134892453396
# r2score corresponing to 72 is: 0.641964925169354
# r2score corresponing to 73 is: 0.6145111126389533
# r2score corresponing to 74 is: 0.6584102661278637
# r2score corresponing to 75 is: 0.6328607104217743
# r2score corresponing to 76 is: 0.5934440129622125
# r2score corresponing to 77 is: 0.7238997904988762
# r2score corresponing to 78 is: 0.6690149115434503
# r2score corresponing to 79 is: 0.6044314110776914
# r2score corresponing to 80 is: 0.5718795585927984
# r2score corresponing to 81 is: 0.654229885627054
# r2score corresponing to 82 is: 0.6500854921093828
# r2score corresponing to 83 is: 0.364819773604826
# r2score corresponing to 84 is: 0.6597361453689665
# r2score corresponing to 85 is: 0.7255983014393927
# r2score corresponing to 86 is: 0.6508695899841462
# r2score corresponing to 87 is: 0.7015308591141731
# r2score corresponing to 88 is: 0.646679883909075
# r2score corresponing to 89 is: 0.565816611580173
# r2score corresponing to 90 is: 0.6290013339685832
# r2score corresponing to 91 is: 0.7125369640529816
# r2score corresponing to 92 is: 0.6204288727045577
# r2score corresponing to 93 is: 0.6788436950406139
# r2score corresponing to 94 is: 0.679318230408812
# r2score corresponing to 95 is: 0.6682030243709711
# r2score corresponing to 96 is: 0.47423910986774276
# r2score corresponing to 97 is: 0.6567188760594362
# r2score corresponing to 98 is: 0.513127200671635
# r2score corresponing to 99 is: 0.5314623931682607
# r2score corresponing to 100 is: 0.6137750449266423
#
#
# max r2_score corresponding to  43 is 0.777890213147719

# %%
from sklearn.linear_model import Ridge
r_reg=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(r_reg,parameters,cv=10)
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
def maxr2_score(r_reg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        r_reg=Ridge(alpha=1)
        r_reg.fit(x_train,y_train)
        y_predict=r_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
r_reg=Ridge(alpha=1)
r_state=maxr2_score(r_reg,df_x,y)
# Out:
# r2score corresponing to 42 is: 0
.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
gbr=GradientBoostingRegressor(learning_rate=0.01,n_estimators=100)
r_state=maxr2_score(gbr,df_x,y)
# Out:
# r2score corresponing to 42 is: 0.47212461595735444
# r2score corresponing to 43 is: 0.45538915505544386
# r2score corresponing to 44 is: 0.4290955978911124
# r2score corresponing to 45 is: 0.4604086019839343
# r2score corresponing to 46 is: 0.4928689475048632
# r2score corresponing to 47 is: 0.5248439555271007
# r2score corresponing to 48 is: 0.4534784588951116
# r2score corresponing to 49 is: 0.44428949903921555
# r2score corresponing to 50 is: 0.46631132701495603
# r2score corresponing to 51 is: 0.4719312432620414
# r2score corresponing to 52 is: 0.4489251698460719
# r2score corresponing to 53 is: 0.4726354234872647
# r2score corresponing to 54 is: 0.4609230410073588
# r2score corresponing to 55 is: 0.45959883292754766
# r2score corresponing to 56 is: 0.42702401827056535
# r2score corresponing to 57 is: 0.4620446223440583
# r2score corresponing to 58 is: 0.46308911702981503
# r2score corresponing to 59 is: 0.4342937451747736
# r2score corresponing to 60 is: 0.4882360729467997
# r2score corresponing to 61 is: 0.437978446799133
# r2score corresponing to 62 is: 0.4060980382076811
# r2score corresponing to 63 is: 0.43435412410651186
# r2score corresponing to 64 is: 0.4629622555607109
# r2score corresponing to 65 is: 0.4286216872143611
# r2score corresponing to 66 is: 0.4821560742863258
# r2score corresponing to 67 is: 0.46237595233599116
# r2score corresponing to 68 is: 0.49950241749303403
# r2score corresponing to 69 is: 0.43584214659778453
# r2score corresponing to 70 is: 0.44167029738844465
# r2score corresponing to 71 is: 0.46761487160116066
# r2score corresponing to 72 is: 0.43995600595516615
# r2score corresponing to 73 is: 0.49702990341525244
# r2score corresponing to 74 is: 0.4906128522240215
# r2score corresponing to 75 is: 0.4390137445248111
# r2score corresponing to 76 is: 0.43822903805880986
# r2score corresponing to 77 is: 0.46876035384630843
# r2score corresponing to 78 is: 0.4573289219905248
# r2score corresponing to 79 is: 0.43943141344683456
# r2score corresponing to 80 is: 0.46334789105940866
# r2score corresponing to 81 is: 0.442142072967431
# r2score corresponing to 82 is: 0.5080537388738694
# r2score corresponing to 83 is: 0.44777930312407377
# r2score corresponing to 84 is: 0.48087427592236043
# r2score corresponing to 85 is: 0.45951106518978346
# r2score corresponing to 86 is: 0.4036449019953551
# r2score corresponing to 87 is: 0.49218256096232604
# r2score corresponing to 88 is: 0.44016332393981505
# r2score corresponing to 89 is: 0.48391644811979406
# r2score corresponing to 90 is: 0.4422233934388763
# r2score corresponing to 91 is: 0.4362256690552
# r2score corresponing to 92 is: 0.4901098656146289
# r2score corresponing to 93 is: 0.491205437534324
# r2score corresponing to 94 is: 0.473525354912238
# r2score corresponing to 95 is: 0.45373038456620374
# r2score corresponing to 96 is: 0.42724263566504816
# r2score corresponing to 97 is: 0.42194444814435506
# r2score corresponing to 98 is: 0.43823746446914336
# r2score corresponing to 99 is: 0.47607987998552703
# r2score corresponing to 100 is: 0.4167147792382162
#
#
# max r2_score corresponding to  47 is 0.5248439555271007

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[regr,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 500}

# %%
def maxr2_score(ada_reg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
                       max_leaf_nodes=None, min_impurity_decrease=0.0,
                       min_impurity_split=None, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       presort=False, random_state=None, splitter='best'),
 learning_rate= 1,
 n_estimators= 500)
        ada_reg.fit(x_train,y_train)
        y_predict=ada_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
                       max_leaf_nodes=None, min_impurity_decrease=0.0,
                       min_impurity_split=None, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       presort=False, random_state=None, splitter='best'),
 learning_rate= 1,
 n_estimators= 500)
r_state=maxr2_score(ada_reg,df_x,y)
# Out:
# r2score corresponing to 42 is: 1.0
# r2score corresponing to 43 is: 1.0
# r2score corresponing to 44 is: 1.0
# r2score corresponing to 45 is: 1.0
# r2score corresponing to 46 is: 1.0
# r2score corresponing to 47 is: 1.0
# r2score corresponing to 48 is: 1.0
# r2score corresponing to 49 is: 1.0
# r2score corresponing to 50 is: 1.0
# r2score corresponing to 51 is: 1.0
# r2score corresponing to 52 is: 1.0
# r2score corresponing to 53 is: 1.0
# r2score corresponing to 54 is: 1.0
# r2score corresponing to 55 is: 1.0
# r2score corresponing to 56 is: 1.0
# r2score corresponing to 57 is: 1.0
# r2score corresponing to 58 is: 1.0
# r2score corresponing to 59 is: 1.0
# r2score corresponing to 60 is: 1.0
# r2score corresponing to 61 is: 1.0
# r2score corresponing to 62 is: 1.0
# r2score corresponing to 63 is: 1.0
# r2score corresponing to 64 is: 1.0
# r2score corresponing to 65 is: 1.0
# r2score corresponing to 66 is: 1.0
# r2score corresponing to 67 is: 1.0
# r2score corresponing to 68 is: 1.0
# r2score corresponing to 69 is: 1.0
# r2score corresponing to 70 is: 1.0
# r2score corresponing to 71 is: 1.0
# r2score corresponing to 72 is: 1.0
# r2score corresponing to 73 is: 1.0
# r2score corresponing to 74 is: 1.0
# r2score corresponing to 75 is: 1.0
# r2score corresponing to 76 is: 1.0
# r2score corresponing to 77 is: 1.0
# r2score corresponing to 78 is: 1.0
# r2score corresponing to 79 is: 1.0
# r2score corresponing to 80 is: 1.0
# r2score corresponing to 81 is: 1.0
# r2score corresponing to 82 is: 1.0
# r2score corresponing to 83 is: 1.0
# r2score corresponing to 84 is: 1.0
# r2score corresponing to 85 is: 1.0
# r2score corresponing to 86 is: 1.0
# r2score corresponing to 87 is: 1.0
# r2score corresponing to 88 is: 1.0
# r2score corresponing to 89 is: 1.0
# r2score corresponing to 90 is: 1.0
# r2score corresponing to 91 is: 1.0
# r2score corresponing to 92 is: 1.0
# r2score corresponing to 93 is: 1.0
# r2score corresponing to 94 is: 1.0
# r2score corresponing to 95 is: 1.0
# r2score corresponing to 96 is: 1.0
# r2score corresponing to 97 is: 1.0
# r2score corresponing to 98 is: 1.0
# r2score corresponing to 99 is: 1.0
# r2score corresponing to 100 is: 1.0
#
#
# max r2_score corresponding to  42 is 1.0

# %%
import xgboost as xgb

# %%
xgr=xgb.XGBRegressor()
def maxr2_score(xgr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        xgr=xgb.XGBRegressor()
        xgr.fit(x_train,y_train)
        y_predict=xgr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
warnings.filterwarnings("ignore")
xgr.fit(df_x,y)
r_state=maxr2_score(xgr,df_x,y)
# Out:
# [21:58:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:58:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 42 is: 0.9999998127150879
# [21:58:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 43 is: 0.9999999110497243
# [21:58:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 44 is: 0.9999996555014211
# [21:58:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 45 is: 0.9999998682468885
# [21:58:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 46 is: 0.9999998878427615
# [21:58:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 47 is: 0.999999802927632
# [21:58:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 48 is: 0.9999995648934694
# [21:58:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 49 is: 0.9999998673743425
# [21:58:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 50 is: 0.9999998886847802
# [21:58:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 51 is: 0.9999999208406001
# [21:58:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 52 is: 0.9999999507873361
# [21:58:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 53 is: 0.9999999003483419
# [21:58:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 54 is: 0.9999998846561555
# [21:58:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 55 is: 0.9999997736258852
# [21:58:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 56 is: 0.9999999066767233
# [21:58:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 57 is: 0.9999998525338166
# [21:58:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 58 is: 0.9999998820100032
# [21:58:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 59 is: 0.9999998821864844
# [21:58:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 60 is: 0.9999997478423649
# [21:58:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 61 is: 0.9999998912205208
# [21:58:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 62 is: 0.9999997328267914
# [21:58:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 63 is: 0.9999997432621385
# [21:58:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 64 is: 0.9999998777528937
# [21:58:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 65 is: 0.9999998696358043
# [21:58:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 66 is: 0.9999998808069455
# [21:58:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 67 is: 0.9999999253399543
# [21:58:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 68 is: 0.9999998288708591
# [21:58:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 69 is: 0.9999999435203839
# [21:58:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 70 is: 0.9999996869506776
# [21:58:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 71 is: 0.9999998146225344
# [21:58:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 72 is: 0.9999999356260395
# [21:58:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 73 is: 0.9999999138168437
# [21:58:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 74 is: 0.999999806568108
# [21:58:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 75 is: 0.9999999392381109
# [21:58:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 76 is: 0.9999997653978322
# [21:58:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 77 is: 0.9999998819548147
# [21:58:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 78 is: 0.9999997941044555
# [21:58:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 79 is: 0.9999998700662269
# [21:58:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 80 is: 0.9999998385739488
# [21:58:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 81 is: 0.9999998853794934
# [21:58:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 82 is: 0.9999999699392976
# [21:58:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 83 is: 0.9999997997276696
# [21:58:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 84 is: 0.999999967966034
# [21:58:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 85 is: 0.9999998712989489
# [21:58:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 86 is: 0.9999999013004143
# [21:58:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 87 is: 0.9999993742187364
# [21:58:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 88 is: 0.9999998234207296
# [21:58:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 89 is: 0.9999996560667427
# [21:58:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 90 is: 0.9999999647439165
# [21:58:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 91 is: 0.9999997506081051
# [21:58:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 92 is: 0.9999999627499769
# [21:58:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 93 is: 0.9999998887325318
# [21:58:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 94 is: 0.9999998745067684
# [21:58:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 95 is: 0.9999995348163935
# [21:58:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 96 is: 0.999999897462966
# [21:59:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 97 is: 0.9999998808861569
# [21:59:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 98 is: 0.9999996514177336
# [21:59:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 99 is: 0.999999922329484
# [21:59:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r2score corresponing to 100 is: 0.9999997584879954
#
#
# max r2_score corresponding to  82 is 0.9999999699392976

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
regr_score_mean=cross_val_score(regr,df_x,y,cv=5,scoring="r2").mean()
regr_score_std=cross_val_score(regr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of linearRegression :",regr_score_mean)
print("stadard deviation for r2 score of linearRegression :",regr_score_std)
knr_score_mean=cross_val_score(knr,df_x,y,cv=5,scoring="r2").mean()
knr_score_std=cross_val_score(knr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of knr:",knr_score_mean)
print("standard deviation of r2score for knr:",knr_score_std)
dtr_score_mean=cross_val_score(dtr,df_x,y,cv=5,scoring="r2").mean()
dtr_score_std=cross_val_score(dtr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of DecisionTreeRegression :",dtr_score_mean)
print("stadard deviation for r2 score of DecisionTreeeRegression :",dtr_score_std)
r_reg_score_mean=cross_val_score(r_reg,df_x,y,cv=5,scoring="r2").mean()
r_reg_score_std=cross_val_score(r_reg,df_x,y,cv=5,scoring="r2").std()
print("mean r2score for RidgeRegression:",r_reg_score_mean)
print("standard deviation in r2score for RidgeRegression:",r_reg_score_std)
Lsreg_score_mean=cross_val_score(lsreg,df_x,y,cv=5,scoring="r2").mean()
Lsreg_score_std=cross_val_score(lsreg,df_x,y,cv=5,scoring="r2").std()
print("mean r2score for Lasso:",Lsreg_score_mean)
print("standard deviation in r2score for lasso:",Lsreg_score_std)
gbr_score_mean=cross_val_score(gbr,df_x,y,cv=5,scoring="r2").mean()
gbr_score_std=cross_val_score(gbr,df_x,y,cv=5,scoring="r2").std()
print("mean r2score for GradientBoostRegression:",gbr_score_mean)
print("standard deviation in r2score for GradientBoostRegression:",gbr_score_std)
print("mean r2score for AdaBoostRegressor:",cross_val_score(ada_reg,df_x,y,cv=5,scoring="r2").mean())
print("standard deviationof  r2score for AdaBoostRegressor:",cross_val_score(ada_reg,df_x,y,cv=5,scoring="r2").std())
print("mean r2score for XGBoostRegressor:",cross_val_score(xgr,df_x,y,cv=5,scoring="r2").mean())
print("standard deviationof  r2score for XGBoostRegressor:",cross_val_score(xgr,df_x,y,cv=5,scoring="r2").std())
# Out:
# mean r2 score of linearRegression : 1.0
# stadard deviation for r2 score of linearRegression : 0.0
# mean r2 score of knr: -7.998758852845566
# standard deviation of r2score for knr: 9.128973757713917
# mean r2 score of DecisionTreeRegression : 0.12261415652279153
# stadard deviation for r2 score of DecisionTreeeRegression : 0.7267211480778978
# mean r2score for RidgeRegression: 0.9999019137346995
# standard deviation in r2score for RidgeRegression: 0.0001246855404503034
# mean r2score for Lasso: 0.9999851550638796
# standard deviation in r2score for lasso: 1.8969360338984536e-05
# mean r2score for GradientBoostRegression: -2.83828478980589
# standard deviation in r2score for GradientBoostRegression: 3.7157058429048346
# mean r2score for AdaBoostRegressor: 0.051737550009342395
# standard deviationof  r2score for AdaBoostRegressor: 0.7759279125492446
# [21:59:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:59:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:59:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:59:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:59:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# mean r2score for XGBoostRegressor: 0.40770212250977256
# [21:59:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:59:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:59:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:59:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:59:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# standard deviationof  r2score for XGBoostRegressor: 0.37131731856333766

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)
ada_reg.fit(x_train,y_train)
y_pred=ada_reg.predict(x_test)

# %%
print("r2score is",r2_score(y_test,y_pred))
print("root mean squared error is",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2score is 1.0
# root mean squared error is 0.0

# %%
#save the model
from sklearn.externals import joblib
joblib.dump(ada_reg,"ada_reg_avocado_data.pkl")
# Out:
# ['ada_reg_avocado_data.pkl']

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x1=ss.fit_transform(x1)

# %%
y=df_avocado["region"]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: region, dtype: int32

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x1,y,random_state=9,test_size=0.3,stratify=y)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=6)
sv=SVC()
dt=DecisionTreeClassifier(random_state=6)
lr=LogisticRegression()
rf=RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
neighbors={"n_neighbors":range(1,30)}
gknn=GridSearchCV(knn,neighbors,cv=10)
gknn.fit(x1,y)
gknn.best_params_
# Out:
# {'n_neighbors': 1}

# %%
grid_param={"random_state":range(0,20),"criterion":['gini','entropy']}
Gdt=GridSearchCV(dt,param_grid=grid_param,scoring='accuracy',cv=10)
Gdt.fit(x1,y)
Gdt.best_params_
# Out:
# {'criterion': 'entropy', 'random_state': 3}

# %%
kernel={"kernel":["linear","rbf","poly"]}
Gsv=GridSearchCV(sv,kernel,cv=10)
Gsv.fit(x1,y)
Gsv.best_params_
# Out:
# {'kernel': 'linear'}

# %%
knn=KNeighborsClassifier(n_neighbors=1)
sv=SVC(kernel="linear")
dt=DecisionTreeClassifier(random_state=3,criterion="entropy")
lr=LogisticRegression()
rf=RandomForestClassifier()

# %%
models=[]
models.append(("KNeighborsClassifier",knn))
models.append(("SVC",sv))
models.append(("DecisionTreeClassifier",dt))
models.append(("LogisticRegression",lr))
models.append(("RandomForestClassifier",rf))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Model=[]
score=[]
cvs=[]
roc_score=[]
for name,model in models:
    print('*********************',name,'***************************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print("accuracy_score",AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x1,y,cv=10,scoring="accuracy").mean()
    print("cross_val_score=",sc)
    cvs.append(sc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print("\n")
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True positive rate')
    plt.xlabel('False positive rate')
    print('\n\n')
# Out:
# ********************* KNeighborsClassifier ***************************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')
#
#
# accuracy_score 0.9605263157894737
#
#
# cross_val_score= 0.9630931258213294
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        20
#            1       1.00      1.00      1.00        16
#            2       0.95      1.00      0.98        20
#            3       1.00      1.00      1.00        20
#            4       1.00      1.00      1.00        19
#            5       1.00      0.73      0.85        15
#            6       1.00      1.00      1.00        23
#            7       1.00      1.00      1.00         9
#            8       1.00      0.86      0.92         7
#            9       1.00      1.00      1.00        14
#           10       1.00      1.00      1.00         5
#           11       1.00      1.00      1.00         7
#           12       1.00      1.00      1.00        12
#           13       1.00      0.86      0.92         7
#           14       1.00      1.00      1.00         5
#           15       1.00      1.00      1.00         6
#           16       0.60      0.75      0.67         4
#           17       0.90      1.00      0.95         9
#           18       0.71      1.00      0.83         5
#           19       1.00      0.92      0.96        12
#           20       1.00      1.00      1.00         3
#           21       1.00      1.00      1.00         1
#           22       1.00      1.00      1.00        10
#           23       0.80      0.80      0.80         5
#           24       1.00      1.00      1.00         5
#           25       0.88      1.00      0.93         7
#           26       1.00      1.00      1.00        13
#           27       1.00      1.00      1.00         4
#           28       0.90      1.00      0.95         9
#           29       0.83      0.83      0.83         6
#           30       1.00      1.00      1.00         4
#           31       1.00      0.94      0.97        16
#           32       1.00      0.86      0.92         7
#           33       1.00      1.00      1.00         4
#           34       0.90      1.00      0.95         9
#           35       1.00      0.80      0.89         5
#           36       1.00      0.83      0.91         6
#           37       1.00      1.00      1.00         5
#           38       0.85      1.00      0.92        11
#           39       1.00      0.75      0.86         4
#           40       1.00      0.67      0.80         3
#           41       0.78      1.00      0.88         7
#           42       0.92      1.00      0.96        12
#           43       1.00      0.67      0.80         3
#           44       1.00      1.00      1.00        15
#           45       1.00      1.00      1.00         5
#           46       1.00      1.00      1.00         6
#           47       1.00      0.90      0.95        10
#           48       1.00      1.00      1.00         7
#           49       1.00      1.00      1.00        11
#           50       1.00      1.00      1.00         8
#
#     accuracy                           0.96       456
#    macro avg       0.96      0.94      0.95       456
# weighted avg       0.97      0.96      0.96       456
#
#
#
# [[20  0  0 ...  0  0  0]
#  [ 0 16  0 ...  0  0  0]
#  [ 0  0 20 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  7  0  0]
#  [ 0  0  0 ...  0 11  0]
#  [ 0  0  0 ...  0  0  8]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# No handles with labels found to put in legend.
# ********************* SVC ***************************
#
#
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)
#
#
# accuracy_score 0.9890350877192983
#
#
# cross_val_score= 0.987540361491854
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        20
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        20
#            4       1.00      1.00      1.00        19
#            5       1.00      0.93      0.97        15
#            6       1.00      1.00      1.00        23
#            7       1.00      1.00      1.00         9
#            8       1.00      1.00      1.00         7
#            9       1.00      1.00      1.00        14
#           10       1.00      1.00      1.00         5
#           11       1.00      1.00      1.00         7
#           12       1.00      1.00      1.00        12
#           13       1.00      1.00      1.00         7
#           14       1.00      1.00      1.00         5
#           15       1.00      1.00      1.00         6
#           16       1.00      1.00      1.00         4
#           17       1.00      1.00      1.00         9
#           18       1.00      1.00      1.00         5
#           19       1.00      1.00      1.00        12
#           20       1.00      1.00      1.00         3
#           21       1.00      1.00      1.00         1
#           22       0.91      1.00      0.95        10
#           23       1.00      1.00      1.00         5
#           24       1.00      1.00      1.00         5
#           25       1.00      1.00      1.00         7
#           26       1.00      1.00      1.00        13
#           27       1.00      1.00      1.00         4
#           28       1.00      1.00      1.00         9
#           29       1.00      1.00      1.00         6
#           30       1.00      1.00      1.00         4
#           31       1.00      0.94      0.97        16
#           32       1.00      0.86      0.92         7
#           33       1.00      1.00      1.00         4
#           34       1.00      1.00      1.00         9
#           35       1.00      0.80      0.89         5
#           36       1.00      1.00      1.00         6
#           37       1.00      1.00      1.00         5
#           38       0.85      1.00      0.92        11
#           39       1.00      1.00      1.00         4
#           40       1.00      1.00      1.00         3
#           41       0.88      1.00      0.93         7
#           42       1.00      1.00      1.00        12
#           43       1.00      1.00      1.00         3
#           44       1.00      1.00      1.00        15
#           45       1.00      1.00      1.00         5
#           46       1.00      1.00      1.00         6
#           47       1.00      0.90      0.95        10
#           48       1.00      1.00      1.00         7
#           49       1.00      1.00      1.00        11
#           50       1.00      1.00      1.00         8
#
#     accuracy                           0.99       456
#    macro avg       0.99      0.99      0.99       456
# weighted avg       0.99      0.99      0.99       456
#
#
#
# [[20  0  0 ...  0  0  0]
#  [ 0 16  0 ...  0  0  0]
#  [ 0  0 20 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  7  0  0]
#  [ 0  0  0 ...  0 11  0]
#  [ 0  0  0 ...  0  0  8]]
# No handles with labels found to put in legend.
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ********************* DecisionTreeClassifier ***************************
#
#
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=3, splitter='best')
#
#
# accuracy_score 0.993421052631579
#
#
# cross_val_score= 0.9929282629673564
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        20
#            4       1.00      1.00      1.00        19
#            5       1.00      1.00      1.00        15
#            6       1.00      1.00      1.00        23
#            7       1.00      1.00      1.00         9
#            8       1.00      1.00      1.00         7
#            9       1.00      1.00      1.00        14
#           10       1.00      1.00      1.00         5
#           11       1.00      1.00      1.00         7
#           12       1.00      1.00      1.00        12
#           13       1.00      1.00      1.00         7
#           14       1.00      1.00      1.00         5
#           15       1.00      1.00      1.00         6
#           16       1.00      1.00      1.00         4
#           17       1.00      1.00      1.00         9
#           18       1.00      1.00      1.00         5
#           19       1.00      0.92      0.96        12
#           20       0.75      1.00      0.86         3
#           21       1.00      1.00      1.00         1
#           22       1.00      1.00      1.00        10
#           23       1.00      1.00      1.00         5
#           24       1.00      1.00      1.00         5
#           25       1.00      1.00      1.00         7
#           26       1.00      1.00      1.00        13
#           27       1.00      1.00      1.00         4
#           28       1.00      1.00      1.00         9
#           29       1.00      1.00      1.00         6
#           30       1.00      1.00      1.00         4
#           31       1.00      1.00      1.00        16
#           32       1.00      1.00      1.00         7
#           33       1.00      1.00      1.00         4
#           34       1.00      1.00      1.00         9
#           35       1.00      1.00      1.00         5
#           36       0.83      0.83      0.83         6
#           37       0.80      0.80      0.80         5
#           38       1.00      1.00      1.00        11
#           39       1.00      1.00      1.00         4
#           40       1.00      1.00      1.00         3
#           41       1.00      1.00      1.00         7
#           42       1.00      1.00      1.00        12
#           43       1.00      1.00      1.00         3
#           44       1.00      1.00      1.00        15
#           45       1.00      1.00      1.00         5
#           46       1.00      1.00      1.00         6
#           47       1.00      1.00      1.00        10
#           48       1.00      1.00      1.00         7
#           49       1.00      1.00      1.00        11
#           50       1.00      1.00      1.00         8
#
#     accuracy                           0.99       456
#    macro avg       0.99      0.99      0.99       456
# weighted avg       0.99      0.99      0.99       456
#
#
#
# [[20  0  0 ...  0  0  0]
#  [ 0 16  0 ...  0  0  0]
#  [ 0  0 20 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  7  0  0]
#  [ 0  0  0 ...  0 11  0]
#  [ 0  0  0 ...  0  0  8]]
# No handles with labels found to put in legend.
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ********************* LogisticRegression ***************************
#
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# accuracy_score 0.8574561403508771
#
#
# cross_val_score= 0.8792268232497058
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        20
#            1       1.00      1.00      1.00        16
#            2       0.85      0.85      0.85        20
#            3       1.00      1.00      1.00        20
#            4       0.90      1.00      0.95        19
#            5       1.00      0.80      0.89        15
#            6       0.96      1.00      0.98        23
#            7       1.00      0.89      0.94         9
#            8       1.00      0.71      0.83         7
#            9       1.00      1.00      1.00        14
#           10       0.75      0.60      0.67         5
#           11       1.00      1.00      1.00         7
#           12       1.00      1.00      1.00        12
#           13       1.00      1.00      1.00         7
#           14       0.62      1.00      0.77         5
#           15       1.00      1.00      1.00         6
#           16       0.00      0.00      0.00         4
#           17       0.78      0.78      0.78         9
#           18       1.00      0.20      0.33         5
#           19       0.86      1.00      0.92        12
#           20       0.00      0.00      0.00         3
#           21       0.00      0.00      0.00         1
#           22       0.67      1.00      0.80        10
#           23       0.83      1.00      0.91         5
#           24       1.00      0.40      0.57         5
#           25       1.00      1.00      1.00         7
#           26       0.59      1.00      0.74        13
#           27       0.00      0.00      0.00         4
#           28       0.82      1.00      0.90         9
#           29       1.00      0.17      0.29         6
#           30       0.00      0.00      0.00         4
#           31       0.82      0.88      0.85        16
#           32       0.86      0.86      0.86         7
#           33       1.00      1.00      1.00         4
#           34       0.67      0.67      0.67         9
#           35       1.00      0.60      0.75         5
#           36       0.00      0.00      0.00         6
#           37       1.00      1.00      1.00         5
#           38       0.56      0.91      0.69        11
#           39       0.33      0.25      0.29         4
#           40       0.00      0.00      0.00         3
#           41       0.70      1.00      0.82         7
#           42       0.91      0.83      0.87        12
#           43       1.00      1.00      1.00         3
#           44       0.79      1.00      0.88        15
#           45       1.00      1.00      1.00         5
#           46       1.00      1.00      1.00         6
#           47       0.82      0.90      0.86        10
#           48       1.00      1.00      1.00         7
#           49       0.85      1.00      0.92        11
#           50       1.00      1.00      1.00         8
#
#     accuracy                           0.86       456
#    macro avg       0.76      0.75      0.73       456
# weighted avg       0.83      0.86      0.83       456
#
#
#
# [[20  0  0 ...  0  0  0]
#  [ 0 16  0 ...  0  0  0]
#  [ 0  0 17 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  7  0  0]
#  [ 0  0  0 ...  0 11  0]
#  [ 0  0  0 ...  0  0  8]]
# No handles with labels found to put in legend.
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ********************* RandomForestClassifier ***************************
#
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
# accuracy_score 0.993421052631579
#
#
# cross_val_score= 0.9851218167043859
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        20
#            4       1.00      1.00      1.00        19
#            5       1.00      1.00      1.00        15
#            6       1.00      1.00      1.00        23
#            7       1.00      1.00      1.00         9
#            8       1.00      1.00      1.00         7
#            9       0.93      1.00      0.97        14
#           10       1.00      1.00      1.00         5
#           11       1.00      1.00      1.00         7
#           12       1.00      1.00      1.00        12
#           13       1.00      1.00      1.00         7
#           14       1.00      1.00      1.00         5
#           15       1.00      1.00      1.00         6
#           16       1.00      1.00      1.00         4
#           17       1.00      1.00      1.00         9
#           18       1.00      1.00      1.00         5
#           19       0.85      0.92      0.88        12
#           20       1.00      1.00      1.00         3
#           21       1.00      1.00      1.00         1
#           22       1.00      1.00      1.00        10
#           23       1.00      1.00      1.00         5
#           24       1.00      1.00      1.00         5
#           25       1.00      0.86      0.92         7
#           26       1.00      1.00      1.00        13
#           27       1.00      1.00      1.00         4
#           28       1.00      1.00      1.00         9
#           29       1.00      0.83      0.91         6
#           30       1.00      1.00      1.00         4
#           31       1.00      1.00      1.00        16
#           32       1.00      1.00      1.00         7
#           33       1.00      1.00      1.00         4
#           34       1.00      1.00      1.00         9
#           35       1.00      1.00      1.00         5
#           36       1.00      1.00      1.00         6
#           37       1.00      1.00      1.00         5
#           38       1.00      1.00      1.00        11
#           39       1.00      1.00      1.00         4
#           40       1.00      1.00      1.00         3
#           41       1.00      1.00      1.00         7
#           42       1.00      1.00      1.00        12
#           43       1.00      1.00      1.00         3
#           44       1.00      1.00      1.00        15
#           45       1.00      1.00      1.00         5
#           46       1.00      1.00      1.00         6
#           47       1.00      1.00      1.00        10
#           48       1.00      1.00      1.00         7
#           49       1.00      1.00      1.00        11
#           50       1.00      1.00      1.00         8
#
#     accuracy                           0.99       456
#    macro avg       1.00      0.99      0.99       456
# weighted avg       0.99      0.99      0.99       456
#
#
#
# [[20  0  0 ...  0  0  0]
#  [ 0 16  0 ...  0  0  0]
#  [ 0  0 20 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  7  0  0]
#  [ 0  0  0 ...  0 11  0]
#  [ 0  0  0 ...  0  0  8]]
# No handles with labels found to put in legend.
# AxesSubplot(0.125,0.808774;0.62x0.0712264)

# %%
result=pd.DataFrame({'Model':Model,'Accuracy_score':score,'Cross_Val_Score':cvs})
result
# Out:
#                     Model  Accuracy_score  Cross_Val_Score
# 0    KNeighborsClassifier       96.052632        96.309313
# 1                     SVC       98.903509        98.754036
# 2  DecisionTreeClassifier       99.342105        99.292826
# 3      LogisticRegression       85.745614        87.922682
# 4  RandomForestClassifier       99.342105        98.512182

# %%
from sklearn.externals import joblib
joblib.dump(dt,"dtavocado.pkl")
# Out:
# ['dtavocado.pkl']
