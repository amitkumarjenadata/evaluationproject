# %%
import pandas as pd
df_airline=pd.read_excel("Data_Train.xlsx",parse_dates=["Date_of_Journey"])
df_airline.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
#checking the datatypes
df_airline.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time                   object
# Arrival_Time               object
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
#heatmap shows no missing data present in the dataset
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df_airline.isnull())
plt.show()

# %%
#creating a DataFrame and loanding the month year day and count data on the DataFrame
df_airline["month"]=df_airline["Date_of_Journey"].dt.month_name()
df_airline["year"]=df_airline["Date_of_Journey"].dt.year
df_airline["day"]=df_airline["Date_of_Journey"].dt.day_name()

# %%
df_airline.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#        month  year       day
# 0      March  2019    Sunday
# 1    January  2019  Saturday
# 2  September  2019    Friday
# 3   December  2019  Thursday
# 4    January  2019  Thursday

# %%
#making one more column for type_of_day
import numpy as np
df_airline["type_of_day"]=np.where((df_airline["day"]=="Sunday")|(df_airline["day"]=="Saturday"),"weekend","weekday")

# %%
sns.barplot(x="type_of_day",y="Price",data=df_airline)
plt.show()
#shows the plot of Price as the per the day .i.e weekday or weekend shows that ticket price in weekend is more

# %%
sns.lineplot(x="type_of_day",y="Price",data=df_airline)
plt.show()
#shows the plot of price as the per the day .i.e weekday or weekend shows weekend has more ticket price

# %%
sns.lineplot(x="Duration",y="Price",data=df_airline)
plt.show()
#shows the plot of Duration as the the Price which shows that Price changes according to Duration

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Duration",y="Price",data=df_airline)
plt.show()
#shows the plot of count as the per the day .i.e weekday or weekend

# %%
#barplot to showw the count of ecah day of the week
sns.barplot(x="day",y="Price",data=df_airline)
plt.show()
#some days have more price compared to other days

# %%
#barplot to show the price of ecah month of the year
sns.barplot(x="month",y="Price",data=df_airline)
plt.show()
#january has the highest price wile in april the prices are lowest

# %%
#barplot to show the price of route
plt.figure(figsize=(10,10))
sns.barplot(x="Route",y="Price",data=df_airline)
plt.show()
#some routes outshines other as the price of such routes are extremly high

# %%
#barplot to show the price of each departure time
plt.figure(figsize=(10,10))
sns.barplot(x="Dep_Time",y="Price",data=df_airline)
plt.show()
#price depends on departure time

# %%
#barplot to show the price of ecah month of the year
sns.barplot(x="Source",y="Price",data=df_airline)
plt.show()
#the flights originating from delhi have the highest price

# %%
#barplot to show the price of each arrival time
plt.figure(figsize=(10,10))
sns.barplot(x="Arrival_Time",y="Price",data=df_airline)
plt.show()
#arrival_time is related to price but compared to departure time the correaltion is less

# %%
#barplot to show the price of ecah month of the year
plt.figure(figsize=(25,10))
sns.barplot(x="Airline",y="Price",data=df_airline)
plt.show()
#jet airways business has the highest price 
#trujet has the lowest price

# %%
df_airline.describe()
#mean price 9087.064
# Out:
#               Price     year
# count  10683.000000  10683.0
# mean    9087.064121   2019.0
# std     4611.359167      0.0
# min     1759.000000   2019.0
# 25%     5277.000000   2019.0
# 50%     8372.000000   2019.0
# 75%    12373.000000   2019.0
# max    79512.000000   2019.0

# %%
df_airline.drop(["Date_of_Journey","Additional_Info","year"],inplace=True,axis=1)
#dropping the not necessary column

# %%
#using labelEncoder to convert categorical column into numerical column
import warnings
warnings.filterwarnings("ignore")
import numpy as np
for col in df_airline.columns:
    if df_airline[col].dtypes=="object":
        from sklearn.preprocessing import LabelEncoder
        le=LabelEncoder()
        df_airline[col]=le.fit_transform(df_airline[col].astype(str))

# %%
df_airline.dtypes
#checking the datatypes
# Out:
# Airline         int32
# Source          int32
# Destination     int32
# Route           int32
# Dep_Time        int32
# Arrival_Time    int32
# Duration        int32
# Total_Stops     int32
# Price           int64
# month           int32
# day             int32
# type_of_day     int32
# dtype: object

# %%
sns.distplot(df_airline["Price"])
#distplot of price

# %%
#barplot to show the price vs Total_Stops
sns.barplot(x="Total_Stops",y="Price",data=df_airline)
plt.show()
#shows that more the no. of stops the more the price

# %%
sns.pairplot(df_airline)

# %%
#visualization with violin plot for specific columns
plt.violinplot(df_airline["Price"])
#mostly the price lies between 500-10000
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x24e2633b1c8>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x24e264d2c48>,
#  'cmins': <matplotlib.collections.LineCollection at 0x24e274c5748>,
#  'cbars': <matplotlib.collections.LineCollection at 0x24e263662c8>}

# %%
#heatmap shows the correlation of different column
plt.figure(figsize=(15,10))
sns.heatmap(df_airline.corr(),annot=True)
#mostly columns are not correlated

# %%
#histogram plot of each column
df_airline.hist(figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E28811E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E264AA308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E264DDC88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E28849DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E28882EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E288B8FC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E288F80C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E2892E1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E28935D88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E2896DF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E289DA508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E28A125C8>]],
#       dtype=object)

# %%
#removing outliers
from scipy.stats import zscore
z_score=abs(zscore(df_airline))
print(df_airline.shape)
df_airline=df_airline.loc[(z_score<3).all(axis=1)]
print(df_airline.shape)
#change in shape from 10683,12 to 10587,12
# Out:
# (10683, 12)
# (10587, 12)

# %%
df_airline.skew()
#skewness of the column shows that airline destination total_stops and type_of_day column are skewed
# Out:
# Airline         0.731723
# Source         -0.437770
# Destination     1.267105
# Route          -0.509937
# Dep_Time        0.194056
# Arrival_Time   -0.608082
# Duration       -0.215311
# Total_Stops     0.655691
# Price           0.412076
# month          -0.356464
# day            -0.056564
# type_of_day     1.399427
# dtype: float64

# %%
#removing skewness
import warnings
warnings.filterwarnings("ignore")
import numpy as np
for col in df_airline.columns:
    if df_airline.skew().loc[col]>0.55:
        df_airline[col]=np.log1p(df_airline[col])

# %%
y=df_airline["Price"]
x=df_airline.drop(columns=['Price'],inplace=True)
x=df_airline
#dividing data into input and output

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_x=sc.fit_transform(x)
df_x=pd.DataFrame(df_x,columns=x.columns)
#scaling the data

# %%
#creating a function to find the random_state coresponding to the maximum r2score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_predict=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling function with linear regression
regr=linear_model.LinearRegression()
r_state=maxr2_score(regr,df_x,y)
# Out:
# r2score corresponing to 42 is: 0.3420019712396293
# r2score corresponing to 43 is: 0.3603517738577593
# r2score corresponing to 44 is: 0.3668715336187106
# r2score corresponing to 45 is: 0.31842007933393346
# r2score corresponing to 46 is: 0.3569913399326051
# r2score corresponing to 47 is: 0.394682731710599
# r2score corresponing to 48 is: 0.3372018323913938
# r2score corresponing to 49 is: 0.36288310605301755
# r2score corresponing to 50 is: 0.3729993484869062
# r2score corresponing to 51 is: 0.36600177524739874
# r2score corresponing to 52 is: 0.33113559753728183
# r2score corresponing to 53 is: 0.37552049521655384
# r2score corresponing to 54 is: 0.38532273355363666
# r2score corresponing to 55 is: 0.36924631028597654
# r2score corresponing to 56 is: 0.3410657699780276
# r2score corresponing to 57 is: 0.36898829739719363
# r2score corresponing to 58 is: 0.3741221014571545
# r2score corresponing to 59 is: 0.3628281738985586
# r2score corresponing to 60 is: 0.38855336234334026
# r2score corresponing to 61 is: 0.3635102675350984
# r2score corresponing to 62 is: 0.3414037212503478
# r2score corresponing to 63 is: 0.37512519179548875
# r2score corresponing to 64 is: 0.3401137082505472
# r2score corresponing to 65 is: 0.3474964389593048
# r2score corresponing to 66 is: 0.38876571343314004
# r2score corresponing to 67 is: 0.35866007288597235
# r2score corresponing to 68 is: 0.3521251877901981
# r2score corresponing to 69 is: 0.3771971520687082
# r2score corresponing to 70 is: 0.3680734336217828
# r2score corresponing to 71 is: 0.35374841465929974
# r2score corresponing to 72 is: 0.35959798822502675
# r2score corresponing to 73 is: 0.3567120956190317
# r2score corresponing to 74 is: 0.3668866423128305
# r2score corresponing to 75 is: 0.3634236479813471
# r2score corresponing to 76 is: 0.346330356275408
# r2score corresponing to 77 is: 0.3382668708086335
# r2score corresponing to 78 is: 0.3951026765252996
# r2score corresponing to 79 is: 0.33635238169280746
# r2score corresponing to 80 is: 0.3776495370616686
# r2score corresponing to 81 is: 0.37795989117849027
# r2score corresponing to 82 is: 0.3627377529154091
# r2score corresponing to 83 is: 0.37821787429174447
# r2score corresponing to 84 is: 0.3572066891960973
# r2score corresponing to 85 is: 0.3604937295554492
# r2score corresponing to 86 is: 0.36970417993249494
# r2score corresponing to 87 is: 0.36235313938532565
# r2score corresponing to 88 is: 0.3887307070581463
# r2score corresponing to 89 is: 0.3435121317625496
# r2score corresponing to 90 is: 0.3668797424157707
# r2score corresponing to 91 is: 0.3804950809957668
# r2score corresponing to 92 is: 0.38831813557430905
# r2score corresponing to 93 is: 0.35555920539601216
# r2score corresponing to 94 is: 0.3657521988625456
# r2score corresponing to 95 is: 0.3800600664240227
# r2score corresponing to 96 is: 0.35045851587267907
# r2score corresponing to 97 is: 0.34194632281476744
# r2score corresponing to 98 is: 0.3550474615686531
# r2score corresponing to 99 is: 0.3762695395459106
# r2score corresponing to 100 is: 0.3716869292800158
#
#
# max r2_score corresponding to  78 is 0.3951026765252996

# %%
#using GridSearchCV to find the best parameter
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,25)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(df_x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 5}

# %%
#creating a function to find the random_state coresponding to the maximum r2score
def maxr2_score(knr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        knr=KNeighborsRegressor(n_neighbors=5)
        knr.fit(x_train,y_train)
        y_predict=knr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling function with KNeighborsRegressor
knr=KNeighborsRegressor(n_neighbors=5)
r_state=maxr2_score(knr,df_x,y)
# Out:
# r2score corresponing to 42 is: 0.6445703837021018
# r2score corresponing to 43 is: 0.6487325460537623
# r2score corresponing to 44 is: 0.6664430867267033
# r2score corresponing to 45 is: 0.6446503604643135
# r2score corresponing to 46 is: 0.6578914238114462
# r2score corresponing to 47 is: 0.675922305168915
# r2score corresponing to 48 is: 0.6422244212382675
# r2score corresponing to 49 is: 0.6331047812916608
# r2score corresponing to 50 is: 0.6742096289598428
# r2score corresponing to 51 is: 0.6556075003221873
# r2score corresponing to 52 is: 0.6332943367484025
# r2score corresponing to 53 is: 0.6701437063118836
# r2score corresponing to 54 is: 0.6944900655902662
# r2score corresponing to 55 is: 0.6576429889582616
# r2score corresponing to 56 is: 0.6522667100944652
# r2score corresponing to 57 is: 0.6570644493576498
# r2score corresponing to 58 is: 0.6652797331659062
# r2score corresponing to 59 is: 0.6744783245129662
# r2score corresponing to 60 is: 0.6738532730644831
# r2score corresponing to 61 is: 0.6692971919690156
# r2score corresponing to 62 is: 0.6670105630643814
# r2score corresponing to 63 is: 0.6527277226088246
# r2score corresponing to 64 is: 0.6453108157637278
# r2score corresponing to 65 is: 0.6560133788202438
# r2score corresponing to 66 is: 0.6527731475213568
# r2score corresponing to 67 is: 0.6550778133925989
# r2score corresponing to 68 is: 0.6306123008602798
# r2score corresponing to 69 is: 0.6425021029417608
# r2score corresponing to 70 is: 0.6609209192480884
# r2score corresponing to 71 is: 0.6726800914426926
# r2score corresponing to 72 is: 0.6672017814315916
# r2score corresponing to 73 is: 0.649778507777866
# r2score corresponing to 74 is: 0.6595386628952958
# r2score corresponing to 75 is: 0.6597947860241733
# r2score corresponing to 76 is: 0.6403498996037913
# r2score corresponing to 77 is: 0.6451221657697006
# r2score corresponing to 78 is: 0.6687080762153852
# r2score corresponing to 79 is: 0.6539180456112799
# r2score corresponing to 80 is: 0.6660496582371631
# r2score corresponing to 81 is: 0.665534426845943
# r2score corresponing to 82 is: 0.646860577897707
# r2score corresponing to 83 is: 0.6683358401916732
# r2score corresponing to 84 is: 0.6718365742630092
# r2score corresponing to 85 is: 0.6540770866233467
# r2score corresponing to 86 is: 0.6875968696024815
# r2score corresponing to 87 is: 0.6661208949750776
# r2score corresponing to 88 is: 0.6685619821608584
# r2score corresponing to 89 is: 0.6425210174681227
# r2score corresponing to 90 is: 0.6620919732003225
# r2score corresponing to 91 is: 0.6921091674731026
# r2score corresponing to 92 is: 0.6770820740636818
# r2score corresponing to 93 is: 0.6488995760792684
# r2score corresponing to 94 is: 0.6785468139552362
# r2score corresponing to 95 is: 0.666192039063791
# r2score corresponing to 96 is: 0.6738061479207039
# r2score corresponing to 97 is: 0.6518995151864592
# r2score corresponing to 98 is: 0.6424830112040099
# r2score corresponing to 99 is: 0.6551076744339266
# r2score corresponing to 100 is: 0.6615240793647468
#
#
# max r2_score corresponding to  54 is 0.6944900655902662

# %%
#using GridSearchCV to find the best parameter
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
grid_param={"random_state":range(0,20)}
Gdt=GridSearchCV(dtr,param_grid=grid_param,scoring='r2',cv=10)
Gdt.fit(df_x,y)
Gdt.best_params_
# Out:
# {'random_state': 15}

# %%
#creating a function to find the random_state coresponding to the maximum r2score
def maxr2_score(dtr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        dtr=DecisionTreeRegressor(random_state=15)
        dtr.fit(x_train,y_train)
        y_predict=dtr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function with DecisionTreeRegressor
dtr=DecisionTreeRegressor(random_state=15)
r_state=maxr2_score(dtr,df_x,y)
# Out:
# r2score corresponing to 42 is: 0.6722383151603779
# r2score corresponing to 43 is: 0.6606415357883841
# r2score corresponing to 44 is: 0.6714825037345431
# r2score corresponing to 45 is: 0.6346565488735372
# r2score corresponing to 46 is: 0.6722808097959804
# r2score corresponing to 47 is: 0.6833525063128988
# r2score corresponing to 48 is: 0.6387679609106329
# r2score corresponing to 49 is: 0.6222607121180559
# r2score corresponing to 50 is: 0.6583450775861026
# r2score corresponing to 51 is: 0.6691243523866639
# r2score corresponing to 52 is: 0.6799665909948047
# r2score corresponing to 53 is: 0.694392243836754
# r2score corresponing to 54 is: 0.6979033699890931
# r2score corresponing to 55 is: 0.6554900799358583
# r2score corresponing to 56 is: 0.6637551836369866
# r2score corresponing to 57 is: 0.692623231544951
# r2score corresponing to 58 is: 0.6542622447708955
# r2score corresponing to 59 is: 0.6725690133293817
# r2score corresponing to 60 is: 0.6942330077086619
# r2score corresponing to 61 is: 0.680496905727709
# r2score corresponing to 62 is: 0.6761109961236921
# r2score corresponing to 63 is: 0.6649295877820043
# r2score corresponing to 64 is: 0.6546384342055548
# r2score corresponing to 65 is: 0.6685445756396843
# r2score corresponing to 66 is: 0.6782008852332208
# r2score corresponing to 67 is: 0.6705469486676205
# r2score corresponing to 68 is: 0.631980404603507
# r2score corresponing to 69 is: 0.671263412242443
# r2score corresponing to 70 is: 0.6455894729248894
# r2score corresponing to 71 is: 0.6615921029976899
# r2score corresponing to 72 is: 0.6913308417921586
# r2score corresponing to 73 is: 0.6199008896090878
# r2score corresponing to 74 is: 0.7026647854294015
# r2score corresponing to 75 is: 0.6516333665878555
# r2score corresponing to 76 is: 0.662545766729563
# r2score corresponing to 77 is: 0.6661686331091129
# r2score corresponing to 78 is: 0.6450182789806898
# r2score corresponing to 79 is: 0.6662405972415049
# r2score corresponing to 80 is: 0.6852452611120634
# r2score corresponing to 81 is: 0.6697128645526955
# r2score corresponing to 82 is: 0.6834686883628273
# r2score corresponing to 83 is: 0.6729496113601847
# r2score corresponing to 84 is: 0.6713865177499404
# r2score corresponing to 85 is: 0.6711613792788611
# r2score corresponing to 86 is: 0.7016370187039727
# r2score corresponing to 87 is: 0.6503787052285923
# r2score corresponing to 88 is: 0.6602716186254889
# r2score corresponing to 89 is: 0.63915809517551
# r2score corresponing to 90 is: 0.6671349012883554
# r2score corresponing to 91 is: 0.6757398489469545
# r2score corresponing to 92 is: 0.6780297141639178
# r2score corresponing to 93 is: 0.6712775753804141
# r2score corresponing to 94 is: 0.6853755371879182
# r2score corresponing to 95 is: 0.6712787226579449
# r2score corresponing to 96 is: 0.7064280997489965
# r2score corresponing to 97 is: 0.6956149178190856
# r2score corresponing to 98 is: 0.6377699588719233
# r2score corresponing to 99 is: 0.6606966393491263
# r2score corresponing to 100 is: 0.653041832689243
#
#
# max r2_score corresponding to  96 is 0.7064280997489965

# %%
#using GridSearchCV to find the best parameter
from sklearn.linear_model import Ridge
r_reg=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(r_reg,parameters,cv=10)
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
#creating a function to find the random_state coresponding to the maximum r2score
def maxr2_score(r_reg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        r_reg=Ridge(alpha=1)
        r_reg.fit(x_train,y_train)
        y_predict=r_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the Function with RidgeRegressor
r_reg=Ridge(alpha=1)
r_state=maxr2_score(r_reg,df_x,y)
# Out:
# r2score corresponing to 42 is: 0.34200416714550097
# r2score corresponing to 43 is: 0.36035250765845883
# r2score corresponing to 44 is: 0.36687156645207497
# r2score corresponing to 45 is: 0.3184279906907107
# r2score corresponing to 46 is: 0.3569952423891045
# r2score corresponing to 47 is: 0.39467280399982607
# r2score corresponing to 48 is: 0.3372040102347855
# r2score corresponing to 49 is: 0.36288832945895033
# r2score corresponing to 50 is: 0.37300016868042196
# r2score corresponing to 51 is: 0.36600117373838514
# r2score corresponing to 52 is: 0.3311427883440682
# r2score corresponing to 53 is: 0.3755225663899171
# r2score corresponing to 54 is: 0.3853195381171768
# r2score corresponing to 55 is: 0.36924427422351924
# r2score corresponing to 56 is: 0.3410679188972964
# r2score corresponing to 57 is: 0.36899081962300007
# r2score corresponing to 58 is: 0.37412352803011717
# r2score corresponing to 59 is: 0.36282960574420897
# r2score corresponing to 60 is: 0.3885510535056417
# r2score corresponing to 61 is: 0.3635080634606337
# r2score corresponing to 62 is: 0.3414073582594599
# r2score corresponing to 63 is: 0.3751257554113868
# r2score corresponing to 64 is: 0.3401184906717416
# r2score corresponing to 65 is: 0.34749957508319684
# r2score corresponing to 66 is: 0.38876597903998755
# r2score corresponing to 67 is: 0.3586604862580308
# r2score corresponing to 68 is: 0.3521288114065214
# r2score corresponing to 69 is: 0.3771968513636125
# r2score corresponing to 70 is: 0.3680736222878377
# r2score corresponing to 71 is: 0.3537481217450875
# r2score corresponing to 72 is: 0.359602089464894
# r2score corresponing to 73 is: 0.35671446973642185
# r2score corresponing to 74 is: 0.3668854800039709
# r2score corresponing to 75 is: 0.36342342046750353
# r2score corresponing to 76 is: 0.3463319762509066
# r2score corresponing to 77 is: 0.33827201575197163
# r2score corresponing to 78 is: 0.3950948774668481
# r2score corresponing to 79 is: 0.3363561728933048
# r2score corresponing to 80 is: 0.37764985641773663
# r2score corresponing to 81 is: 0.3779584541442198
# r2score corresponing to 82 is: 0.3627370437027436
# r2score corresponing to 83 is: 0.3782153507748537
# r2score corresponing to 84 is: 0.3572054308355139
# r2score corresponing to 85 is: 0.36049635831165294
# r2score corresponing to 86 is: 0.3697025808150918
# r2score corresponing to 87 is: 0.3623543267372372
# r2score corresponing to 88 is: 0.3887285940755658
# r2score corresponing to 89 is: 0.3435164739597635
# r2score corresponing to 90 is: 0.36687924760032486
# r2score corresponing to 91 is: 0.38049234296238077
# r2score corresponing to 92 is: 0.388314278050257
# r2score corresponing to 93 is: 0.3555581976775736
# r2score corresponing to 94 is: 0.36574906361807213
# r2score corresponing to 95 is: 0.3800595737795267
# r2score corresponing to 96 is: 0.3504599459468466
# r2score corresponing to 97 is: 0.34194429556283135
# r2score corresponing to 98 is: 0.3550507292567222
# r2score corresponing to 99 is: 0.37626510454319617
# r2score corresponing to 100 is: 0.371688643528138
#
#
# max r2_score corresponding to  78 is 0.3950948774668481

# %%
#using GridSearchCV to find the best parameter
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
#creating a function to find the random_state coresponding to the maximum r2score
def maxr2_score(lsreg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        lsreg=Lasso(alpha=1)
        lsreg.fit(x_train,y_train)
        y_predict=lsreg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling using Lasso
lsreg=Lasso(alpha=1)
r_state=maxr2_score(lsreg,df_x,y)
# Out:
# r2score corresponing to 42 is: 0.34204400383722267
# r2score corresponing to 43 is: 0.3604417192333278
# r2score corresponing to 44 is: 0.3668814716123946
# r2score corresponing to 45 is: 0.3184579406109005
# r2score corresponing to 46 is: 0.3569736329372648
# r2score corresponing to 47 is: 0.3946392593765661
# r2score corresponing to 48 is: 0.3372517290510736
# r2score corresponing to 49 is: 0.3629235984068915
# r2score corresponing to 50 is: 0.37302360245277455
# r2score corresponing to 51 is: 0.3660078009858192
# r2score corresponing to 52 is: 0.33113426816962177
# r2score corresponing to 53 is: 0.37553516307430235
# r2score corresponing to 54 is: 0.38534421857440415
# r2score corresponing to 55 is: 0.3692410172483388
# r2score corresponing to 56 is: 0.34114737049880905
# r2score corresponing to 57 is: 0.3689819939825577
# r2score corresponing to 58 is: 0.3740515621019801
# r2score corresponing to 59 is: 0.36283348834561824
# r2score corresponing to 60 is: 0.38858027849211674
# r2score corresponing to 61 is: 0.36353871637984136
# r2score corresponing to 62 is: 0.34144147262544977
# r2score corresponing to 63 is: 0.37510498479039556
# r2score corresponing to 64 is: 0.34016899234580156
# r2score corresponing to 65 is: 0.3474164241530808
# r2score corresponing to 66 is: 0.3887387981022672
# r2score corresponing to 67 is: 0.358622555703046
# r2score corresponing to 68 is: 0.35211213673628416
# r2score corresponing to 69 is: 0.3771947398657468
# r2score corresponing to 70 is: 0.36807901037701796
# r2score corresponing to 71 is: 0.35377876558220933
# r2score corresponing to 72 is: 0.3595714228694653
# r2score corresponing to 73 is: 0.35667854217529726
# r2score corresponing to 74 is: 0.36687385020093166
# r2score corresponing to 75 is: 0.3634184484765932
# r2score corresponing to 76 is: 0.3463856369405969
# r2score corresponing to 77 is: 0.3382467834840045
# r2score corresponing to 78 is: 0.39513277210892195
# r2score corresponing to 79 is: 0.33637335186345474
# r2score corresponing to 80 is: 0.3776650511601428
# r2score corresponing to 81 is: 0.377972570408324
# r2score corresponing to 82 is: 0.3628039272586462
# r2score corresponing to 83 is: 0.37815654520445174
# r2score corresponing to 84 is: 0.35722950067321135
# r2score corresponing to 85 is: 0.36055767468957367
# r2score corresponing to 86 is: 0.36970161509428345
# r2score corresponing to 87 is: 0.36230360212640167
# r2score corresponing to 88 is: 0.3886740908211199
# r2score corresponing to 89 is: 0.34358261837351833
# r2score corresponing to 90 is: 0.3669078232447255
# r2score corresponing to 91 is: 0.38047044982272227
# r2score corresponing to 92 is: 0.38830668860117934
# r2score corresponing to 93 is: 0.3556251914287758
# r2score corresponing to 94 is: 0.36579864235888504
# r2score corresponing to 95 is: 0.38007213723788136
# r2score corresponing to 96 is: 0.3505044626309849
# r2score corresponing to 97 is: 0.34201263354459355
# r2score corresponing to 98 is: 0.3550586447507107
# r2score corresponing to 99 is: 0.3762599646168657
# r2score corresponing to 100 is: 0.37168001771695114
#
#
# max r2_score corresponding to  78 is 0.39513277210892195

# %%
#using GridSearchCV to find the best parameter
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 1000}

# %%
#creating a function to find the random_state coresponding to the maximum r2score
def maxr2_score(gbr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        gbr=GradientBoostingRegressor(learning_rate=0.1, n_estimators=1000)
        gbr.fit(x_train,y_train)
        y_predict=gbr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling using GradientBoostRegressor
gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=1000)
r_state=maxr2_score(gbr,df_x,y)
# Out:
# r2score corresponing to 42 is: 0.8120443514762617
# r2score corresponing to 43 is: 0.8086904962590132
# r2score corresponing to 44 is: 0.8167248739338129
# r2score corresponing to 45 is: 0.8103084131881091
# r2score corresponing to 46 is: 0.826554403746174
# r2score corresponing to 47 is: 0.8205464485976184
# r2score corresponing to 48 is: 0.8140874782265439
# r2score corresponing to 49 is: 0.8153116541488141
# r2score corresponing to 50 is: 0.8295378207305938
# r2score corresponing to 51 is: 0.8209501413140636
# r2score corresponing to 52 is: 0.8161347178144556
# r2score corresponing to 53 is: 0.8254855585312288
# r2score corresponing to 54 is: 0.8267833850133675
# r2score corresponing to 55 is: 0.8216075043168553
# r2score corresponing to 56 is: 0.8156874617232857
# r2score corresponing to 57 is: 0.8323613925879493
# r2score corresponing to 58 is: 0.8173088199196363
# r2score corresponing to 59 is: 0.8220548721747094
# r2score corresponing to 60 is: 0.8206525434189346
# r2score corresponing to 61 is: 0.8186524628235948
# r2score corresponing to 62 is: 0.8198650086366459
# r2score corresponing to 63 is: 0.8134379062341592
# r2score corresponing to 64 is: 0.7997108683630079
# r2score corresponing to 65 is: 0.8207915908406552
# r2score corresponing to 66 is: 0.8193604042894583
# r2score corresponing to 67 is: 0.8224528981096728
# r2score corresponing to 68 is: 0.8153372324790787
# r2score corresponing to 69 is: 0.8201772633346688
# r2score corresponing to 70 is: 0.8197015972582602
# r2score corresponing to 71 is: 0.8161125772915774
# r2score corresponing to 72 is: 0.8204330580201326
# r2score corresponing to 73 is: 0.8064119410358277
# r2score corresponing to 74 is: 0.821969657487427
# r2score corresponing to 75 is: 0.8173484295379899
# r2score corresponing to 76 is: 0.8166890302956845
# r2score corresponing to 77 is: 0.8148683815118167
# r2score corresponing to 78 is: 0.8236889323894141
# r2score corresponing to 79 is: 0.8092620948001442
# r2score corresponing to 80 is: 0.8199360522784067
# r2score corresponing to 81 is: 0.8235022036476282
# r2score corresponing to 82 is: 0.8131350480072579
# r2score corresponing to 83 is: 0.8165362522968975
# r2score corresponing to 84 is: 0.8305902260137088
# r2score corresponing to 85 is: 0.8133740686886601
# r2score corresponing to 86 is: 0.828101583446077
# r2score corresponing to 87 is: 0.8157765105786658
# r2score corresponing to 88 is: 0.8218636353456075
# r2score corresponing to 89 is: 0.80888439782414
# r2score corresponing to 90 is: 0.8092780014715978
# r2score corresponing to 91 is: 0.8346112459519801
# r2score corresponing to 92 is: 0.8282527873094909
# r2score corresponing to 93 is: 0.8187672721684551
# r2score corresponing to 94 is: 0.8141408679487221
# r2score corresponing to 95 is: 0.8337154576848859
# r2score corresponing to 96 is: 0.8321662018086464
# r2score corresponing to 97 is: 0.814536974447353
# r2score corresponing to 98 is: 0.8068826248131318
# r2score corresponing to 99 is: 0.816004241278822
# r2score corresponing to 100 is: 0.8211605188759825
#
#
# max r2_score corresponding to  91 is 0.8346112459519801

# %%
#using GridSearchCV to find the best parameter
from sklearn.ensemble import AdaBoostRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[regr,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 0.1,
#  'n_estimators': 1000}

# %%
#creating a function to find the random_state coresponding to the maximum r2score
def maxr2_score(ada_reg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
            max_leaf_nodes=None, min_impurity_decrease=0.0,
            min_impurity_split=None, min_samples_leaf=1,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=None, splitter='best'),
 learning_rate=0.1,
 n_estimators=1000)
        ada_reg.fit(x_train,y_train)
        y_predict=ada_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling using AdaBoostRegressor
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
            max_leaf_nodes=None, min_impurity_decrease=0.0,
            min_impurity_split=None, min_samples_leaf=1,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=None, splitter='best'),
 learning_rate=0.1,
 n_estimators=1000)
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2score corresponing to 42 is: 0.7635299912887051
# r2score corresponing to 43 is: 0.7678512115598704
# r2score corresponing to 44 is: 0.7677440207880022
# r2score corresponing to 45 is: 0.7509518350862844
# r2score corresponing to 46 is: 0.7818030722698138
# r2score corresponing to 47 is: 0.7671520427453169
# r2score corresponing to 48 is: 0.7598076150227234
# r2score corresponing to 49 is: 0.7328454770669268
# r2score corresponing to 50 is: 0.7577300830936249
# r2score corresponing to 51 is: 0.7723375274197534
# r2score corresponing to 52 is: 0.7566965705714208
# r2score corresponing to 53 is: 0.7699285285808812
# r2score corresponing to 54 is: 0.7761972450178085
# r2score corresponing to 55 is: 0.7903652870754987
# r2score corresponing to 56 is: 0.7757116492478385
# r2score corresponing to 57 is: 0.780819810426885
# r2score corresponing to 58 is: 0.7678049690234967
# r2score corresponing to 59 is: 0.7873245122118478
# r2score corresponing to 60 is: 0.7619687884345228
# r2score corresponing to 61 is: 0.7659634078499147
# r2score corresponing to 62 is: 0.7798156666229087
# r2score corresponing to 63 is: 0.7704031621516956
# r2score corresponing to 64 is: 0.7469403759270108
# r2score corresponing to 65 is: 0.7671092060221419
# r2score corresponing to 66 is: 0.7588859375615964
# r2score corresponing to 67 is: 0.7780768561453021
# r2score corresponing to 68 is: 0.7515159406107543
# r2score corresponing to 69 is: 0.7486662742794128
# r2score corresponing to 70 is: 0.7646147457872893
# r2score corresponing to 71 is: 0.7792204481677188
# r2score corresponing to 72 is: 0.7895018067666993
# r2score corresponing to 73 is: 0.7638152396681015
# r2score corresponing to 74 is: 0.7868719029969138
# r2score corresponing to 75 is: 0.7470759033826543
# r2score corresponing to 76 is: 0.7495910402634087
# r2score corresponing to 77 is: 0.770060750292332
# r2score corresponing to 78 is: 0.7641334825671473
# r2score corresponing to 79 is: 0.7756145990662191
# r2score corresponing to 80 is: 0.758516083630265
# r2score corresponing to 81 is: 0.7694103378976572
# r2score corresponing to 82 is: 0.7518039905239536
# r2score corresponing to 83 is: 0.7681545534611273
# r2score corresponing to 84 is: 0.7648800641918851
# r2score corresponing to 85 is: 0.7536113581658768
# r2score corresponing to 86 is: 0.7776210853337313
# r2score corresponing to 87 is: 0.7832261850493331
# r2score corresponing to 88 is: 0.7742114802682731
# r2score corresponing to 89 is: 0.7750379239613605
# r2score corresponing to 90 is: 0.7778420367471102
# r2score corresponing to 91 is: 0.7766186300614994
# r2score corresponing to 92 is: 0.7782294953783353
# r2score corresponing to 93 is: 0.763696778177337
# r2score corresponing to 94 is: 0.7568527799382896
# r2score corresponing to 95 is: 0.7794334709659234
# r2score corresponing to 96 is: 0.7750574005181707
# r2score corresponing to 97 is: 0.7616384339996214
# r2score corresponing to 98 is: 0.7435570189800093
# r2score corresponing to 99 is: 0.7551785508543032
# r2score corresponing to 100 is: 0.7656742343764906
#
#
# max r2_score corresponding to  55 is 0.7903652870754987

# %%
#checking for bias-variance tradeoff using cross_val_sccore for all the algorithm
from sklearn.model_selection import cross_val_score
import numpy as np
regr_score_mean=cross_val_score(regr,df_x,y,cv=5,scoring="r2").mean()
regr_score_std=cross_val_score(regr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of linearRegression :",regr_score_mean)
print("stadard deviation for r2 score of linearRegression :",regr_score_std)
knr_score_mean=cross_val_score(knr,df_x,y,cv=5,scoring="r2").mean()
knr_score_std=cross_val_score(knr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of knr:",knr_score_mean)
print("standard deviation of r2score for knr:",knr_score_std)
dtr_score_mean=cross_val_score(dtr,df_x,y,cv=5,scoring="r2").mean()
dtr_score_std=cross_val_score(dtr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of DecisionTreeRegression :",dtr_score_mean)
print("stadard deviation for r2 score of DecisionTreeeRegression :",dtr_score_std)
r_reg_score_mean=cross_val_score(r_reg,df_x,y,cv=5,scoring="r2").mean()
r_reg_score_std=cross_val_score(r_reg,df_x,y,cv=5,scoring="r2").std()
print("mean r2score for RidgeRegression:",r_reg_score_mean)
print("standard deviation in r2score for RidgeRegression:",r_reg_score_std)
Lsreg_score_mean=cross_val_score(lsreg,df_x,y,cv=5,scoring="r2").mean()
Lsreg_score_std=cross_val_score(lsreg,df_x,y,cv=5,scoring="r2").std()
print("mean r2score for Lasso:",Lsreg_score_mean)
print("standard deviation in r2score for lasso:",Lsreg_score_std)
gbr_score_mean=cross_val_score(gbr,df_x,y,cv=5,scoring="r2").mean()
gbr_score_std=cross_val_score(gbr,df_x,y,cv=5,scoring="r2").std()
print("mean r2score for GradientBoostRegression:",gbr_score_mean)
print("standard deviation in r2score for GradientBoostRegression:",gbr_score_std)
print("mean r2score for AdaBoostRegressor:",cross_val_score(ada_reg,df_x,y,cv=5,scoring="r2").mean())
print("standard deviationof  r2score for AdaBoostRegressor:",cross_val_score(ada_reg,df_x,y,cv=5,scoring="r2").std())
# Out:
# mean r2 score of linearRegression : 0.3594103712808028
# stadard deviation for r2 score of linearRegression : 0.01060965491060818
# mean r2 score of knr: 0.6571412611435641
# standard deviation of r2score for knr: 0.023965077020554747
# mean r2 score of DecisionTreeRegression : 0.6682669231751335
# stadard deviation for r2 score of DecisionTreeeRegression : 0.020856439071965306
# mean r2score for RidgeRegression: 0.3594107346257541
# standard deviation in r2score for RidgeRegression: 0.010606588761104308
# mean r2score for Lasso: 0.359418644394648
# standard deviation in r2score for lasso: 0.010615638998182948
# mean r2score for GradientBoostRegression: 0.8193125764240374
# standard deviation in r2score for GradientBoostRegression: 0.008118025426803505
# mean r2score for AdaBoostRegressor: 0.7635765664665677
# standard deviationof  r2score for AdaBoostRegressor: 0.016498508017909145

# %% [markdown]
# # Since GradientBoostRegressor gives a r2 score of 83.47  at random state of 91 so using this as algoritm and random state to divide the data into testing and training data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=91,test_size=0.20)
gbr.fit(x_train,y_train)
y_pred=gbr.predict(x_test)

# %%
print("r2score is",r2_score(y_test,y_pred))
print("root mean squared error is",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2score is 0.8347196840830502
# root mean squared error is 1650.475858985599

# %%
#save the model
from sklearn.externals import joblib
joblib.dump(gbr,"gbr_airline.pkl")
# Out:
# ['gbr_airline.pkl']

# %% [markdown]
# # using GradientBoostingRegressor as algorithm to dump using joblib because it also overcomes the overfitting and underfitting problem and provides the best r2score and crossval score among the other algorithm
