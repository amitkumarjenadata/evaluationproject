# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
#importing the required library

# %%
#upload the csv file and providing the column names
census_data=pd.read_csv("adult.csv",names=["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country","income"])

# %%
#head or first five data of the dataset
census_data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
#datatype of each column in the dataset
census_data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
census_data.describe()
#statistical description of the data (mean,standard deviation etc)
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#no null data present in the dataset
census_data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
#heatmap shows that the data doesnot contain any null data
sns.heatmap(census_data.isnull())

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
census_data['workclass']=le.fit_transform(census_data['workclass'].astype(str))
census_data['education']=le.fit_transform(census_data['education'].astype(str))
census_data['marital-status']=le.fit_transform(census_data['marital-status'].astype(str))
census_data['occupation']=le.fit_transform(census_data['occupation'].astype(str))
census_data['relationship']=le.fit_transform(census_data['relationship'].astype(str))
census_data['race']=le.fit_transform(census_data['race'].astype(str))
census_data['sex']=le.fit_transform(census_data['sex'].astype(str))
census_data['native-country']=le.fit_transform(census_data['native-country'].astype(str))
census_data['income']=le.fit_transform(census_data['income'].astype(str))
#using labelEncoder converting the catergorical columns to numerical form

# %%
census_data.corr()
#correlation matrix of the data
# Out:
#                      age  workclass    fnlwgt  education  education-num  \
# age             1.000000   0.003787 -0.076646  -0.010508       0.036527
# workclass       0.003787   1.000000 -0.016656   0.023513       0.052085
# fnlwgt         -0.076646  -0.016656  1.000000  -0.028145      -0.043195
# education      -0.010508   0.023513 -0.028145   1.000000       0.359153
# education-num   0.036527   0.052085 -0.043195   0.359153       1.000000
# marital-status -0.266288  -0.064731  0.028153  -0.038407      -0.069304
# occupation     -0.020947   0.254892  0.001597  -0.021260       0.109697
# relationship   -0.263698  -0.090461  0.008931  -0.010876      -0.094153
# race            0.028718   0.049742 -0.021291   0.014131       0.031838
# sex             0.088832   0.095981  0.026858  -0.027356       0.012280
# capital-gain    0.077674   0.033835  0.000432   0.030046       0.122630
# capital-loss    0.057775   0.012216 -0.010252   0.016746       0.079923
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(census_data.corr())
#most of the data is mildly correlated as we can see it in the heatmap

# %%
from scipy.stats import zscore
z_score=abs(zscore(census_data))
print(census_data.shape)
census_data=census_data.loc[(z_score<3).all(axis=1)]
print(census_data.shape)
#may outliers are present changing the shape of the data from 32561,15 to 27418,15
# Out:
# (32561, 15)
# (27418, 15)

# %%
#pairplot of the data shows the relation between individual column
sns.pairplot(census_data)

# %%
#pairplot of the data categorised according to the income status
sns.pairplot(census_data,hue="income")

# %%
census_data.plot(kind='box', subplots=True, layout=(4,4), sharex=False, sharey=False,figsize=(10,10))
plt.tight_layout()
#box plot shows the outliers,min,max mean.25th and 75th percentile in each column

# %%
#shows the data distribution of the age column
sns.distplot(census_data["age"])

# %%
#shows the data distribution of the fnlwgt column
sns.distplot(census_data["fnlwgt"])

# %%
#shows the data distribution of the capital-gain column
sns.distplot(census_data["capital-gain"])

# %%
sns.distplot(census_data["capital-loss"])
#shows the data distribution of the capital-loss column

# %%
sns.distplot(census_data["hours-per-week"])
##shows the data distribution of the hours-per-week column

# %%
#relationship between age and income column
sns.jointplot(x="age",y="income",data=census_data)

# %%
#relationship between hous-per-week and income column
sns.jointplot(x="hours-per-week",y="income",data=census_data)

# %%
#relationship between age and hours-per-week column
sns.jointplot(x="age",y="hours-per-week",data=census_data)

# %%
#visualization with violin plot for age column shows that most of the age in data is between 20-40
sns.violinplot(census_data["age"])

# %%
#visualization with violin plot for hours-per-week column shows that most of them lies in the 40 hours region
sns.violinplot(census_data["hours-per-week"])

# %%
#visualization with violin plot for fnlwgt column
sns.violinplot(census_data["fnlwgt"])

# %%
#countplot of the income column
sns.countplot(census_data["income"])

# %%
#countplot of the sex column 
sns.countplot(census_data["sex"])

# %%
#histogram of each of the column in dataset
census_data.hist(figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024968E87948>,
# ...
#       dtype=object)

# %%
#dividing the data according to input and output
x=census_data.drop(columns=['income'])
x=pd.DataFrame(census_data.iloc[:,:15])
y=pd.DataFrame(census_data['income'])

# %%
#it shows that some of the data columns are skewed
x.skew()
# Out:
# age                0.483480
# workclass         -0.737714
# fnlwgt             0.626258
# education         -0.957433
# education-num     -0.144018
# marital-status    -0.044388
# occupation         0.131200
# relationship       0.750249
# race              -2.592997
# sex               -0.684173
# capital-gain       4.934777
# capital-loss      29.326272
# hours-per-week    -0.358404
# native-country    -5.460784
# income             1.324975
# dtype: float64

# %%
#removing the skewness using logrithmic function
for col in x.columns:
    if x.skew().loc[col]>0.55:
        x[col]=np.log1p(x[col])

# %%
#skewness removed
x.skew()
# Out:
# age                0.483480
# workclass         -0.737714
# fnlwgt            -0.955471
# education         -0.957433
# education-num     -0.144018
# marital-status    -0.044388
# occupation         0.131200
# relationship       0.252970
# race              -2.592997
# sex               -0.684173
# capital-gain       3.111997
# capital-loss      24.847394
# hours-per-week    -0.358404
# native-country    -5.460784
# income             1.324975
# dtype: float64

# %%
#scaling the data 
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_x=sc.fit_transform(x)
df_x=pd.DataFrame(df_x,columns=x.columns)

# %%
from sklearn.model_selection import GridSearchCV

# %%
#splitting the data
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2,stratify=y)

# %%
#importing the appropiate algorithms
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %%
#creating an object of the algorithms
knn=KNeighborsClassifier()
sv=SVC()
dt=DecisionTreeClassifier(random_state=6)
lr=LogisticRegression()
rf=RandomForestClassifier()

# %%
#using GridsearchCV for hyperparameter tuning
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
neighbors={"n_neighbors":range(1,30)}
gknn=GridSearchCV(knn,neighbors,cv=10)
gknn.fit(x,y)
gknn.best_params_
# Out:
# {'n_neighbors': 14}

# %%
#using GridsearchCV for hyperparameter tuning
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
grid_param={"random_state":range(0,20),"criterion":['gini','entropy']}
Gdt=GridSearchCV(dt,param_grid=grid_param,scoring='accuracy',cv=10)
Gdt.fit(x,y)
Gdt.best_params_
# Out:
# {'criterion': 'gini', 'random_state': 0}

# %%
#using GridsearchCV for hyperparameter tuning
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
kernel={"kernel":["linear","rbf","poly"]}
Gsv=GridSearchCV(sv,kernel,cv=10)
Gsv.fit(x,y)
Gsv.best_params_
# Out:
# {'kernel': 'linear'}

# %%
#using GridsearchCV for hyperparameter tuning
from sklearn.ensemble import AdaBoostClassifier
ada_class=AdaBoostClassifier()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lr,dt]}
clf=GridSearchCV(ada_class,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=6, splitter='best'),
#  'learning_rate': 0.001,
#  'n_estimators': 10}

# %%
#imoprting XGBoost algorithm
import xgboost as xgb
xgc=xgb.XGBClassifier()

# %%
#proving the parameters obtained in GridsearchCV to the algorithm for best results
knn=KNeighborsClassifier(n_neighbors=14)
sv=SVC(kernel="linear")
dt=DecisionTreeClassifier(random_state=0,criterion="gini")
lr=LogisticRegression()
rf=RandomForestClassifier()
ada_class=AdaBoostClassifier(base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
                        max_features=None, max_leaf_nodes=None,
                        min_impurity_decrease=0.0, min_impurity_split=None,
                        min_samples_leaf=1, min_samples_split=2,
                        min_weight_fraction_leaf=0.0, presort=False,
                        random_state=6, splitter='best'),
 learning_rate=0.001,
 n_estimators=10)
gnb=GaussianNB()

# %%
models=[]
models.append(("GaussianNB",gnb))
models.append(("KNeighborsClassifier",knn))
models.append(("SVC",sv))
models.append(("DecisionTreeClassifier",dt))
models.append(("LogisticRegression",lr))
models.append(("RandomForestClassifier",rf))
models.append(("AdaBoostClassifier",ada_class))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Model=[]
score=[]
cvs=[]
roc_score=[]
for name,model in models:
    print('*********************',name,'***************************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print("accuracy_score",AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring="accuracy").mean()
    print("cross_val_score=",sc)
    cvs.append(sc*100)
    false_positive_rate,true_positive_rate,threshold=roc_curve(y_test,pre)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print("roc_auc_score=",roc_auc)
    roc_score.append(roc_auc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print("\n")
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True positive rate')
    plt.xlabel('False positive rate')
    print('\n\n')
# Out:
# ********************* GaussianNB ***************************
#
#
# GaussianNB(priors=None, var_smoothing=1e-09)
#
#
# accuracy_score 1.0
#
#
# cross_val_score= 1.0
# roc_auc_score= 1.0
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4256
#            1       1.00      1.00      1.00      1228
#
#     accuracy                           1.00      5484
#    macro avg       1.00      1.00      1.00      5484
# weighted avg       1.00      1.00      1.00      5484
#
#
#
# [[4256    0]
#  [   0 1228]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ********************* KNeighborsClassifier ***************************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=14, p=2,
#                      weights='uniform')
#
#
# accuracy_score 0.8440919037199125
#
#
# ...

# %%
result=pd.DataFrame({'Model':Model,'Accuracy_score':score,'Cross_Val_Score':cvs,'roc_auc_curve':roc_score})
result
# Out:
#                     Model  Accuracy_score  Cross_Val_Score  roc_auc_curve
# 0              GaussianNB       100.00000       100.000000     100.000000
# 1    KNeighborsClassifier        84.40919        84.309631      74.196497
# 2                     SVC       100.00000       100.000000     100.000000
# 3  DecisionTreeClassifier       100.00000       100.000000     100.000000
# 4      LogisticRegression       100.00000       100.000000     100.000000
# 5  RandomForestClassifier       100.00000        99.992705     100.000000
# 6      AdaBoostClassifier       100.00000       100.000000     100.000000

# %%
from sklearn.externals import joblib
joblib.dump(rf,"rf_loan_data.pkl")
# Out:
# ['rf_loan_data.pkl']

# %% [markdown]
# # #as we can see the that algorithm provides excellent accuracy,cross-val and auc-roc score the model choosen if randomforestclassifier as it also take into account the underfitting and overfitting problem
