# %%
#importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#uploading the csv and providing names to the columnss
abalone_data=pd.read_csv("abalone.csv",names=["sex","lenghth","diameter","height",
                                             'whole_weight',"shucked_weight","viscera_weight","shell_weight","rings"],header=0)

# %%
#head of the dataset
abalone_data.head()
# Out:
#   sex  lenghth  diameter  height  whole_weight  shucked_weight  \
# 0   M    0.350     0.265   0.090        0.2255          0.0995
# 1   F    0.530     0.420   0.135        0.6770          0.2565
# 2   M    0.440     0.365   0.125        0.5160          0.2155
# 3   I    0.330     0.255   0.080        0.2050          0.0895
# 4   I    0.425     0.300   0.095        0.3515          0.1410
#
#    viscera_weight  shell_weight  rings
# 0          0.0485         0.070      7
# 1          0.1415         0.210      9
# 2          0.1140         0.155     10
# 3          0.0395         0.055      7
# 4          0.0775         0.120      8

# %%
#statistical description of the dataset
abalone_data.describe()
# Out:
#            lenghth     diameter       height  whole_weight  shucked_weight  \
# count  4176.000000  4176.000000  4176.000000   4176.000000      4176.00000
# mean      0.524009     0.407892     0.139527      0.828818         0.35940
# std       0.120103     0.099250     0.041826      0.490424         0.22198
# min       0.075000     0.055000     0.000000      0.002000         0.00100
# 25%       0.450000     0.350000     0.115000      0.441500         0.18600
# 50%       0.545000     0.425000     0.140000      0.799750         0.33600
# 75%       0.615000     0.480000     0.165000      1.153250         0.50200
# max       0.815000     0.650000     1.130000      2.825500         1.48800
#
#        viscera_weight  shell_weight        rings
# count     4176.000000   4176.000000  4176.000000
# mean         0.180613      0.238852     9.932471
# std          0.109620      0.139213     3.223601
# min          0.000500      0.001500     1.000000
# 25%          0.093375      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
#the shape of the dataset
abalone_data.shape
# Out:
# (4176, 9)

# %%
#counts of sex present in the dataset
abalone_data["sex"].value_counts()
# Out:
# M    1527
# I    1342
# F    1307
# Name: sex, dtype: int64

# %%
#countplot (visualization of the count of sex column )
sns.countplot(x='sex',data=abalone_data)

# %%
#value counts of the rings in the dataset
abalone_data["rings"].value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    102
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 24      2
# 27      2
# 1       1
# 25      1
# 2       1
# 26      1
# 29      1
# Name: rings, dtype: int64

# %%
#no missing data present 
abalone_data.isnull().sum()
# Out:
# sex               0
# lenghth           0
# diameter          0
# height            0
# whole_weight      0
# shucked_weight    0
# viscera_weight    0
# shell_weight      0
# rings             0
# dtype: int64

# %%
#no missing data present in the dataset
sns.heatmap(abalone_data.isnull())

# %%
#pairplot of abalone data categorised according to sex
sns.pairplot(abalone_data,hue="sex")

# %%
#scatter_matrix of the data with each column
from pandas.plotting import scatter_matrix
scatter_matrix(abalone_data,figsize=(15,10))
plt.show()

# %%
#histogram plot of each column
abalone_data.hist(figsize=(15,10))
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
abalone_data['sex']=le.fit_transform(abalone_data['sex'].astype(str))
abalone_data.head()
#using labelEncoder converting the sex column to numerical form
# Out:
#    sex  lenghth  diameter  height  whole_weight  shucked_weight  \
# 0    2    0.350     0.265   0.090        0.2255          0.0995
# 1    0    0.530     0.420   0.135        0.6770          0.2565
# 2    2    0.440     0.365   0.125        0.5160          0.2155
# 3    1    0.330     0.255   0.080        0.2050          0.0895
# 4    1    0.425     0.300   0.095        0.3515          0.1410
#
#    viscera_weight  shell_weight  rings
# 0          0.0485         0.070      7
# 1          0.1415         0.210      9
# 2          0.1140         0.155     10
# 3          0.0395         0.055      7
# 4          0.0775         0.120      8

# %%
abalone_data.skew()
#checking the skewness shows that height,shucked_weight,viscera_weight,shell_weight,rings are skewed
# Out:
# sex              -0.097729
# lenghth          -0.640240
# diameter         -0.609457
# height            3.129241
# whole_weight      0.530576
# shucked_weight    0.718724
# viscera_weight    0.591463
# shell_weight      0.620547
# rings             1.115157
# dtype: float64

# %%
#removing skewness using log function
import numpy as np
for col in abalone_data.columns:
    if abalone_data.skew().loc[col]>0.55:
        abalone_data[col]=np.log1p(abalone_data[col])

# %%
abalone_data.skew()
# Out:
# sex              -0.097729
# lenghth          -0.640240
# diameter         -0.609457
# height            1.099478
# whole_weight      0.530576
# shucked_weight    0.306070
# viscera_weight    0.375234
# shell_weight      0.314939
# rings            -0.061065
# dtype: float64

# %%
df_x=abalone_data.drop(columns=["rings"])
y=abalone_data[["rings"]]
#dividing data into input and output

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_predict=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#function to find the maxr2_score corresponding to the random state

# %%
regr=linear_model.LinearRegression()
r_state=maxr2_score(regr,df_x,y)
#calling the function using linearRegression algorithm
# Out:
# r2score corresponing to 42 is: 0.6225957097241408
# r2score corresponing to 43 is: 0.5482915901151195
# r2score corresponing to 44 is: 0.5771842391442987
# r2score corresponing to 45 is: 0.59662642803474
# r2score corresponing to 46 is: 0.6067368502847512
# r2score corresponing to 47 is: 0.5779495429710784
# r2score corresponing to 48 is: 0.5608780443832959
# r2score corresponing to 49 is: 0.5673511170649479
# r2score corresponing to 50 is: 0.5796819679680998
# r2score corresponing to 51 is: 0.5948417215039716
# r2score corresponing to 52 is: 0.5475252084029106
# r2score corresponing to 53 is: 0.5853705060390586
# r2score corresponing to 54 is: 0.5431028683562457
# r2score corresponing to 55 is: 0.5924246540019982
# r2score corresponing to 56 is: 0.5712932954567788
# r2score corresponing to 57 is: 0.5789067947268183
# r2score corresponing to 58 is: 0.6238274304880236
# r2score corresponing to 59 is: 0.6404211058399051
# r2score corresponing to 60 is: 0.5493755971783982
# r2score corresponing to 61 is: 0.6068311767017286
# r2score corresponing to 62 is: 0.5707607812971817
# r2score corresponing to 63 is: 0.5859158262691224
# r2score corresponing to 64 is: 0.532849929892101
# r2score corresponing to 65 is: 0.531452775968333
# r2score corresponing to 66 is: 0.5923224945521189
# r2score corresponing to 67 is: 0.5479066204895633
# r2score corresponing to 68 is: 0.5886624845920627
# r2score corresponing to 69 is: 0.5960942893294947
# r2score corresponing to 70 is: 0.6067677674021699
# r2score corresponing to 71 is: 0.6060032272796366
# r2score corresponing to 72 is: 0.559399047985085
# r2score corresponing to 73 is: 0.5812583085388099
# r2score corresponing to 74 is: 0.5966089454253962
# r2score corresponing to 75 is: 0.5559105495011847
# r2score corresponing to 76 is: 0.5918399353998647
# r2score corresponing to 77 is: 0.5893195365353892
# r2score corresponing to 78 is: 0.5828697563188732
# r2score corresponing to 79 is: 0.5416219573415539
# r2score corresponing to 80 is: 0.6137952380394216
# r2score corresponing to 81 is: 0.5413153510485049
# r2score corresponing to 82 is: 0.5830066585316614
# r2score corresponing to 83 is: 0.5843907393279553
# r2score corresponing to 84 is: 0.618863530524864
# r2score corresponing to 85 is: 0.5175735046359671
# r2score corresponing to 86 is: 0.5817107228420004
# r2score corresponing to 87 is: 0.5568429810952702
# r2score corresponing to 88 is: 0.6069504964668442
# r2score corresponing to 89 is: 0.6181674781885718
# r2score corresponing to 90 is: 0.5872160186641906
# r2score corresponing to 91 is: 0.5171574416803952
# r2score corresponing to 92 is: 0.5746758297910566
# r2score corresponing to 93 is: 0.5940046647730313
# r2score corresponing to 94 is: 0.5832278336802997
# r2score corresponing to 95 is: 0.5684750940770211
# r2score corresponing to 96 is: 0.5627889819507221
# r2score corresponing to 97 is: 0.5791294663382068
# r2score corresponing to 98 is: 0.5680116020407869
# r2score corresponing to 99 is: 0.5951980968539399
# r2score corresponing to 100 is: 0.5807671342166968
#
#
# max r2_score corresponding to  59 is 0.6404211058399051

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(df_x,y)
gknr.best_params_
#using GridSearchCV to get the best parameters for hyperparameter tuning
# Out:
# {'n_neighbors': 15}

# %%
def maxr2_score(knr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        knr=KNeighborsRegressor(n_neighbors=15)
        knr.fit(x_train,y_train)
        y_predict=knr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#function to find the maxr2_score corresponding to the random state

# %%
knr=KNeighborsRegressor(n_neighbors=15)
r_state=maxr2_score(knr,df_x,y)
#calling the function using KNeighborsRegressor
# Out:
# r2score corresponing to 42 is: 0.6370375242149646
# r2score corresponing to 43 is: 0.5746717232104348
# r2score corresponing to 44 is: 0.6262886513584713
# r2score corresponing to 45 is: 0.6254058781540579
# r2score corresponing to 46 is: 0.634619058925328
# r2score corresponing to 47 is: 0.6174961464945258
# r2score corresponing to 48 is: 0.6135962689851435
# r2score corresponing to 49 is: 0.5944219544529462
# r2score corresponing to 50 is: 0.6053339298087522
# r2score corresponing to 51 is: 0.6244190496734562
# r2score corresponing to 52 is: 0.5803549078355531
# r2score corresponing to 53 is: 0.6283429591537557
# r2score corresponing to 54 is: 0.5682578499604005
# r2score corresponing to 55 is: 0.6063583615392238
# r2score corresponing to 56 is: 0.6146681734448312
# r2score corresponing to 57 is: 0.5979463908568026
# r2score corresponing to 58 is: 0.6398553134146975
# r2score corresponing to 59 is: 0.6531803287233467
# r2score corresponing to 60 is: 0.5763202073010479
# r2score corresponing to 61 is: 0.6248656925892886
# r2score corresponing to 62 is: 0.5973396223901875
# r2score corresponing to 63 is: 0.6229284949390823
# r2score corresponing to 64 is: 0.6163290529159645
# r2score corresponing to 65 is: 0.5962306859162517
# r2score corresponing to 66 is: 0.6057254112384567
# r2score corresponing to 67 is: 0.6250330454441786
# r2score corresponing to 68 is: 0.5920555999955466
# r2score corresponing to 69 is: 0.6192266214094793
# r2score corresponing to 70 is: 0.6286985942678297
# r2score corresponing to 71 is: 0.6233200579123614
# r2score corresponing to 72 is: 0.5599684013818262
# r2score corresponing to 73 is: 0.6138663288058854
# r2score corresponing to 74 is: 0.6102575067152027
# r2score corresponing to 75 is: 0.58372655447808
# r2score corresponing to 76 is: 0.6322718495680877
# r2score corresponing to 77 is: 0.645414922032072
# r2score corresponing to 78 is: 0.6127646100938271
# r2score corresponing to 79 is: 0.6304590108608056
# r2score corresponing to 80 is: 0.6266550525688768
# r2score corresponing to 81 is: 0.6010982520489376
# r2score corresponing to 82 is: 0.6397320648702588
# r2score corresponing to 83 is: 0.6012882676992888
# r2score corresponing to 84 is: 0.6228001781286261
# r2score corresponing to 85 is: 0.6016318690674147
# r2score corresponing to 86 is: 0.6241841503853229
# r2score corresponing to 87 is: 0.5907735152498994
# r2score corresponing to 88 is: 0.646884772158594
# r2score corresponing to 89 is: 0.6449220109351687
# r2score corresponing to 90 is: 0.6023525118583803
# r2score corresponing to 91 is: 0.5935745852160568
# r2score corresponing to 92 is: 0.611358662960932
# r2score corresponing to 93 is: 0.6243365318498775
# r2score corresponing to 94 is: 0.6276409565327226
# r2score corresponing to 95 is: 0.5869234896857471
# r2score corresponing to 96 is: 0.593792107280096
# r2score corresponing to 97 is: 0.5990448232144232
# r2score corresponing to 98 is: 0.6061195169731323
# r2score corresponing to 99 is: 0.6581972372040947
# r2score corresponing to 100 is: 0.6087445477197346
#
#
# max r2_score corresponding to  99 is 0.6581972372040947

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
grid_param={"random_state":range(0,20)}
Gdt=GridSearchCV(dtr,param_grid=grid_param,scoring='r2',cv=10)
Gdt.fit(df_x,y)
Gdt.best_params_
#using GridSearchCV to find the best parameter for hyperparameter tuning
# Out:
# {'random_state': 6}

# %%
def maxr2_score(dtr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        dtr=DecisionTreeRegressor(random_state=6)
        dtr.fit(x_train,y_train)
        y_predict=dtr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#function to find the maxr2_score corresponding to the random state

# %%
knr=DecisionTreeRegressor(random_state=6)
r_state=maxr2_score(dtr,df_x,y)
#calling the function using DecisionTreeRegressor
# Out:
# r2score corresponing to 42 is: 0.374233491983901
# r2score corresponing to 43 is: 0.20163073983561752
# r2score corresponing to 44 is: 0.1878808188838459
# r2score corresponing to 45 is: 0.33342688233470796
# r2score corresponing to 46 is: 0.28937769304334393
# r2score corresponing to 47 is: 0.31631361509334543
# r2score corresponing to 48 is: 0.21160592636098918
# r2score corresponing to 49 is: 0.30451432357035413
# r2score corresponing to 50 is: 0.24068636176715263
# r2score corresponing to 51 is: 0.23969009058540747
# r2score corresponing to 52 is: 0.16904941416637342
# r2score corresponing to 53 is: 0.30642467936322637
# r2score corresponing to 54 is: 0.24238554753531338
# r2score corresponing to 55 is: 0.29000567206631733
# r2score corresponing to 56 is: 0.19220978166546876
# r2score corresponing to 57 is: 0.34716041254867713
# r2score corresponing to 58 is: 0.325124977672799
# r2score corresponing to 59 is: 0.3085218107484793
# r2score corresponing to 60 is: 0.2813057404700192
# r2score corresponing to 61 is: 0.33088994876158295
# r2score corresponing to 62 is: 0.1905068297245761
# r2score corresponing to 63 is: 0.35607478540289517
# r2score corresponing to 64 is: 0.3174655975574554
# r2score corresponing to 65 is: 0.28160020450537926
# r2score corresponing to 66 is: 0.29221704644702706
# r2score corresponing to 67 is: 0.25317436516499736
# r2score corresponing to 68 is: 0.243060734841674
# r2score corresponing to 69 is: 0.3941853295140547
# r2score corresponing to 70 is: 0.3006751702670625
# r2score corresponing to 71 is: 0.26205075146446144
# r2score corresponing to 72 is: 0.27810441992604074
# r2score corresponing to 73 is: 0.33767911759708646
# r2score corresponing to 74 is: 0.3120830063090735
# r2score corresponing to 75 is: 0.27092938601090844
# r2score corresponing to 76 is: 0.26334203144308754
# r2score corresponing to 77 is: 0.2861812659617443
# r2score corresponing to 78 is: 0.29958800180953216
# r2score corresponing to 79 is: 0.3088316065513035
# r2score corresponing to 80 is: 0.22629456165691464
# r2score corresponing to 81 is: 0.2519223663699548
# r2score corresponing to 82 is: 0.2955801328870986
# r2score corresponing to 83 is: 0.314086396917194
# r2score corresponing to 84 is: 0.32402840099140096
# r2score corresponing to 85 is: 0.2924950067018649
# r2score corresponing to 86 is: 0.302560837352963
# r2score corresponing to 87 is: 0.2616472659017095
# r2score corresponing to 88 is: 0.3326064672861062
# r2score corresponing to 89 is: 0.30560377360049495
# r2score corresponing to 90 is: 0.2837036543072664
# r2score corresponing to 91 is: 0.3210755830838192
# r2score corresponing to 92 is: 0.3069355941813009
# r2score corresponing to 93 is: 0.35873413813008104
# r2score corresponing to 94 is: 0.30684041623603264
# r2score corresponing to 95 is: 0.20406952579325321
# r2score corresponing to 96 is: 0.22021898012664287
# r2score corresponing to 97 is: 0.2759303234703372
# r2score corresponing to 98 is: 0.2325216970080325
# r2score corresponing to 99 is: 0.3212545866612403
# r2score corresponing to 100 is: 0.25766396237855094
#
#
# max r2_score corresponding to  69 is 0.3941853295140547

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
regr_score_mean=cross_val_score(regr,df_x,y,cv=5,scoring="r2").mean()
regr_score_std=cross_val_score(regr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of linearRegression :",regr_score_mean)
print("stadard deviation for r2 score of linearRegression :",regr_score_std)
knr_score_mean=cross_val_score(knr,df_x,y,cv=5,scoring="r2").mean()
knr_score_std=cross_val_score(knr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of knr:",knr_score_mean)
print("standard deviation of r2score for knr:",knr_score_std)
dtr_score_mean=cross_val_score(dtr,df_x,y,cv=5,scoring="r2").mean()
dtr_score_std=cross_val_score(dtr,df_x,y,cv=5,scoring="r2").std()
print("mean r2 score of DecisionTrennRegression :",dtr_score_mean)
print("stadard deviation for r2 score of DecisionTreeeRegression :",dtr_score_std)
#using cross_val_score determining the bias-variance tradeoff
# Out:
# mean r2 score of linearRegression : 0.5075020676767924
# stadard deviation for r2 score of linearRegression : 0.06309920788966891
# mean r2 score of knr: 0.5583541731983077
# standard deviation of r2score for knr: 0.054672838438552925
# mean r2 score of DecisionTrennRegression : 0.16769345569336713
# stadard deviation for r2 score of DecisionTreeeRegression : 0.1296779299701542

# %%
from sklearn.svm import SVR
import warnings
warnings.filterwarnings("ignore")

sv=SVR()

parameters={"kernel":['linear','poly','rbf']}
clf=GridSearchCV(sv,parameters,cv=5)
clf.fit(df_x,y)
clf.best_params_
#using GridSearchCV to find the best parameter for hyperparameter tuning
# Out:
# {'kernel': 'rbf'}

# %%
def maxr2_score(sv,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        sv=SVR(kernel="rbf")
        sv.fit(x_train,y_train)
        y_predict=sv.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#function to find the maxr2_score corresponding to the random state

# %%
sv=SVR(kernel="rbf")
r_state=maxr2_score(sv,df_x,y)
#calling the function using Supprt Vector Regressor
# Out:
# r2score corresponing to 42 is: 0.6553891818131483
# r2score corresponing to 43 is: 0.5730147605317704
# r2score corresponing to 44 is: 0.6274085090361863
# r2score corresponing to 45 is: 0.6291074237988423
# r2score corresponing to 46 is: 0.64382792139815
# r2score corresponing to 47 is: 0.6212645670204222
# r2score corresponing to 48 is: 0.6108276425110841
# r2score corresponing to 49 is: 0.5988635216723319
# r2score corresponing to 50 is: 0.620518589200715
# r2score corresponing to 51 is: 0.6311878443457006
# r2score corresponing to 52 is: 0.5820326610842581
# r2score corresponing to 53 is: 0.6343895353631315
# r2score corresponing to 54 is: 0.5864717711577668
# r2score corresponing to 55 is: 0.6354088932704298
# r2score corresponing to 56 is: 0.6149955268253224
# r2score corresponing to 57 is: 0.6070326011629592
# r2score corresponing to 58 is: 0.6511620691067221
# r2score corresponing to 59 is: 0.6667718419070949
# r2score corresponing to 60 is: 0.5926692227217487
# r2score corresponing to 61 is: 0.6337207060863348
# r2score corresponing to 62 is: 0.5983644444987861
# r2score corresponing to 63 is: 0.6166373412394279
# r2score corresponing to 64 is: 0.6209372098365809
# r2score corresponing to 65 is: 0.6038895226406866
# r2score corresponing to 66 is: 0.6220266175515561
# r2score corresponing to 67 is: 0.6253731340289441
# r2score corresponing to 68 is: 0.6151277732997322
# r2score corresponing to 69 is: 0.6277757181264622
# r2score corresponing to 70 is: 0.6294886490707473
# r2score corresponing to 71 is: 0.6385632220782306
# r2score corresponing to 72 is: 0.5840073770418273
# r2score corresponing to 73 is: 0.6097069441874826
# r2score corresponing to 74 is: 0.6151175393962259
# r2score corresponing to 75 is: 0.5861807185760035
# r2score corresponing to 76 is: 0.6414511421891511
# r2score corresponing to 77 is: 0.6351894056197342
# r2score corresponing to 78 is: 0.6191054871622355
# r2score corresponing to 79 is: 0.6329373413644814
# r2score corresponing to 80 is: 0.6368399525658115
# r2score corresponing to 81 is: 0.5984001456162255
# r2score corresponing to 82 is: 0.6250174029285225
# r2score corresponing to 83 is: 0.6179195843383418
# r2score corresponing to 84 is: 0.6459145619479865
# r2score corresponing to 85 is: 0.6105663019347742
# r2score corresponing to 86 is: 0.6168438482880622
# r2score corresponing to 87 is: 0.5918069933467985
# r2score corresponing to 88 is: 0.6431046705917729
# r2score corresponing to 89 is: 0.6512422613831741
# r2score corresponing to 90 is: 0.6135615880545289
# r2score corresponing to 91 is: 0.5997692825481789
# r2score corresponing to 92 is: 0.6117962082938684
# r2score corresponing to 93 is: 0.6354998478147184
# r2score corresponing to 94 is: 0.6223510798131964
# r2score corresponing to 95 is: 0.5996979498337263
# r2score corresponing to 96 is: 0.590385232073033
# r2score corresponing to 97 is: 0.6043434115535334
# r2score corresponing to 98 is: 0.602545694903261
# r2score corresponing to 99 is: 0.642872311647231
# r2score corresponing to 100 is: 0.6116519369784127
#
#
# max r2_score corresponding to  59 is 0.6667718419070949

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(df_x,y)
clf.best_params_
#using GridSearchCV finding the best parameter for hyperparameter tuning
# Out:
# {'alpha': 0.001}

# %%
def maxr2_score(lsreg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        lsreg=Lasso(alpha=0.001)
        lsreg.fit(x_train,y_train)
        y_predict=lsreg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#function to find the maxr2_score corresponding to the random state

# %%
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,df_x,y)
#calling the function with Lasso
# Out:
# r2score corresponing to 42 is: 0.5729956131572075
# r2score corresponing to 43 is: 0.5182284277499853
# r2score corresponing to 44 is: 0.5502781852965698
# r2score corresponing to 45 is: 0.5569585781185609
# r2score corresponing to 46 is: 0.575320431919454
# r2score corresponing to 47 is: 0.5495369492895321
# r2score corresponing to 48 is: 0.5569611753656067
# r2score corresponing to 49 is: 0.5266213057285563
# r2score corresponing to 50 is: 0.5425698536436125
# r2score corresponing to 51 is: 0.5616496653680837
# r2score corresponing to 52 is: 0.5167710024866426
# r2score corresponing to 53 is: 0.5616179099275156
# r2score corresponing to 54 is: 0.5150542281491874
# r2score corresponing to 55 is: 0.56555408703069
# r2score corresponing to 56 is: 0.5432803584627182
# r2score corresponing to 57 is: 0.5297619618113786
# r2score corresponing to 58 is: 0.5796762291772989
# r2score corresponing to 59 is: 0.5871619160225255
# r2score corresponing to 60 is: 0.5274423589672802
# r2score corresponing to 61 is: 0.5658271318426547
# r2score corresponing to 62 is: 0.5331501074744454
# r2score corresponing to 63 is: 0.5328089424310296
# r2score corresponing to 64 is: 0.5486550950355933
# r2score corresponing to 65 is: 0.53615837036768
# r2score corresponing to 66 is: 0.5484833767862167
# r2score corresponing to 67 is: 0.5473700982751492
# r2score corresponing to 68 is: 0.5542803391969897
# r2score corresponing to 69 is: 0.5489704617729637
# r2score corresponing to 70 is: 0.5555321236736389
# r2score corresponing to 71 is: 0.5583352749826948
# r2score corresponing to 72 is: 0.5233841162530735
# r2score corresponing to 73 is: 0.5268448620489871
# r2score corresponing to 74 is: 0.5455389859907158
# r2score corresponing to 75 is: 0.5139217135627272
# r2score corresponing to 76 is: 0.5495240466798119
# r2score corresponing to 77 is: 0.5526737853305728
# r2score corresponing to 78 is: 0.5353090185698406
# r2score corresponing to 79 is: 0.5516634806432397
# r2score corresponing to 80 is: 0.5584272379286204
# r2score corresponing to 81 is: 0.5224637854603431
# r2score corresponing to 82 is: 0.5470380707817124
# r2score corresponing to 83 is: 0.5423319793492494
# r2score corresponing to 84 is: 0.5713940887024138
# r2score corresponing to 85 is: 0.5314809015821036
# r2score corresponing to 86 is: 0.5283694740196883
# r2score corresponing to 87 is: 0.5128551945829163
# r2score corresponing to 88 is: 0.5609840811956626
# r2score corresponing to 89 is: 0.5831607093088689
# r2score corresponing to 90 is: 0.5295841745810744
# r2score corresponing to 91 is: 0.5225025052646834
# r2score corresponing to 92 is: 0.53938703139159
# r2score corresponing to 93 is: 0.5609202624434436
# r2score corresponing to 94 is: 0.5519200472158151
# r2score corresponing to 95 is: 0.5374026394601475
# r2score corresponing to 96 is: 0.5123770416616298
# r2score corresponing to 97 is: 0.5256439160030861
# r2score corresponing to 98 is: 0.5221618074854462
# r2score corresponing to 99 is: 0.5424467648860369
# r2score corresponing to 100 is: 0.5393853280732672
#
#
# max r2_score corresponding to  59 is 0.5871619160225255

# %%
Lsreg_score_mean=cross_val_score(lsreg,df_x,y,cv=5,scoring="r2").mean()
Lsreg_score_std=cross_val_score(lsreg,df_x,y,cv=5,scoring="r2").std()
print("mean r2score for Lasso:",Lsreg_score_mean)
print("standard deviation in r2score for lasso:",Lsreg_score_std)
#cross validating for bias-variance tradeoff using Cross_val_score
# Out:
# mean r2score for Lasso: 0.46988626043790677
# standard deviation in r2score for lasso: 0.07663071079109791

# %%
from sklearn.linear_model import Ridge
r_reg=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(r_reg,parameters,cv=10)
clf.fit(df_x,y)
clf.best_params_
#using GridSearchCv to find the best parameter
# Out:
# {'alpha': 1}

# %%
def maxr2_score(r_reg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        r_reg=Ridge(alpha=1)
        r_reg.fit(x_train,y_train)
        y_predict=r_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#function to find the maxr2_score corresponding to the random state

# %%
r_reg=Ridge(alpha=1)
r_state=maxr2_score(r_reg,df_x,y)
#calling the function using Ridge Regressor
# Out:
# r2score corresponing to 42 is: 0.610863264905054
# r2score corresponing to 43 is: 0.5441693949963997
# r2score corresponing to 44 is: 0.5749901096552117
# r2score corresponing to 45 is: 0.5877254665745111
# r2score corresponing to 46 is: 0.6024300645554534
# r2score corresponing to 47 is: 0.5770674349335936
# r2score corresponing to 48 is: 0.5842497896914675
# r2score corresponing to 49 is: 0.5592668650480633
# r2score corresponing to 50 is: 0.5718144726744745
# r2score corresponing to 51 is: 0.5920314360338701
# r2score corresponing to 52 is: 0.5423999776059336
# r2score corresponing to 53 is: 0.5844424122372004
# r2score corresponing to 54 is: 0.538078485084172
# r2score corresponing to 55 is: 0.5884083659904764
# r2score corresponing to 56 is: 0.5676042090982847
# r2score corresponing to 57 is: 0.5655822326489823
# r2score corresponing to 58 is: 0.6153079696961572
# r2score corresponing to 59 is: 0.6286286624195363
# r2score corresponing to 60 is: 0.5487553509410447
# r2score corresponing to 61 is: 0.5982561272257494
# r2score corresponing to 62 is: 0.565422036365264
# r2score corresponing to 63 is: 0.5725500239401242
# r2score corresponing to 64 is: 0.5712118285636629
# r2score corresponing to 65 is: 0.5585445347888525
# r2score corresponing to 66 is: 0.582236829281108
# r2score corresponing to 67 is: 0.5721852171610902
# r2score corresponing to 68 is: 0.5831753306341969
# r2score corresponing to 69 is: 0.585471679304461
# r2score corresponing to 70 is: 0.5967227059956123
# r2score corresponing to 71 is: 0.5962877966162197
# r2score corresponing to 72 is: 0.552723587329446
# r2score corresponing to 73 is: 0.5661149213535366
# r2score corresponing to 74 is: 0.5833805271886323
# r2score corresponing to 75 is: 0.5469650287062547
# r2score corresponing to 76 is: 0.5838731298624906
# r2score corresponing to 77 is: 0.5836815387866494
# r2score corresponing to 78 is: 0.5694473418906014
# r2score corresponing to 79 is: 0.5765014998904838
# r2score corresponing to 80 is: 0.5990577895868416
# r2score corresponing to 81 is: 0.5432323862414732
# r2score corresponing to 82 is: 0.577668214914643
# r2score corresponing to 83 is: 0.5727313196357127
# r2score corresponing to 84 is: 0.6086300265984053
# r2score corresponing to 85 is: 0.5560532556662453
# r2score corresponing to 86 is: 0.5691883531251235
# r2score corresponing to 87 is: 0.5473360090112049
# r2score corresponing to 88 is: 0.5956733323338348
# r2score corresponing to 89 is: 0.6157858497078437
# r2score corresponing to 90 is: 0.571544156751904
# r2score corresponing to 91 is: 0.5443075502095671
# r2score corresponing to 92 is: 0.5698036298778308
# r2score corresponing to 93 is: 0.5881989340853016
# r2score corresponing to 94 is: 0.5793068502244016
# r2score corresponing to 95 is: 0.5650125483843663
# r2score corresponing to 96 is: 0.5514853482546136
# r2score corresponing to 97 is: 0.5663382100122496
# r2score corresponing to 98 is: 0.5571110335075407
# r2score corresponing to 99 is: 0.5830632706649304
# r2score corresponing to 100 is: 0.5739185195103294
#
#
# max r2_score corresponding to  59 is 0.6286286624195363

# %%
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(df_x,y)
clf.best_params_
#using GridSearchCv to find the best parameter for hyperparameter tuning
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
def maxr2_score(gbr,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        gbr=GradientBoostingRegressor(learning_rate=0.1, n_estimators=100)
        gbr.fit(x_train,y_train)
        y_predict=gbr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#function to find the maxr2_score corresponding to the random state

# %%
gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=100)
r_state=maxr2_score(gbr,df_x,y)
#calling the function with GradientBoostRegressor
# Out:
# r2score corresponing to 42 is: 0.6778438243718765
# r2score corresponing to 43 is: 0.5941695736829216
# r2score corresponing to 44 is: 0.640213070827103
# r2score corresponing to 45 is: 0.6452092074834803
# r2score corresponing to 46 is: 0.657678165767914
# r2score corresponing to 47 is: 0.6407782451725754
# r2score corresponing to 48 is: 0.620563818957339
# r2score corresponing to 49 is: 0.6207415206769453
# r2score corresponing to 50 is: 0.6307573939462223
# r2score corresponing to 51 is: 0.6343314105603223
# r2score corresponing to 52 is: 0.6045192007913907
# r2score corresponing to 53 is: 0.6326977562959095
# r2score corresponing to 54 is: 0.6078071185356136
# r2score corresponing to 55 is: 0.6301247490041441
# r2score corresponing to 56 is: 0.6162127103129484
# r2score corresponing to 57 is: 0.6318335190633425
# r2score corresponing to 58 is: 0.6695985596063567
# r2score corresponing to 59 is: 0.679484818529695
# r2score corresponing to 60 is: 0.5967650997414409
# r2score corresponing to 61 is: 0.6531066909042065
# r2score corresponing to 62 is: 0.604225171449572
# r2score corresponing to 63 is: 0.6527693787260997
# r2score corresponing to 64 is: 0.6398000467607059
# r2score corresponing to 65 is: 0.6158446555397279
# r2score corresponing to 66 is: 0.6432064747330062
# r2score corresponing to 67 is: 0.6418109993335622
# r2score corresponing to 68 is: 0.6339155982645172
# r2score corresponing to 69 is: 0.6389878352543238
# r2score corresponing to 70 is: 0.6461226364188715
# r2score corresponing to 71 is: 0.6459684009881059
# r2score corresponing to 72 is: 0.6004494538410026
# r2score corresponing to 73 is: 0.618852915017264
# r2score corresponing to 74 is: 0.6475530034135974
# r2score corresponing to 75 is: 0.6020029441898072
# r2score corresponing to 76 is: 0.6416912625793217
# r2score corresponing to 77 is: 0.6505985722097598
# r2score corresponing to 78 is: 0.6401072100524039
# r2score corresponing to 79 is: 0.6346680338744906
# r2score corresponing to 80 is: 0.6592908689406106
# r2score corresponing to 81 is: 0.5965488624897033
# r2score corresponing to 82 is: 0.6553003136668316
# r2score corresponing to 83 is: 0.6370585061057229
# r2score corresponing to 84 is: 0.6570419677812065
# r2score corresponing to 85 is: 0.6220832775856915
# r2score corresponing to 86 is: 0.6223385471307734
# r2score corresponing to 87 is: 0.6008898090713477
# r2score corresponing to 88 is: 0.6492786392502687
# r2score corresponing to 89 is: 0.6665030171149567
# r2score corresponing to 90 is: 0.6292880740561291
# r2score corresponing to 91 is: 0.6225848112804239
# r2score corresponing to 92 is: 0.6360133368325851
# r2score corresponing to 93 is: 0.6532801509980379
# r2score corresponing to 94 is: 0.6294399174883472
# r2score corresponing to 95 is: 0.6083635859687013
# r2score corresponing to 96 is: 0.6069899449430325
# r2score corresponing to 97 is: 0.624626042022266
# r2score corresponing to 98 is: 0.6136030028202903
# r2score corresponing to 99 is: 0.6647404663021959
# r2score corresponing to 100 is: 0.6100565870018735
#
#
# max r2_score corresponding to  59 is 0.679484818529695

# %%
print("mean r2score for GradientBoostingRegressor:",cross_val_score(gbr,df_x,y,cv=5,scoring="r2").mean())
print("standard deviationof  r2score for GradientBoostingRegressor:",cross_val_score(gbr,df_x,y,cv=5,scoring="r2").std())
#cross validating for bias-variance tadeoff using cross_val_score
# Out:
# mean r2score for GradientBoostingRegressor: 0.5817093576144066
# standard deviationof  r2score for GradientBoostingRegressor: 0.053557368842564186

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[regr,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(df_x,y)
clf.best_params_
#using GridSearchCV to find the best parameter
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 1000}

# %%
def maxr2_score(ada_reg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=r_state,test_size=0.20)
        ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
                       max_leaf_nodes=None, min_impurity_decrease=0.0,
                       min_impurity_split=None, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       presort=False, random_state=None, splitter='best'),
 learning_rate= 1,
 n_estimators= 1000)
        ada_reg.fit(x_train,y_train)
        y_predict=ada_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state
#function to find the maxr2_score corresponding to the random state

# %%
ada_reg=AdaBoostRegressor(AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
                       max_leaf_nodes=None, min_impurity_decrease=0.0,
                       min_impurity_split=None, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       presort=False, random_state=None, splitter='best'),
 learning_rate= 1,
 n_estimators= 1000))
r_state=maxr2_score(ada_reg,df_x,y)
#calling the function using AdaBoostRegressor
# Out:
# r2score corresponing to 42 is: 0.6399660708568672
# r2score corresponing to 43 is: 0.56350975198922
# r2score corresponing to 44 is: 0.5971543607443602
# r2score corresponing to 45 is: 0.5907728964848795
# r2score corresponing to 46 is: 0.6390621860957478
# r2score corresponing to 47 is: 0.6025860057270556
# r2score corresponing to 48 is: 0.5893023328453094
# r2score corresponing to 49 is: 0.5831150528088631
# r2score corresponing to 50 is: 0.6009711596827825
# r2score corresponing to 51 is: 0.6143237064460684
# r2score corresponing to 52 is: 0.568333761523709
# r2score corresponing to 53 is: 0.5966930648888026
# r2score corresponing to 54 is: 0.5681405101960291
# r2score corresponing to 55 is: 0.6019093338959529
# r2score corresponing to 56 is: 0.5776289401190166
# r2score corresponing to 57 is: 0.6053741290802237
# r2score corresponing to 58 is: 0.6456985257548884
# r2score corresponing to 59 is: 0.649114783870377
# r2score corresponing to 60 is: 0.5798455517727785
# r2score corresponing to 61 is: 0.6184699825430042
# r2score corresponing to 62 is: 0.5685677039237286
# r2score corresponing to 63 is: 0.643446229389631
# r2score corresponing to 64 is: 0.6137610885610343
# r2score corresponing to 65 is: 0.592297883717965
# r2score corresponing to 66 is: 0.6258430305525722
# r2score corresponing to 67 is: 0.6179670804781707
# r2score corresponing to 68 is: 0.5955544952193613
# r2score corresponing to 69 is: 0.6048554540363309
# r2score corresponing to 70 is: 0.6336357301045052
# r2score corresponing to 71 is: 0.611054967543317
# r2score corresponing to 72 is: 0.5770431403138778
# r2score corresponing to 73 is: 0.6035735839722052
# r2score corresponing to 74 is: 0.6248364882920031
# r2score corresponing to 75 is: 0.5679367090145429
# r2score corresponing to 76 is: 0.617315521282119
# r2score corresponing to 77 is: 0.6336523581531406
# r2score corresponing to 78 is: 0.5954433567742119
# r2score corresponing to 79 is: 0.6171840779685758
# r2score corresponing to 80 is: 0.6324317033908177
# r2score corresponing to 81 is: 0.5607381123350176
# r2score corresponing to 82 is: 0.6383412916410629
# r2score corresponing to 83 is: 0.6177576493897814
# r2score corresponing to 84 is: 0.6236582839550742
# r2score corresponing to 85 is: 0.5908241052021015
# r2score corresponing to 86 is: 0.6085483578663551
# r2score corresponing to 87 is: 0.5731655444816945
# r2score corresponing to 88 is: 0.6278831486160736
# r2score corresponing to 89 is: 0.6307198447617786
# r2score corresponing to 90 is: 0.616308146980577
# r2score corresponing to 91 is: 0.5947867042013002
# r2score corresponing to 92 is: 0.6104017789188463
# r2score corresponing to 93 is: 0.6289278035215928
# r2score corresponing to 94 is: 0.6151148170796152
# r2score corresponing to 95 is: 0.5735821246212061
# r2score corresponing to 96 is: 0.594478120589432
# r2score corresponing to 97 is: 0.6112645194324999
# r2score corresponing to 98 is: 0.5973598227799604
# r2score corresponing to 99 is: 0.63503896939802
# r2score corresponing to 100 is: 0.5865458653996101
#
#
# max r2_score corresponding to  59 is 0.649114783870377

# %%
print("mean r2score for AdaBoostRegressor:",cross_val_score(ada_reg,df_x,y,cv=5,scoring="r2").mean())
print("standard deviationof  r2score for AdaBoostRegressor:",cross_val_score(ada_reg,df_x,y,cv=5,scoring="r2").std())
#cross validating for bias-variance tradeoff
# Out:
# mean r2score for AdaBoostRegressor: 0.543003914827153
# standard deviationof  r2score for AdaBoostRegressor: 0.04792262423883357

# %%
x_train,x_test,y_train,y_test=train_test_split(df_x,y,random_state=59,test_size=0.20)
gbr.fit(x_train,y_train)
y_predict=gbr.predict(x_test)

# %% [markdown]
# # since GradientBoostRegressor gives the best r2score of 0.6794 corresponding to random_state 59 so with the change in random state and fitting the traing data using GradientBoostRegressor and usnig Predict function on the testing data

# %%
print("r2score is",r2_score(y_test,y_predict))
print("root mean squarred error is",np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# r2score is 0.679415767173883
# root mean squarred error is 0.16414519949275147

# %%
from sklearn.externals import joblib
joblib.dump(gbr,"gbr_abalone.pkl")
# Out:
# ['gbr_abalone.pkl']

# %% [markdown]
# # using joblib to dump the file using GradientBoostRegressor as my selected algorithm as it also takes care of overfitting or underfitting problem
