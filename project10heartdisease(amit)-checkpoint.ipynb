# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
#importing the libraries and warnings and setting warnings to ignore warnings

# %%
#loading dataset and providing names to the column
heart_data=pd.read_csv("heartdisease.csv",names=["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","pred"])

# %%
#loading the data into a DataFrame and checking the head of the data
heart_data=pd.DataFrame(heart_data)
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  pred
# 0  0.0   6.0     0
# 1  3.0   3.0     2
# 2  2.0   7.0     1
# 3  0.0   3.0     0
# 4  0.0   3.0     0

# %%
#datatypes of the column in the dataset
heart_data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca          float64
# thal        float64
# pred          int64
# dtype: object

# %%
#the shape of the data
heart_data.shape
# Out:
# (303, 14)

# %%
#no null values present in the dataset
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# pred        0
# dtype: int64

# %%
#no null values present in the dataset
sns.heatmap(heart_data.isnull())

# %%
#droping NaN values
heart_data.dropna(inplace=True)

# %%
#statistical description of individual column
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# std      0.994971   22.875003    0.469794    1.161075    0.616226    0.937438
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000
#
#              thal        pred
# count  301.000000  303.000000
# mean     4.734219    0.937294
# std      1.939706    1.228536
# min      3.000000    0.000000
# 25%      3.000000    0.000000
# 50%      3.000000    0.000000
# 75%      7.000000    2.000000
# max      7.000000    4.000000

# %%
#the count of different types of prediction
print(heart_data.groupby('pred').size())
# Out:
# pred
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# dtype: int64

# %%
#histogram of the individual column 
heart_data.hist(layout=(3,5),figsize=(20,20),bins=10)
plt.tight_layout()

# %%
#boxplot of individual column shows outliers in trestbps,chol,fbs,oldpeak,ca column
heart_data.plot(kind='box', subplots=True, layout=(5,6), sharex=False, sharey=False,figsize=(20,20))
plt.tight_layout()

# %%
#correlation matrix of the columns present in the dataset
heart_data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.097542  0.104139  0.284946  0.208950  0.118530
# sex      -0.097542  1.000000  0.010084 -0.064456 -0.199915  0.047862
# cp        0.104139  0.010084  1.000000 -0.036077  0.072319 -0.039975
# trestbps  0.284946 -0.064456 -0.036077  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.072319  0.130120  1.000000  0.009841
# fbs       0.118530  0.047862 -0.039975  0.175340  0.009841  1.000000
# restecg   0.148868  0.021647  0.067505  0.146560  0.171043  0.069564
# thalach  -0.393806 -0.048663 -0.334422 -0.045351 -0.003432 -0.007854
# exang     0.091661  0.146201  0.384060  0.064762  0.061310  0.025665
# oldpeak   0.203805  0.102173  0.202277  0.189171  0.046564  0.005747
# slope     0.161770  0.037533  0.152050  0.117382 -0.004062  0.059894
# ca        0.362605  0.093185  0.233214  0.098773  0.119000  0.145478
# thal      0.127389  0.380936  0.265246  0.133554  0.014214  0.071358
# pred      0.222853  0.224469  0.407075  0.157754  0.070909  0.059186
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age       0.148868 -0.393806  0.091661  0.203805  0.161770  0.362605
# sex       0.021647 -0.048663  0.146201  0.102173  0.037533  0.093185
# cp        0.067505 -0.334422  0.384060  0.202277  0.152050  0.233214
# trestbps  0.146560 -0.045351  0.064762  0.189171  0.117382  0.098773
# chol      0.171043 -0.003432  0.061310  0.046564 -0.004062  0.119000
# fbs       0.069564 -0.007854  0.025665  0.005747  0.059894  0.145478
# restecg   1.000000 -0.083389  0.084867  0.114133  0.133946  0.128343
# thalach  -0.083389  1.000000 -0.378103 -0.343085 -0.385601 -0.264246
# exang     0.084867 -0.378103  1.000000  0.288223  0.257748  0.145570
# oldpeak   0.114133 -0.343085  0.288223  1.000000  0.577537  0.295832
# slope     0.133946 -0.385601  0.257748  0.577537  1.000000  0.110119
# ca        0.128343 -0.264246  0.145570  0.295832  0.110119  1.000000
# thal      0.024531 -0.279631  0.329680  0.341004  0.287232  0.256382
# pred      0.183696 -0.415040  0.397057  0.504092  0.377957  0.518909
#
#               thal      pred
# age       0.127389  0.222853
# sex       0.380936  0.224469
# cp        0.265246  0.407075
# trestbps  0.133554  0.157754
# chol      0.014214  0.070909
# fbs       0.071358  0.059186
# restecg   0.024531  0.183696
# thalach  -0.279631 -0.415040
# exang     0.329680  0.397057
# oldpeak   0.341004  0.504092
# slope     0.287232  0.377957
# ca        0.256382  0.518909
# thal      1.000000  0.509923
# pred      0.509923  1.000000

# %%
#heatmap showing the correlation between the various column
plt.figure(figsize=(10,10))
sns.heatmap(heart_data.corr(),annot=True)
plt.tight_layout()

# %%
#pairplot of each of the individual column categorised as prediction
sns.pairplot(heart_data,hue="pred")

# %%
#pair plotting of each of the column 
sns.pairplot(heart_data)

# %%
scatter_matrix(heart_data,figsize=(20,20))
plt.show()

# %%
# voilin plot shows that most of the age group lies in between 50-60
sns.violinplot(heart_data["age"])

# %%
#jointplot of the age and the loan status
sns.jointplot(x="age",y="pred",data=heart_data)

# %%
#jointplot of sex and pred 
sns.jointplot(x="sex",y="pred",data=heart_data)

# %%
#shows the skewness in age column
sns.distplot(heart_data["age"])

# %%
#shows the skewness in restecg column
sns.distplot(heart_data["restecg"])

# %%
#skewness in cp column
sns.distplot(heart_data["cp"])

# %%
#countplot of the pred column shows the no. of prediction for each type
sns.countplot(heart_data["pred"])

# %%
sns.barplot(x="pred",y="sex",data=heart_data)

# %%
#dividing the data into input
x=heart_data.iloc[:,:13]
x.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal
# 0  0.0   6.0
# 1  3.0   3.0
# 2  2.0   7.0
# 3  0.0   3.0
# 4  0.0   3.0

# %%
#removing skewness from the input column
for col in x.columns:
    if x.skew().loc[col]>0.55:
        x[col]=np.log1p(x[col])

# %%
#output data
y=heart_data.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    2
# 2    1
# 3    0
# 4    0
# Name: pred, dtype: int64

# %%
#scaling of the input data
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import GridSearchCV

# %%
#dividing the data into training and testing data
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2,stratify=y)

# %%
#importing the algorithms
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

# %%
#creating object file of the algorithm
knn=KNeighborsClassifier()
sv=SVC()
dt=DecisionTreeClassifier(random_state=6)
lr=LogisticRegression()
rf=RandomForestClassifier()

# %%
#using GridSearchCV to find the best parameters for hyperparameter tuning
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
neighbors={"n_neighbors":range(1,30)}
gknn=GridSearchCV(knn,neighbors,cv=10)
gknn.fit(x,y)
gknn.best_params_
# Out:
# {'n_neighbors': 29}

# %%
#using GridSearchCV to find the best parameters for hyperparameter tuning
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
grid_param={"random_state":range(0,20),"criterion":['gini','entropy']}
Gdt=GridSearchCV(dt,param_grid=grid_param,scoring='accuracy',cv=10)
Gdt.fit(x,y)
Gdt.best_params_
# Out:
# {'criterion': 'gini', 'random_state': 19}

# %%
#using GridSearchCV to find the best parameters for hyperparameter tuning
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
kernel={"kernel":["linear","rbf","poly"]}
Gsv=GridSearchCV(sv,kernel,cv=10)
Gsv.fit(x,y)
Gsv.best_params_
# Out:
# {'kernel': 'linear'}

# %%
#using GridSearchCV to find the best parameters for hyperparameter tuning
from sklearn.ensemble import AdaBoostClassifier
ada_class=AdaBoostClassifier()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lr,dt]}
clf=GridSearchCV(ada_class,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                     intercept_scaling=1, l1_ratio=None, max_iter=100,
#                     multi_class='warn', n_jobs=None, penalty='l2',
#                     random_state=None, solver='warn', tol=0.0001, verbose=0,
#                     warm_start=False),
#  'learning_rate': 0.01,
#  'n_estimators': 1000}

# %%
import xgboost as xgb
xgc=xgb.XGBClassifier()

# %%
#providing the parameters to the algorithm
knn=KNeighborsClassifier(n_neighbors=29)
sv=SVC(kernel="linear")
dt=DecisionTreeClassifier(random_state=19,criterion="gini")
lr=LogisticRegression()
rf=RandomForestClassifier()
ada_class=AdaBoostClassifier(base_estimator= LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
                    intercept_scaling=1, l1_ratio=None, max_iter=100,
                    multi_class='warn', n_jobs=None, penalty='l2',
                    random_state=None, solver='warn', tol=0.0001, verbose=0,
                    warm_start=False),
 learning_rate=0.01,
 n_estimators=1000)

# %%
models=[]
models.append(("KNeighborsClassifier",knn))
models.append(("SVC",sv))
models.append(("DecisionTreeClassifier",dt))
models.append(("LogisticRegression",lr))
models.append(("RandomForestClassifier",rf))
models.append(("XGBClassifier",xgc))
models.append(("ADABoostClassifier",ada_class))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Model=[]
score=[]
cvs=[]
roc_score=[]
for name,model in models:
    print('*********************',name,'***************************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print("accuracy_score",AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring="accuracy").mean()
    print("cross_val_score=",sc)
    cvs.append(sc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print("\n")
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
# Out:
# ********************* KNeighborsClassifier ***************************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=29, p=2,
#                      weights='uniform')
#
#
# accuracy_score 0.55
#
#
# cross_val_score= 0.5997244623655915
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85        32
#            1       0.10      0.09      0.10        11
#            2       0.00      0.00      0.00         7
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.55        60
#    macro avg       0.17      0.22      0.19        60
# weighted avg       0.42      0.55      0.47        60
#
#
#
# [[32  0  0  0  0]
#  [ 8  1  2  0  0]
#  [ 2  4  0  1  0]
#  [ 1  3  3  0  0]
#  [ 0  2  1  0  0]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ********************* SVC ***************************
#
#
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)
#
#
# accuracy_score 0.6
#
#
# cross_val_score= 0.5967665130568356
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89        32
#            1       0.50      0.27      0.35        11
#            2       0.00      0.00      0.00         7
#            3       0.29      0.29      0.29         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.60        60
#    macro avg       0.32      0.31      0.30        60
# weighted avg       0.56      0.60      0.57        60
#
#
#
# [[31  0  1  0  0]
#  [ 5  3  2  1  0]
#  [ 2  3  0  2  0]
#  [ 0  0  4  2  1]
#  [ 0  0  1  2  0]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ********************* DecisionTreeClassifier ***************************
#
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=19, splitter='best')
#
#
# accuracy_score 0.5
#
#
# cross_val_score= 0.5188152841781873
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        32
#            1       0.28      0.45      0.34        11
#            2       0.17      0.14      0.15         7
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.50        60
#    macro avg       0.26      0.27      0.26        60
# weighted avg       0.53      0.50      0.51        60
#
#
#
# [[24  4  2  2  0]
#  [ 4  5  1  0  1]
#  [ 0  3  1  3  0]
#  [ 0  5  2  0  0]
#  [ 0  1  0  2  0]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ********************* LogisticRegression ***************************
#
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# accuracy_score 0.6
#
#
# cross_val_score= 0.5831653225806451
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.78      0.97      0.86        32
#            1       0.33      0.18      0.24        11
#            2       0.00      0.00      0.00         7
#            3       0.38      0.43      0.40         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.60        60
#    macro avg       0.30      0.32      0.30        60
# weighted avg       0.52      0.60      0.55        60
#
#
#
# [[31  1  0  0  0]
#  [ 6  2  2  1  0]
#  [ 3  1  0  3  0]
#  [ 0  0  3  3  1]
#  [ 0  2  0  1  0]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ********************* RandomForestClassifier ***************************
#
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
# accuracy_score 0.5666666666666667
#
#
# cross_val_score= 0.5680942780337941
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.74      0.97      0.84        32
#            1       0.33      0.27      0.30        11
#            2       0.00      0.00      0.00         7
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.57        60
#    macro avg       0.21      0.25      0.23        60
# weighted avg       0.45      0.57      0.50        60
#
#
#
# [[31  0  0  1  0]
#  [ 6  3  1  1  0]
#  [ 3  2  0  2  0]
#  [ 2  3  2  0  0]
#  [ 0  1  0  2  0]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ********************* XGBClassifier ***************************
#
#
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)
#
#
# accuracy_score 0.55
#
#
# cross_val_score= 0.5513316052227342
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88        32
#            1       0.24      0.36      0.29        11
#            2       0.00      0.00      0.00         7
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.55        60
#    macro avg       0.22      0.25      0.23        60
# weighted avg       0.50      0.55      0.52        60
#
#
#
# [[29  1  0  1  1]
#  [ 4  4  0  2  1]
#  [ 1  4  0  0  2]
#  [ 0  6  1  0  0]
#  [ 0  2  0  1  0]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ********************* ADABoostClassifier ***************************
#
#
# AdaBoostClassifier(algorithm='SAMME.R',
#                    base_estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                      dual=False,
#                                                      fit_intercept=True,
#                                                      intercept_scaling=1,
#                                                      l1_ratio=None,
#                                                      max_iter=100,
#                                                      multi_class='warn',
#                                                      n_jobs=None, penalty='l2',
#                                                      random_state=None,
#                                                      solver='warn', tol=0.0001,
#                                                      verbose=0,
#                                                      warm_start=False),
#                    learning_rate=0.01, n_estimators=1000, random_state=None)
#
#
# accuracy_score 0.5833333333333334
#
#
# cross_val_score= 0.5830280337941629
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86        32
#            1       0.40      0.18      0.25        11
#            2       0.14      0.14      0.14         7
#            3       0.22      0.29      0.25         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.58        60
#    macro avg       0.31      0.31      0.30        60
# weighted avg       0.54      0.58      0.55        60
#
#
#
# [[30  2  0  0  0]
#  [ 6  2  2  1  0]
#  [ 2  0  1  4  0]
#  [ 0  0  4  2  1]
#  [ 0  1  0  2  0]]
# AxesSubplot(0.125,0.808774;0.62x0.0712264)

# %%
result=pd.DataFrame({'Model':Model,'Accuracy_score':score,'Cross_Val_Score':cvs})
result
# Out:
#                     Model  Accuracy_score  Cross_Val_Score
# 0    KNeighborsClassifier       55.000000        59.972446
# 1                     SVC       60.000000        59.676651
# 2  DecisionTreeClassifier       50.000000        51.881528
# 3      LogisticRegression       60.000000        58.316532
# 4  RandomForestClassifier       56.666667        56.809428
# 5           XGBClassifier       55.000000        55.133161
# 6      ADABoostClassifier       58.333333        58.302803

# %%
from sklearn.externals import joblib
joblib.dump(sv,"svc_heartdisease.pkl")
# Out:
# ['svc_heartdisease.pkl']

# %% [markdown]
# # since the highest accuracy i.e 60% is provided by the support vector classifier and the cross_val_score is also the highest at 59.67% so it is appropiate to choose support vector classifier
